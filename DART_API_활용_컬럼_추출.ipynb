# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunhye1109/Practical-Project/blob/HS/DART_API_%ED%99%9C%EC%9A%A9_%EC%BB%AC%EB%9F%BC_%EC%B6%94%EC%B6%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 마운트
import google.colab.drive
google.colab.drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/실전프로젝트
# Out:
# /content/drive/MyDrive/Colab Notebooks/실전프로젝트

# %%
# !pip install dart-fss
# Out:
# Collecting dart-fss
#   Downloading dart_fss-0.4.13-py3-none-any.whl.metadata (3.6 kB)
# Collecting xmltodict (from dart-fss)
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.32.3)
# Collecting arelle-release (from dart-fss)
#   Downloading arelle_release-2.37.37-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from dart-fss) (4.67.1)
# Collecting yaspin (from dart-fss)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Collecting fake-useragent>=1.5 (from dart-fss)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from dart-fss) (4.13.4)
# Collecting appdirs (from dart-fss)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting bottle<0.14,>=0.13 (from arelle-release->dart-fss)
#   Downloading bottle-0.13.4-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.18.0)
# Requirement already satisfied: jsonschema==4.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (4.24.0)
# Collecting isodate==0.* (from arelle-release->dart-fss)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: lxml<6,>=4 in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (5.4.0)
# Requirement already satisfied: openpyxl==3.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.1.5)
# Requirement already satisfied: pillow<12,>=10 in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (11.2.1)
# Requirement already satisfied: pyparsing==3.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.2.3)
# Requirement already satisfied: python-dateutil==2.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2.9.0.post0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2024.11.6)
# Collecting truststore==0.* (from arelle-release->dart-fss)
#   Downloading truststore-0.10.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: typing-extensions==4.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (4.14.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (0.26.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl==3.*->arelle-release->dart-fss) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil==2.*->arelle-release->dart-fss) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->dart-fss) (2.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->dart-fss) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->dart-fss) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (2.4.0)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->dart-fss)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Downloading dart_fss-0.4.13-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 4.7 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 14.8 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading arelle_release-2.37.37-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 90.3 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading truststore-0.10.1-py3-none-any.whl (18 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading bottle-0.13.4-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 9.9 MB/s eta 0:00:00
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: bottle, appdirs, xmltodict, truststore, termcolor, isodate, fake-useragent, yaspin, arelle-release, dart-fss
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
# Successfully installed appdirs-1.4.4 arelle-release-2.37.37 bottle-0.13.4 dart-fss-0.4.13 fake-useragent-2.2.0 isodate-0.7.2 termcolor-2.3.0 truststore-0.10.1 xmltodict-0.14.2 yaspin-3.1.0

# %%
# !pip install sentence-transformers scikit-learn pandas
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.53.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.33.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.7.14)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 38.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# 코리안 임베딩 모델을 활용해서 DF 컬럼 유사도 측정
# 필요한 라이브러리 import
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import itertools
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from collections import Counter

# %%
import dart_fss as dart_fss
import pandas as pd

api_key = '845166f5401aeebbed295c86b5f47621b51f520a'
dart_fss.set_api_key(api_key=api_key)
# Out:
# WARNING:fake_useragent:Error occurred during getting browser(s): random, but was suppressed with fallback.
# '845166f5401aeebbed295c86b5f47621b51f520a'

# %%
corp_list = dart_fss.get_corp_list()

corp_list.corps
# Out:
# [[00434003]다코,
#  [00430964]굿앤엘에스,
#  [00388953]크레디피아제이십오차유동화전문회사,
#  [00179984]연방건설산업,
#  [00420143]브룩스피알아이오토메이션잉크,
#  [00401111]매경아이비아이,
#  [00435534]캐드뱅크,
#  [00430186]엠와이오피삼차유동화전문유한회사,
#  [00430201]엠와이오피이차유동화전문유한회사,
#  [00430210]엠와이오피일차유동화전문유한회사,
#  [00430229]포스미디어,
#  [00140432]축복할렐루야,
#  [00426208]한국전자화학,
#  [00433262]ConnachtCapitalMarketInvestmentLtd.,
#  [00433749]선진아이티,
#  [00433785]팀스코리아,
#  [00196079]에넥스하이테크,
#  [00435048]세이스텝바이스텝혼합형펀드,
#  [00435057]유리알파헷지채권혼합형펀드,
#  [00108843]한기술정보통신,
#  [00443232]다움종합건설,
#  [00248293]한국애치슨,
#  [00455662]고은상사,
#  [00149318]조흥종합건설,
#  [00451347]유니즈유통,
#  [00415105]창대화장품,
#  [00420824]문화종합건설,
#  [00389439]한국종합미디어,
#  [00454016]아이펜텍,
#  [00452072]대홍염공,
#  [00437602]지오항공여행사,
#  [00365518]헤이아니타코리아,
#  [00246967]태산산업개발,
#  [00445559]군포종합시장,
#  [00444657]기우,
#  [00448936]라시도,
#  [00405658]예전미디어,
#  [00410818]세미가,
#  [00416061]대닉스,
#  [00448909]인포핸드,
#  [00445407]지현개발,
#  [00421647]한국부동산신탁제일차유동화전문유한회사,
#  [00421425]ISCCaymanLtd.,
#  [00423265]연산,
#  [00423292]씨케이알유동화전문유한회사,
#  [00420602]디에스피,
#  [00307505]LOMBARDKOREAILIMITED,
#  [00241397]우신투자자문,
#  [00421896]외환카드제오차유동화전문유한회사,
#  [00365712]태연,
#  [00388616]글로벌금강제일차유동화전문유한회사,
#  [00230407]글로벌렌탈,
#  [00423566]뤼미에르에셋,
#  [00423274]바사라엔터테인먼트,
#  [00419688]대백유동화전문유한회사,
#  [00419712]아이키키,
#  [00414665]진명씨앤씨,
#  [00421869]한경핫벤처,
#  [00421957]우리부동산제일차유동화전문유한회사,
#  [00255442]영진상운,
#  [00427517]한국토지신탁제오차유동화전문유한회사,
#  [00376152]다드림커뮤니케이션,
#  [00382241]ARISAIGASIANSMALLCOMPANIESFUND(L)BHD,
#  [00431501]싱가포르개발은행서울지점,
#  [00434289]KTB혼합형펀드,
#  [00434298]KTB플러스찬스혼합형펀드,
#  [00434313]KTB포트폴리오스타혼합형펀드,
#  [00434322]KTB에버스타혼합형펀드,
#  [00429463]나노이앤씨,
#  [00429515]지산엔터프라이즈,
#  [00432175]유아이에스코리아,
#  [00387033]트리플에스유동화전문유한회사,
#  [00384045]크레디피아제이십일차유동화전문유한회사,
#  [00431608]싱가포르개발은행,
#  [00431705]엘지팩토링제일차유동화전문유한회사,
#  [00430256]이피에스뱅크,
#  [00431167]이라이프네트워크,
#  [00432315]덕성,
#  [00413134]타오건설,
#  [00435376]장원코리아,
#  [00110909]대신통상,
#  [00220695]서울교육,
#  [00211794]보성패션,
#  [00454496]넥스탑,
#  [00455592]마니빌,
#  [00370796]제이엘코프,
#  [00199401]컴마을,
#  [00369596]삼신크리에이션,
#  [00210078]호한통상,
#  [00363398]케이엠티,
#  [00110042]대백가구,
#  [00364324]청빛산업개발,
#  [00248017]삼양전자,
#  [00452179]숭민코리아유통,
#  [00413754]유오티앤씨,
#  [00343163]한라스페코중공업,
#  [00452513]알본,
#  [00435978]상일디지털,
#  [00368153]서전어패럴,
#  [00455149]웰비스트랜스,
#  [00249946]한국키엔스,
#  [00110839]대신생명보험,
#  [00293798]대성메디테크,
#  [00113119]대한알루미늄공업,
#  [00424389]남성엠케이,
#  [00424486]씨엠액텍,
#  [00224734]한국부동산신탁,
#  [00197713]주은산업,
#  [00421948]신엘지프라이머리제이차유동화전문유한회사,
#  [00422381]데코제일차유동화전문유한회사,
#  [00350446]뉴스테이트삼차모기지유동화전문유한회사,
#  [00396642]엘지수퍼센터,
#  [00425449]아이클릭세븐,
#  [00425458]월드인코레스,
#  [00425333]코리아픽시컴,
#  [00424617]산은부동산제사차유동화전문유한회사,
#  [00424006]글로벌자이언트시스템,
#  [00424051]신클레어,
#  [00403599]에이에스피기업구조조정전문,
#  [00425519]Marubeni-ItochuSteelInc.,
#  [00224585]신한,
#  [00429524]우리모아제이차유동화전문유한회사,
#  [00429533]글로벌사모안정혼합형펀드,
#  [00432722]파워외환카드제팔차유동화전문유한회사,
#  [00432786]파워외환카드제오차유동화전문유한회사,
#  [00429728]영퓨처,
#  [00428668]코로볼틴펀드리미티드,
#  [00430751]대창크랑크,
#  [00385372]허츠제일차유동화전문유한회사,
#  [00431680]새암교육,
#  [00386308]반지종합상가,
#  [00256450]동서산업건설(가칭),
#  [00290816]대우종합기계(가칭),
#  [00291532]대우조선공업(가칭),
#  [00127990]삼일상호저축은행,
#  [00431565]케이디에스에스,
#  [00399959]비젼케이파트너스,
#  [00430238]리버랜드,
#  [00263034]동양선재,
#  [00205298]춘천미도파,
#  [00431042]거버너스M&A사모펀드3호,
#  [00348715]아이앤비골드문브이에이치,
#  [00447964]체리미디어,
#  [00448361]경원하이텍,
#  [00185851]중원화학,
#  [00445735]나크나인,
#  [00385770]동남해상관광호텔,
#  [00319245]한성선박,
#  [00126502]삼성콘크리트공업,
#  [00363440]엠알더블유테크노로지,
#  [00445522]제이에이치홀딩스,
#  [00320302]동연산업,
#  [00444958]우양주택건설,
#  [00441836]해진하우징,
#  [00445629]효헌산업,
#  [00454052]우림산업개발,
#  [00454414]에이스하이테크,
#  [00196857]해표푸드서비스,
#  [00413383]에프씨산업,
#  [00225098]극동뉴메릭,
#  [00410304]서울드림랜드,
#  [00310998]한국미라이공업,
#  [00415114]21세기화장품,
#  [00451000]광명산업,
#  [00369985]다음솔루션,
#  [00371670]정우조명,
#  [00401430]모바일웰컴,
#  [00247027]푸른건설,
#  [00144058]월다크,
#  [00416867]길도건업,
#  [00456263]원일스포지움,
#  [00436339]용인자원,
#  [00120748]마산강관,
#  [00386724]세창철강공업,
#  [00255390]재무와정보,
#  [00455547]대양중공업,
#  [00233398]이에이지씨,
#  [00405065]페타코페트로륨,
#  [00425537]MarubeniCorporation,
#  [00424158]캐피탈라인,
#  [00100920]건설증권,
#  [00370167]일진전자통신,
#  [00409131]오픈솔루션,
#  [00424194]AMERICAORIENTALGROUP,
#  [00364713]mvp창업투자,
#  [00408901]라이져,
#  [00161170]한라시멘트,
#  [00423557]한국알리안츠화재해상보험,
#  [00307444]코리아벌처투자,
#  [00370468]티에스케이지,
#  [00424219]텔레닉스,
#  [00424185]유니텍워터시스템즈,
#  [00424556]거륜씨앤씨,
#  [00121631]문화,
#  [00424866]모비도미,
#  [00424884]에이치케이인베스트먼트유동화전문유한회사,
#  [00424927]LiquidmetalTechnologies,
#  [00423797]모멘타(케이만),
#  [00433350]KTB프라임8호혼합형사모펀드,
#  [00433369]유리명품장기채권형사모펀드3호,
#  [00433378]유리유니콘채권혼합형펀드,
#  [00433387]맥쿼리아이엠엠프라임7호채권형사모펀드,
#  [00433420]마이에셋애국성장형이호펀드,
#  [00433457]채권플러스알파2호펀드,
#  [00433466]마이다스사모프라임안정형2호펀드,
#  [00376073]테크포인트,
#  [00234306]부국개발,
#  [00429418]세닥에듀케이션,
#  [00429977]에이치엘홀딩스에스에이,
#  [00340786]크레디리요네증권,
#  [00218928]케이티인더스트리,
#  [00106793]김천상호저축은행,
#  [00378886]이화홀딩스,
#  [00433484]미래에셋유니온사모혼합형펀드2호,
#  [00433493]맥쿼리아이엠엠액티브채권형사모펀드3호,
#  [00433509]맥쿼리아이엠엠프라임6호혼합형사모펀드,
#  [00433518]유리명품장기채권형사모펀드2호,
#  [00406596]신우쉬핑,
#  [00443001]동흥컨설팅,
#  [00363741]디조콤,
#  [00436375]맘모스산업개발,
#  [00222277]아성,
#  [00446284]디토정보기술,
#  [00446682]오우디앤씨,
#  [00139995]에어웨이엑스프레스,
#  [00444602]탑월드,
#  [00150314]진로종합유통,
#  [00231840]케이에프텍,
#  [00236243]나토상사,
#  [00309479]지오이네트,
#  [00447034]이십일세기종합건설,
#  [00447496]일현건설,
#  [00300928]삼영기공,
#  [00317566]삼능주택,
#  [00412001]동해,
#  [00155407]풍광직물,
#  [00443542]기성텍스타일,
#  [00179726]제텍스바론,
#  [00300982]국제개발,
#  [00298818]유유후마킬라,
#  [00424644]피앤씨미디어,
#  [00350570]비앤에프투자자문,
#  [00424316]한국부동산신탁제이차유동화전문유한회사,
#  [00368551]에이텍,
#  [00424307]덕경종합건설,
#  [00425078]글로벌스페셜혼합형사모펀드,
#  [00154499]태화,
#  [00424653]씨앤앰유동화전문유한회사,
#  [00414522]온누리방송,
#  [00425120]케이티엠,
#  [00356723]아이앤비골드문컨설팅,
#  [00375506]동국제강제일차유동화전문유한회사,
#  [00424769]밸류노믹스기업구조조정전문회사,
#  [00223300]조창,
#  [00360294]영지통상,
#  [00425209]RosewellConsulting&InvestmentLtd.,
#  [00433527]유리시티즌장기채권형사모펀드,
#  [00433536]KTB장기채권형사모펀드3호,
#  [00433545]KTB장기채권형사모펀드4호,
#  [00433554]맥쿼리아이엠엠포세이돈채권형사모펀드4호,
#  [00433563]마이에셋애국안정형1호펀드,
#  [00434702]노보스,
#  [00434711]세이유니온채권혼합형사모펀드,
#  [00434720]LG드림혼합형펀드,
#  [00434739]알파그로스주식형펀드,
#  [00434748]유리알파헷지채권혼합형사모펀드,
#  [00434757]알파헷지이기욱혼합형펀드,
#  [00434775]맥쿼리IMM홀인원채권형펀드,
#  [00434793]유리시장중립채권형사모펀드,
#  [00434809]유리알파30채권혼합형사모펀드,
#  [00432573]파워외환카드제사차유동화전문유한회사,
#  [00432607]파워외환카드제이차유동화전문유한회사,
#  [00432643]케드제이차유동화전문유한회사,
#  [00323390]굿윌경영자문,
#  [00412861]국제금속산업,
#  [00443913]덕정무역,
#  [00315179]삼성코닝마이크로옵틱스,
#  [00165264]혜성건설,
#  [00368171]코스모에쿼티파트너스,
#  [00369480]경빈,
#  [00446196]내외시스템,
#  [00108311]태승어패럴,
#  [00105615]금동조명,
#  [00360197]태광정밀공업,
#  [00360364]게르마니셀로이드코리아,
#  [00366720]청우제강,
#  [00273536]필리아텔레콤,
#  [00443375]진도개발,
#  [00447511]만남과축복,
#  [00403872]영상산업,
#  [00441757]쌈솔,
#  [00445221]링크테크21,
#  [00448769]건화메디팜,
#  [00351357]윈윈창업투자,
#  [00371333]지티웹코리아,
#  [00392716]트랜스미디어매니지먼트,
#  [00424398]남성유통,
#  [00380322]무지개유동화전문유한회사,
#  [00387264]엘지화학제일차유동화전문유한회사,
#  [00425379]페가수스캐피탈아시아,
#  [00421595]한솔케미언스제일차유동화전문유한회사,
#  [00128564]삼천리M&C,
#  [00304757]넥스트디앤드에스,
#  [00407142]드림라인제일차유동화전문유한회사,
#  [00408044]동국산업제일차유동화전문유한회사,
#  [00112387]휴먼이노텍,
#  [00423539]자도,
#  [00103981]광전자INT,
#  [00416478]굿케이디비제삼차유동화전문유한회사,
#  [00418801]신엑스퍼트유동화전문,
#  [00419332]비발디제일차유동화전문유한회사,
#  [00418078]두산위브유동화전문유한회사,
#  [00419651]코오롱폴리스유동화전문유한회사,
#  [00251695]메디캐피탈,
#  [00432661]파워외환카드제삼차유동화전문유한회사,
#  [00430858]에이치에스비프로퍼티원인베스트먼트유동화전문유한회사,
#  [00432670]서상금속,
#  [00434827]세이한가족주식형펀드,
#  [00434872]알파크레디트플러스채권형펀드,
#  [00434881]알파국공채채권형사모펀드,
#  [00434906]세이에이스알파혼합형펀드,
#  [00434915]맥쿼리IMM코리아플러스채권형펀드,
#  [00434924]맥쿼리IMM마켓뉴트럴혼합형사모펀드,
#  [00434933]세이원채권형펀드,
#  [00435093]그레이터차이나1호사모펀드,
#  [00435109]윌러스,
#  [00431820]디베스트사모엠엔에이펀드일호,
#  [00398525]미래에셋프리미어전환혼합형이호펀드,
#  [00260967]디지텔,
#  [00378956]유리세이프롱숏채권혼합형펀드,
#  [00164104]리젠트화재보험,
#  [00101266]경남리스금융,
#  [00412834]굿머니,
#  [00226343]한소닉테크,
#  [00150147]지산개발,
#  [00416937]지구환경산업,
#  [00132497]성도통상,
#  [00216461]에프샵,
#  [00369301]근영전자통신,
#  [00360106]보해주정,
#  [00410483]윈스텍,
#  [00409928]조한도시개발,
#  [00209647]대웅전기산업,
#  [00370316]해피라인,
#  [00134246]세원건설,
#  [00444806]린나이씨에스,
#  [00233112]성우전자,
#  [00450986]미도산업개발,
#  [00442206]덕성섬유,
#  [00361664]기흥종합건설,
#  [00370334]이에이치상사,
#  [00432616]웨이브티브이,
#  [00405436]유니크,
#  [00414319]송학장갑,
#  [00261610]위트비전,
#  [00362432]월드무역,
#  [00415293]오픈테크,
#  [00413204]아피아,
#  [00413277]차세대정보통신,
#  [00268455]조흥신탁유동화전문회사,
#  [00273606]오토일천구백구십구의일유동화전문유한회사,
#  [00303369]한국토지신탁제이차유동화전문유한회사,
#  [00317043]포커스제1차유동화전문유한회사,
#  [00328517]베스트이지제일차유동화전문유한회사,
#  [00341776]모비스코람유동화전문유한회사,
#  [00362131]아이에스피,
#  [00427492]한실흥산,
#  [00363413]아이티엔방송,
#  [00302829]슈퍼데크코리아,
#  [00426758]산은부동산제오차유동화전문유한회사,
#  [00427474]덕화산업,
#  [00428695]국민카드이천이의일유동화전문유한회사,
#  [00366508]마일스톤벤처투자,
#  [00402208]에스비아이코리아,
#  [00175021]씨티은행,
#  [00429250]AllianzFinanceB.V.,
#  [00425777]동의보감유동화전문유한회사,
#  [00109125]세화기술투자,
#  [00388810]미래에셋프리미어혼합형펀드,
#  [00383426]마이다스차익거래안정혼합형펀드,
#  [00146676]아이씨켐,
#  [00338152]소프트윈,
#  [00438902]신하나로유동화전문유한회사,
#  [00432856]벽산건설블루밍제일차유동화전문유한회사,
#  [00431033]이천일아울렛제일차유동화전문유한회사,
#  [00240866]씨마유통,
#  [00440934]캠앤아이코리아,
#  [00440952]제이경영컨설팅,
#  [00435598]태거산업,
#  [00350136]마인드텔,
#  [00350206]엘파오벤쳐캐피탈,
#  [00268288]심스밸리,
#  [00105846]LGEI,
#  [00350756]유리크레디트회사채혼합형펀드,
#  [00149497]알파캐피탈,
#  [00264778]유니씨앤티,
#  [00289227]미래에셋파이오니어벤처코스닥펀드,
#  [00449184]디에이치파트너스,
#  [00369028]근하종합개발호텔엑스포,
#  [00152491]코락,
#  [00445601]터보엔지니어링,
#  [00407610]알파엔지니어링,
#  [00146241]명성건설,
#  [00446071]스카이함백,
#  [00368384]비에스그룹,
#  [00446840]삼부이엔씨,
#  [00245791]두앙종합건설,
#  [00449625]신성전자,
#  [00375223]한국기업금융자문,
#  [00411631]고룡,
#  [00256326]아성식품,
#  [00367330]세원지애에이치,
#  [00371838]남양주택건설,
#  [00246480]이조해운,
#  [00359304]한서화학,
#  [00415600]대륭전자,
#  [00422910]서울에프엔텍파트너스,
#  [00451055]팔공산온천관광호텔,
#  [00448839]택산개발,
#  [00234670]동진피엠씨,
#  [00224707]대흥정공,
#  [00193568]신대광주택,
#  [00415080]아프로시스템스,
#  [00415053]화진코스메틱,
#  [00414869]모비야,
#  [00365527]우리켐테크,
#  [00364245]ABC,
#  [00364005]캐피탈아거스,
#  [00413329]유니솔,
#  [00215222]세화유통,
#  [00252481]용강,
#  [00369897]기바전자,
#  [00310855]에프에스비티아이코리아,
#  [00370015]디지텍,
#  [00303448]알에이코프,
#  [00404394]매경휴스닥,
#  [00201946]한국이연,
#  [00304207]한원텔레콤,
#  [00305093]진우,
#  [00410720]탑종합건설,
#  [00354354]썬키스,
#  [00311049]위슬런,
#  [00412782]대산반도체,
#  [00426615]네오소프트,
#  [00164061]드림에스디,
#  [00381659]크레디피아제십구차유동화전문,
#  [00382959]콩코드캐피탈아시아,
#  [00118886]에이브이씨닷컴,
#  [00374835]케이씨알파트너스,
#  [00115700]동성투자,
#  [00389192]오엔씨네트웍스,
#  [00346452]씨에스지,
#  [00420356]하이페리온제이차유동화전문유한회사,
#  [00425528]부산유조선,
#  [00427784]목동우림루미아트유동화전문유한회사,
#  [00244297]천보파이낸스,
#  [00428817]나라펫,
#  [00425740]하이케어시스템즈,
#  [00389086]우리금융제일차유동화전문유한회사,
#  [00425759]키치녹스,
#  [00426721]에이치에스제일차유동화전문유한회사,
#  [00426651]신드림풀유동화전문유한회사,
#  [00427951]넥센캐피탈,
#  [00448112]종연산업,
#  [00446655]성환,
#  [00357111]삼두디엔에스,
#  [00193221]삼희산업,
#  [00407595]아이스타뮤직,
#  [00367075]신흥울테크,
#  [00448501]삼양이컴,
#  [00197856]전주코아호텔,
#  [00378017]헬리오스기업구조조정전문회사,
#  [00207384]동일상사,
#  [00233927]헨켈코리아,
#  [00255372]센텍,
#  [00246693]태흥기업,
#  [00367932]만적,
#  [00334341]성신무역,
#  [00190224]새한철강,
#  [00448291]한림종합개발,
#  [00445391]동방귀석,
#  [00169321]부곡관광,
#  [00434076]에이취.엠.에스,
#  [00205128]서통테크놀로지,
#  [00450250]한경섬유,
#  [00368126]세진티앤엠,
#  [00175386]경기교통,
#  [00205748]강호개발,
#  [00358378]만덕,
#  [00221409]한국어센셜소프트웨어,
#  [00414328]와우북,
#  [00409982]부풍,
#  [00134149]세우무역,
#  [00414461]신우종합건설,
#  [00304508]중원,
#  [00247753]아스트로,
#  [00368816]한국멀티넷,
#  [00366085]넥스트미디어아이,
#  [00412302]일성리조트,
#  [00387246]동광산건,
#  [00265050]유렉셀테크놀러지,
#  [00236182]성일컴퓨텍,
#  [00296555]엠에프씨,
#  [00327226]얼라이언스시스템,
#  [00412852]대한주택이앤지,
#  [00143970]원창판지,
#  [00301404]한국피시,
#  [00109541]대륙공업,
#  [00404880]디지털테크놀러지,
#  [00393858]드림데이타,
#  [00385123]리첸시아유동화전문유한회사,
#  [00429010]코리아페이넷,
#  [00424963]디더블유씨유동화전문유한회사,
#  [00425768]티지일차유동화전문유한회사,
#  [00426749]피앤지정보통신,
#  [00330415]인바인,
#  [00150794]진흥주택,
#  [00429038]굿앤세이프,
#  [00421081]디바이너,
#  [00361734]케이아이티창업투자,
#  [00388768]외환카드제사차유동화전문유한회사,
#  [00425421]오프마이십일,
#  [00421850]창신테크,
#  [00425315]파워엑시스,
#  [00427580]삼성프론티어제십이차유동화전문유한회사,
#  [00425218]쓰리엔제이차유동화전문유한회사,
#  [00106951]낙산관광호텔,
#  [00395661]현지개발,
#  [00275118]케이티비벤처벌처일호펀드,
#  [00295389]메타텍,
#  [00389147]골든보우창업투자,
#  [00126803]삼아,
#  [00242341]에스엠아이씨,
#  [00440314]오토피아제팔차유동화전문유한회사,
#  [00440332]니즈솔루션,
#  [00441322]이나라카드,
#  [00440165]히타치전선,
#  [00288884]미래에셋드림파이오니어펀드,
#  [00148452]GPS,
#  [00156017]하나은행,
#  [00261045]시스컴,
#  [00437532]개풍주택개발,
#  [00303095]지오스테크널러지,
#  [00438753]IndusAsiaPacificFund,Ltd.,
#  [00367464]지앤텍,
#  [00201955]금화냉동,
#  [00409849]혜성,
#  [00131443]서통상사,
#  [00174022]유창섬유,
#  [00444763]피프,
#  [00412171]모수인터내쇼날,
#  [00232973]동해산업,
#  [00152419]대농중공업,
#  [00257413]신영팩토링,
#  [00362511]승진건설,
#  [00446743]아워스인베스트먼트,
#  [00253055]태흥산업개발,
#  [00448714]마하인더스트리,
#  [00448705]모아건설,
#  [00101716]경북레미콘,
#  [00447876]그루빅,
#  [00448671]라이프건설,
#  [00217150]대진종합건설,
#  [00164344]해피아이,
#  [00303314]성서,
#  [00451213]한신공업,
#  [00407416]오랙스정유,
#  [00178675]이논,
#  [00367181]예들,
#  [00413514]가인수산,
#  [00127538]삼원산업,
#  [00370051]유덕건설,
#  [00415123]크로스전자,
#  [00106012]금성텔,
#  [00158495]한국아프라이드매그네틱스,
#  [00299774]스타럽스,
#  [00414911]텔레프리,
#  [00414762]금화도시개발,
#  [00234078]길정종합건설,
#  [00412515]메디링스,
#  [00151076]창원개발,
#  [00170512]우신레저산업,
#  [00370033]연이산업,
#  [00406587]다른신문,
#  [00413471]비투올네트,
#  [00248804]성진사,
#  [00359854]네투스테크놀러지,
#  [00252870]동구,
#  [00300432]비아이캐피탈,
#  [00415938]세아개발,
#  [00345693]SKIMT,
#  [00426226]일신제약,
#  [00426235]모아에셋,
#  [00376505]그린페이퍼텍,
#  [00427058]원업제이차유동화전문유한회사,
#  [00427100]두손테크피아,
#  [00427331]유니맥코리아,
#  [00429144]아하크레딧유동화전문유한회사,
#  [00429180]거버너스M&A사모펀드2호,
#  [00419916]기가솔,
#  [00421009]모쿠스,
#  [00363796]남양산업,
#  [00302148]에이팩스기술투자,
#  [00426314]에스지테크놀러지,
#  [00427146]도이체방크아게런던,
#  [00245065]에이에스엠엘에스씨,
#  [00427182]얼라이언스캐피탈파트너즈,
#  [00382852]대진산업,
#  [00362113]하늘사랑,
#  [00220756]씨앤씨캐피탈,
#  [00162319]한양상사,
#  [00355511]Photronics,Inc.,
#  [00400176]무빙넷,
#  [00396402]슈마커코리아,
#  [00439938]유케이,
#  [00337977]캐피탈리서치앤매니지먼트컴퍼니,
#  [00436047]월드타운,
#  [00387097]센텀파크유동화전문유한회사,
#  [00274410]인트빔,
#  [00328100]나래소프트시스템,
#  [00243845]삼광고하켐,
#  [00336260]OAKMARKINTERNATIONALFUND,
#  [00262026]신중앙99-1유동화전문유한회사,
#  [00264431]크레디피아유동화전문,
#  [00264495]중소기업유동화전문유한회사,
#  [00267067]산은캐피탈제일호유동화전문유한회사,
#  [00290791]국민제이차유동화전문회사,
#  [00297837]국민제일차유동화전문유한회사,
#  [00429162]남양씨앤씨,
#  [00203643]유일냉장,
#  [00450108]평산공영,
#  [00171414]파산자한국산업증권,
#  [00200549]대홍방직,
#  [00114543]도투락,
#  [00197607]해덕기업,
#  [00258263]이수금속,
#  [00363617]세미코리아,
#  [00450287]정방종합건설,
#  [00413082]성우종합건설,
#  [00449537]신아토건,
#  [00163071]한일염공,
#  [00453239]코스모건설,
#  [00414267]한국방송출판,
#  [00349088]태성개발,
#  [00451514]월성주택건설,
#  [00386830]심도산업,
#  [00410128]코리아라이닝,
#  [00161198]한라종합건설,
#  [00126849]삼안공영,
#  [00437824]제석주택,
#  [00363176]한국모빌솔루션,
#  [00299871]연화상사,
#  [00340892]한강온천,
#  [00415725]나우아이엔에스,
#  [00306205]디아이씨,
#  [00371351]비앤에스아이엔씨,
#  [00369851]창원건설,
#  [00415840]알루테크,
#  [00246666]대상하이디어,
#  [00153296]태강산업,
#  [00161268]한륙전자,
#  [00210476]영신산업,
#  [00365581]이사이트랩,
#  [00183598]영신플랜트,
#  [00417088]정연산업,
#  [00415062]아코텔레콤,
#  [00172529]대영,
#  [00407337]프라임플러스캐피탈,
#  [00405092]에스티지시큐리티,
#  [00226060]보성설비,
#  [00206349]록정개발,
#  [00217035]신아스포츠,
#  [00224318]뉴라인여신금융,
#  [00424945]중소기업제삼차유동화전문유한회사,
#  [00428604]알비에이,
#  [00424565]체리스톤코리아,
#  [00226574]세모화학,
#  [00425157]리딩씨앤씨,
#  [00427340]폴리코,
#  [00427429]산은굿밸류제일차유동화전문유한회사,
#  [00420453]이프리즘,
#  [00403696]디미디어,
#  [00417592]유피텍,
#  [00365998]티브이가이드,
#  [00412913]스타코리아웹케스팅,
#  [00421355]아라정보기술,
#  [00426439]코리아컨텐츠네트워크,
#  [00427386]티티월드,
#  [00167129]흥산건설,
#  [00217707]연덕건설,
#  [00426518]비추미코리아제일차유동화전문유한회사,
#  [00426536]크레디피아제삼십오차유동화전문유한회사,
#  [00426545]아하론제삼차유동화전문유한회사,
#  [00335951]동원제일차유동화전문,
#  [00436588]케이투이,
#  [00435349]지영상사,
#  [00331450]아주의대벤처메딕스,
#  [00341952]엑스퍼트유동화전문유한회사,
#  [00342739]마이에셋유동화전문유한회사,
#  [00342988]한아름제2차유동화전문유한회사,
#  [00436241]에셋외환카드제이차유동화전문유한회사,
#  [00436269]에셋외환카드제육차유동화전문유한회사,
#  [00436296]타이거유동화전문유한회사,
#  [00237491]서한전자,
#  [00118099]동원직물,
#  [00436685]청유,
#  [00437107]서울전산,
#  [00436490]씨에스,
#  [00436524]선암건설,
#  [00435923]아세텔레콤,
#  [00437541]우리엘비제칠차유동화전문유한회사,
#  [00437569]지오택드레인,
#  [00336385]몬덱스코리아,
#  [00198253]서광티앤씨,
#  [00354062]로직스컴퓨터,
#  [00311818]RedTulipInvestments,
#  [00452267]아이산업개발,
#  [00446141]비코레트,
#  [00451365]우림엔지니어링건축사사무소,
#  [00263627]백현건설,
#  [00413912]우연종합건설,
#  [00362618]용성조선,
#  [00202404]송원자동차조명,
#  [00450773]태산종합건설,
#  [00252852]근도물산,
#  [00451879]씨에스피산업,
#  [00181217]삼흥판지,
#  [00375728]인터내셔날쥬피텍,
#  [00445823]대륙종합건설,
#  [00387167]마시나코아,
#  [00256885]부천산업,
#  [00452674]바롬테크,
#  [00449421]대방종합건설,
#  [00209230]영도섬유,
#  [00412311]미디어파트너스,
#  [00233741]한이해운,
#  [00299400]금영,
#  [00112518]대준섬유,
#  [00416760]두일,
#  [00397438]벽송종합건설,
#  [00198615]평해건설,
#  [00363228]대동제지공업,
#  [00415257]동서디엔씨,
#  [00369365]케미스,
#  [00405126]텔리맨,
#  [00415266]과일나라,
#  [00361354]넷츠고,
#  [00415275]동승건설,
#  [00367446]주영크리에이션,
#  [00415673]태광엔터프라이즈,
#  [00171751]한주종합건설,
#  [00416797]유정건설,
#  [00193407]세광종합건설,
#  [00365943]금양레포츠,
#  [00363060]게임벤처,
#  [00418892]마이애셋사모M&A펀드B호,
#  [00418917]하나로밀레니엄,
#  [00417370]메트로에이전시,
#  [00427508]국민카드제십차유동화전문유한회사,
#  [00367987]시봉전자,
#  [00428020]두산스피리츠,
#  [00382296]게토코리아,
#  [00297332]AmkorTechnology,Inc.,
#  [00378929]에이피엠쇼핑몰,
#  [00384735]코텍,
#  [00303572]아이거넷,
#  [00399250]도원닷컴,
#  [00434951]맥쿼리장기채권형펀드,
#  [00434988]세이리딩스톡혼합형펀드,
#  [00434997]세이고배당장기증권저축펀드,
#  [00435002]세이고배당주식형펀드,
#  [00435136]맥쿼리IMM슈페리어채권형사모펀드,
#  [00434331]KTB채권형펀드,
#  [00434359]글로벌퍼펙트혼합형펀드,
#  [00434377]삼성중소형알짜주식형뮤추얼펀드,
#  [00434386]KTB장기증권저축펀드1호,
#  [00434438]KTB에이플러스2호혼합형사모펀드,
#  [00286877]비비앤씨,
#  [00436913]대청산업,
#  [00436366]링컨아카데미,
#  [00369116]디아이컨설팅,
#  [00261577]네띠앙,
#  [00434261]크레디피아제삼십팔차유동화전문유한회사,
#  [00222204]산내들축산,
#  [00436153]거장주택건설,
#  [00437967]쓰리디컴넷,
#  [00435914]대양식품,
#  [00435899]태강건설,
#  [00437383]국제전자정밀,
#  [00351825]투어토털닷컴,
#  [00415008]드림미르,
#  [00436968]부광,
#  [00436852]도원건설,
#  [00436393]현우유통,
#  [00261142]엘리온정보기술,
#  [00439406]지석공영,
#  [00421559]에쓰엠제일차자산유동화전문,
#  [00387060]뉴밀레니엄코람제이차유동화전문유한회사,
#  [00434067]렉스상사,
#  [00450409]엔트,
#  [00430283]협성염공,
#  [00370875]디비엔지니어링,
#  [00230878]삼양텍스,
#  [00409867]얄개네트워크,
#  [00385044]지트랜코리아,
#  [00173245]삼보,
#  [00423812]국민카드제구차유동화전문유한회사,
#  [00425661]국민카드제십일차유동화전문유한회사,
#  [00273907]하나로제4차유동화전문회사,
#  [00283533]와이디세이프유동화전문유한회사,
#  [00445966]늘푸른마을,
#  [00450001]이노크래프트,
#  [00449555]강동종합유선방송,
#  [00452443]한림하우징,
#  [00366836]아이티엠,
#  [00444426]코산아이엔티,
#  [00261665]미광핸드백,
#  [00363945]신정건설,
#  [00414832]코이넬,
#  [00383161]서울제일차유동화전문유한회사,
#  [00163026]이지닷컴,
#  [00414610]지에프엠에스,
#  [00415947]언아더월드,
#  [00304605]로티스,
#  [00414957]이파워게이트,
#  [00416229]윤진개발,
#  [00120243]레이디,
#  [00411659]미트마트옥션,
#  [00198314]아싸,
#  [00413408]웰리치개발,
#  [00163965]항도종합금융,
#  [00416724]아이텍테크널러지,
#  [00218502]중앙제약,
#  [00364175]우남산업,
#  [00417422]윈로지스뉴톤보레알,
#  [00417981]한국지방재정공제회,
#  [00307046]창도건설,
#  [00237349]부국개발,
#  [00414364]유경엔지니어링,
#  [00417626]한국레이저영상,
#  [00418050]씨에이블,
#  [00415567]아토메가,
#  [00247984]도레미농산,
#  [00371494]다인개발,
#  [00358147]호만기업,
#  [00150554]갑을개발,
#  [00305279]에버그린유동화전문유한회사,
#  [00386326]맥트랜스인터내셔날,
#  [00100753]거봉,
#  [00204703]대산레미콘,
#  [00417316]크레딧크리에이터이천이유동화전문유한회사,
#  [00207959]신택,
#  [00411109]바티오테크,
#  [00417477]하우징그룹우신,
#  [00414054]통인물류정보통신,
#  [00303730]에스지에스컨테크,
#  [00362229]광호,
#  [00317326]펜다하우스,
#  [00418430]프르덴셜어슈어런스컴퍼니리티니드,
#  [00434447]KTB장기증권저축펀드,
#  [00434526]KTB하이스타혼합형펀드,
#  [00433721]한국광학초자,
#  [00434207]광평개발,
#  [00434562]KTB밸류스타혼합형펀드,
#  [00434571]KTB글로벌스타주식형펀드,
#  [00434580]KTB프라임4호주식형사모펀드,
#  [00434599]KTB베스트바이혼합형펀드,
#  [00434605]KTB하이턴펀드,
#  [00434614]마이다스A등급채권혼합형펀드,
#  [00435145]맥쿼리아이엠엠프라임3혼합형사모펀드,
#  [00396448]피이아이코리아사모엠엔에이일호펀드,
#  [00430937]아담소프트,
#  [00423034]피델리티펀드,
#  [00435127]유리크레디트채권혼합형펀드,
#  [00434544]KTB프리미엄찬스혼합형펀드,
#  [00434553]KTB에이스찬스혼합형펀드,
#  [00432050]다린정보,
#  [00344843]기보캐피탈제일차유동화전문유한회사,
#  [00371908]엘에스에프프로퍼티투유동화전문,
#  [00339090]온디지털테크,
#  [00337986]캐피탈그룹인터내셔널인코포레이티드,
#  [00206136]세림아이텍,
#  [00440411]코스유동화전문유한회사,
#  [00422309]뉴밀레니엄하나유동화전문유한회사,
#  [00439257]동양정보통신M&A,
#  [00439284]하이페리온제삼차유동화전문유한회사,
#  [00439424]코머스에셋,
#  [00435011]경동실업,
#  [00428525]에스티엑스제이차유동화전문유한회사,
#  [00427128]오일뱅크제삼차유동화전문유한회사,
#  [00428677]케이지브이제일차유동화전문유한회사,
#  [00436560]인성어패럴,
#  [00440697]소프티안,
#  [00327387]소모페스트,
#  [00437611]젤존항공여행사,
#  [00321064]바이오엔비텍,
#  [00362557]세원반도체,
#  [00224105]두원그린피아,
#  [00447654]미도핸드백,
#  [00453169]대영테크,
#  [00371388]아이비젠,
#  [00144340]한화포리마,
#  [00437204]신케이에스유동화전문유한회사,
#  [00443302]프라임유동화전문유한회사,
#  [00436463]우영제일차유동화전문유한회사,
#  [00452692]한컴리눅스,
#  [00441739]두산건설제육유동화전문유한회사,
#  [00441669]산은부동산제팔차유동화전문유한회사,
#  [00436940]오토피아제칠차유동화전문유한회사,
#  [00436959]외환카드제팔차유동화전문유한회사,
#  [00427526]삼성신한아하론일차유동화전문유한회사,
#  [00264705]현대유동화전문유한회사,
#  [00387714]칼제일차유동화전문유한회사,
#  [00300946]백두건설,
#  [00402086]리엔텍,
#  [00452461]대양건설,
#  [00100948]건양콘크리트,
#  [00365572]맥스미디어,
#  [00400486]루넷,
#  [00417909]충일아스콘,
#  [00153816]태양연와공업,
#  [00414586]제동,
#  [00187637]농협축산유통,
#  [00415035]동서D&S,
#  [00235864]에스앤제이,
#  [00416043]창영물산,
#  [00174280]태화건설,
#  [00417352]동방코리아,
#  [00238223]영텍스타일,
#  [00234740]고려소재개발,
#  [00417565]아이앤알코리아기업구조조정전문,
#  [00192958]건륭실업,
#  [00387459]충주공용버스터미널,
#  [00415761]푸른도시개발,
#  [00404011]로고스이넷,
#  [00168553]대광종합건설,
#  [00309804]굿윌씨앤아이,
#  [00408600]아라아이디시,
#  [00418731]디엠아이디,
#  [00363121]웅보개발,
#  [00230577]광복산업개발,
#  [00295671]리빙티브이,
#  [00418759]산은부동산제삼차유동화전문유한회사,
#  [00211448]신라,
#  [00406170]글로만,
#  [00301060]서림개스실린더,
#  [00242350]파인에셋홀딩스,
#  [00134352]세일,
#  [00420569]한일밀라노.존,
#  [00422141]첼린저이차유동화전문유한회사,
#  [00422178]휴민텍,
#  [00419891]템플턴스트래티직이머징마켓츠펀드엘디씨,
#  [00419907]신한파이낸스,
#  [00310989]코오롱모터스,
#  [00420976]큐마트솔루션,
#  [00421072]나은미디어,
#  [00423706]BystronicLaserAG,
#  [00384425]코브코유동화전문유한회사,
#  [00350297]칼스버그에이에스,
#  [00421124]아이엠씨마케팅,
#  [00434632]글로벌채권프리미엄혼합형펀드,
#  [00434650]KTB밸류코스닥혼합형펀드,
#  [00434669]KTB밸류코리아혼합형사모펀드,
#  [00429658]스톰홀딩스,
#  [00118831]아이넥스테크놀로지,
#  [00205483]세종토건,
#  [00434492]부평유선방송,
#  [00435622]KTB온누리혼합형펀드,
#  [00435631]미래에셋인디펜던스오십혼합형펀드,
#  [00435695]KTB드림코스닥혼합형펀드,
#  [00434845]유리리버스국채인덱스혼합형펀드,
#  [00434854]유리비너스채권형사모펀드,
#  [00434863]세이프알파헷지채권혼합형펀드,
#  [00435020]알파롱숏30혼합형사모펀드,
#  [00435154]맥쿼리IMM마켓플러스채권혼합형펀드,
#  [00435163]맥쿼리아이엠엠플러스알파혼합형펀드,
#  [00435172]맥쿼리아이엠엠베스트채권혼합형펀드,
#  [00431583]코스모스유동화전문유한회사,
#  [00429199]우리쉽모기지제일차유동화전문유한회사,
#  [00428905]산은부동산제육차유동화전문유한회사,
#  [00433110]디더블유씨삼차유동화전문유한회사,
#  [00430849]파이오니어유동화전문유한회사,
#  [00432032]오토피아제육차유동화전문유한회사,
#  [00393432]로쿠스개발,
#  [00442853]신하나로제일차유동화전문유한회사,
#  [00309442]지유,
#  [00130055]새한종합금융,
#  [00441429]금성건설,
#  [00301219]현대케이블,
#  [00298890]씨앤티스,
#  [00441942]경도산업개발,
#  [00407355]현진,
#  [00240699]코코스,
#  [00403818]카포넷,
#  [00360993]에이스텔레콤,
#  [00365633]씨투커뮤니케이션,
#  [00452896]지청이엔씨,
#  [00413790]이토스템,
#  [00452294]대한종합건설,
#  [00192374]대원주택,
#  ...]

# %%
all = dart_fss.api.filings.get_corp_code()
all[0]

df = pd.DataFrame(all)
df
# Out:
#        corp_code          corp_name  \
# 0       00434003                 다코
# 1       00430964              굿앤엘에스
# 2       00388953  크레디피아제이십오차유동화전문회사
# 3       00179984             연방건설산업
# 4       00420143     브룩스피알아이오토메이션잉크
# ...          ...                ...
# 112898  01913987      지엠에프십사호선박투자회사
# 112899  01913996      지엠에프십오호선박투자회사
# 112900  01914001      지엠에프십육호선박투자회사
# 112901  01913127              디지탈테크
# 112902  01913491                피유란
#
#                                             corp_eng_name stock_code  \
# 0                                        Daco corporation       None
# 1                                      Good & LS Co.,Ltd.       None
# 2       Credipia 25th Asset Securitization Specialty L...       None
# 3                                                youn bao       None
# 4                             BROOKS-PRI Automation, Inc.       None
# ...                                                   ...        ...
# 112898                  GMF NO.14 Ship Investment Company       None
# 112899                  GMF NO.15 Ship Investment Company       None
# 112900                  GMF NO.16 Ship Investment Company       None
# 112901                               digitalltek co.,ltd.       None
# 112902                                   PYURAN Co., Ltd.       None
#
#        modify_date
# 0         20170630
# 1         20170630
# 2         20170630
# 3         20170630
# 4         20170630
# ...            ...
# 112898    20250423
# 112899    20250423
# 112900    20250423
# 112901    20250423
# 112902    20250423
#
# [112903 rows x 5 columns]

# %%
corp_list_save = save_pickle(df, 'corp_list.pkl')
account_rows_save = save_pickle(account_rows, 'account_rows.pkl')
# Out:
# ✅ 저장 완료 → corp_list.pkl
# ⠙ Downloading CORPCODE.zip✅ 저장 완료 → account_rows.pkl

# %%
load_pickle(corp_list_save)
load_pickle(account_rows_save)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-3198654922.py in <cell line: 0>()
# ----> 1 load_pickle(corp_list_save)
#       2 load_pickle(account_rows_save)
#
# NameError: name 'corp_list_save' is not defined

# %%
# 전체 기업중 상장사만 선택
all_listed_corps = df[df['stock_code'].notnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stock_code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-19-233298211.py in <cell line: 0>()
#       1 # 전체 기업중 상장사만 선택
# ----> 2 all_listed_corps = df[df['stock_code'].notnull()]
#       3 all_listed_corps.head(500)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'stock_code'

# %%
all_listed_corps.head(500)
# Out:
#       corp_code         corp_name                              corp_eng_name  \
# 1946   00260985              한빛네트                            HanbitNet, Inc.
# 1958   00264529              엔플렉스                                 Nplex,Inc.
# 1959   00358545            동서정보기술  Dong Seo Information Technology Co., Ltd.
# 2699   00231567             애드모바일                                       None
# 3771   00359614               리더컴                        LEADER COMM.Co.,Ltd
# ...         ...               ...                                        ...
# 28227  00318839  미래에셋새천년코리아벤처펀드일호  MIRAEASSETNEWMILLENNIUMKOREAVENTURE FUND1
# 28292  00130897              하나은행                                  Hana Bank
# 28321  00183260            에이스하이텍                     Ace Hightech Co., Ltd.
# 28406  00246347             태창파로스                      TAECHANG PHAROS.,Ltd.
# 28455  00599230        평산차업집단유한공사                PING SHAN TEA GROUP LIMITED
#
#       stock_code modify_date
# 1946      036720    20170630
# 1958      040130    20170630
# 1959      055000    20170630
# 2699      032600    20170630
# 3771      056140    20170630
# ...          ...         ...
# 28227     042950    20170630
# 28292     002860    20170630
# 28321     071930    20170630
# 28406     039850    20170630
# 28455     950010    20170630
#
# [500 rows x 5 columns]

# %%
# 상장사 corp_code 추출
corp_codes = [all_listed_corps.iloc[i]["corp_code"] for i in range(len(all_listed_corps))]
print(corp_codes)
# Out:
# ['00260985', '00264529', '00358545', '00231567', '00359614', '00153551', '00344746', '00261188', '00268020', '00269287', '00475286', '00250775', '00114321', '00191108', '00167378', '00225210', '00223346', '00174129', '00114826', '00173333', '00687599', '00256292', '00271431', '00154727', '00246189', '00154204', '00152631', '00358095', '00510215', '00347619', '00372013', '00353735', '00186540', '00128759', '00535588', '00264981', '00231521', '00159908', '00259493', '00359641', '00161639', '00211271', '00388272', '00264796', '00134909', '00236368', '00684547', '00251385', '00262682', '00234555', '00507257', '00417963', '00543523', '00300566', '00299376', '00112068', '00257194', '00477372', '00465410', '00331760', '00200761', '00268297', '00161301', '00237260', '00297970', '00107358', '00267474', '00134051', '00596066', '00347363', '00150226', '00152914', '00158839', '00159281', '00210537', '00240370', '00247887', '00268358', '00316488', '00264130', '00540304', '00617299', '00262275', '00200798', '00335924', '00111591', '00189343', '00252588', '00267997', '00299686', '00463050', '00238913', '00107446', '00114303', '00318617', '00267775', '00394574', '00110176', '00136554', '00144562', '00370547', '00242439', '00134060', '00392600', '00259855', '00385451', '00258944', '00798530', '00451268', '00336570', '00363325', '00148188', '00508566', '00133928', '00540784', '00298252', '00264556', '00581000', '00359094', '00686970', '00255309', '00362380', '00244862', '00297165', '00105767', '00173397', '00259606', '00178471', '00331733', '00104892', '00647917', '00597764', '00355821', '00329677', '00244871', '00246383', '00345499', '00348140', '00215107', '00560991', '00265263', '00142564', '00198572', '00642648', '00537443', '00113173', '00441872', '00480844', '00262044', '00101442', '00295875', '00441298', '00263885', '00475532', '00130204', '00128731', '00325981', '00540021', '00362089', '00228916', '00114215', '00109648', '00261212', '00348007', '00275808', '00375579', '00197324', '00339063', '00538497', '00225140', '00101947', '00287724', '00347840', '00504357', '00269339', '00634959', '00267094', '00142698', '00350057', '00721981', '00248691', '00335562', '00369675', '00265078', '00267809', '00314000', '00355292', '00386557', '00548865', '00221320', '00124054', '00301486', '00311298', '00348557', '00265342', '00156734', '00208693', '00128953', '00428792', '00148744', '00518873', '00300779', '00397766', '00174305', '00320807', '00106492', '00592583', '00275260', '00183914', '00481676', '00104971', '00269773', '00334767', '00453752', '00140919', '00255840', '00133034', '00161028', '00174475', '00251482', '00824659', '00259536', '00505198', '00679730', '00803504', '00350118', '00352295', '00240088', '00560025', '00140380', '00101275', '00797674', '00244589', '00802028', '00371519', '00126593', '00220181', '00254009', '00505541', '00240398', '00828309', '00349468', '00808262', '00252393', '00229818', '00154189', '00680161', '00102645', '00844884', '00592592', '00268437', '00798284', '00164195', '00264811', '00676380', '00543231', '00122436', '00505189', '00271413', '00245296', '00480905', '00890333', '00510534', '00150855', '00173634', '00830377', '00224567', '00582054', '00125929', '00502793', '00505550', '00104704', '00361035', '00630111', '00264802', '00399773', '00257529', '00804114', '00416706', '00173324', '00121729', '00808226', '00162577', '00812229', '00351153', '00126885', '00264741', '00266989', '00260693', '00267951', '00804983', '00502474', '00579379', '00264857', '00375302', '00264848', '00251190', '00694003', '00505170', '00259439', '00207436', '00408585', '00115038', '00288653', '00303837', '00330017', '00264769', '00308948', '00321222', '00361202', '00450728', '00535773', '00152950', '00296069', '00521956', '00360540', '00593519', '00194372', '00154693', '00106650', '00368791', '00220552', '00294371', '00353683', '00252375', '00260903', '00261461', '00265218', '00471989', '00306986', '00356644', '00305695', '00257051', '00 ...

# %%
# corp_name 기준 '카카오' 단일재무제표 전체 컬럼 확인
corp_code = all_listed_corps[all_listed_corps['corp_name'] == '삼성전자'].iloc[0,0]
data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2021', '11011', 'OFS')

pd.DataFrame(data['list'])
# Out:
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20220308000798      11011      2021  00126380     BS  재무상태표
# 1    20220308000798      11011      2021  00126380     BS  재무상태표
# 2    20220308000798      11011      2021  00126380     BS  재무상태표
# 3    20220308000798      11011      2021  00126380     BS  재무상태표
# 4    20220308000798      11011      2021  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 111  20220308000798      11011      2021  00126380    SCE  자본변동표
# 112  20220308000798      11011      2021  00126380    SCE  자본변동표
# 113  20220308000798      11011      2021  00126380    SCE  자본변동표
# 114  20220308000798      11011      2021  00126380    SCE  자본변동표
# 115  20220308000798      11011      2021  00126380    SCE  자본변동표
#
#                                             account_id account_nm  \
# 0                              ifrs-full_CurrentAssets       유동자산
# 1                     ifrs-full_CashAndCashEquivalents   현금및현금성자산
# 2    dart_ShortTermDepositsNotClassifiedAsCashEquiv...     단기금융상품
# 3                        dart_ShortTermTradeReceivable       매출채권
# 4                       dart_ShortTermOtherReceivables        미수금
# ..                                                 ...        ...
# 111                                   ifrs-full_Equity       기말자본
# 112                                   ifrs-full_Equity       기말자본
# 113                                   ifrs-full_Equity       기말자본
# 114                                   ifrs-full_Equity       기말자본
# 115                                   ifrs-full_Equity       기말자본
#
#                  account_detail thstrm_nm    thstrm_amount frmtrm_nm  \
# 0                             -    제 53 기   73553416000000    제 52 기
# 1                             -    제 53 기    3918872000000    제 52 기
# 2                             -    제 53 기   15000576000000    제 52 기
# 3                             -    제 53 기   33088247000000    제 52 기
# 4                             -    제 53 기    1832488000000    제 52 기
# ..                          ...       ...              ...       ...
# 111         자본 [member]|주식발행초과금    제 53 기    4403893000000    제 52 기
# 112    자본 [member]|자본금 [member]    제 53 기     897514000000    제 52 기
# 113          자본 [member]|기타자본항목    제 53 기    -882010000000    제 52 기
# 114             별도재무제표 [member]    제 53 기  193193732000000    제 52 기
# 115  자본 [member]|이익잉여금 [member]    제 53 기  188774335000000    제 52 기
#
#        frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord currency  \
# 0     73798549000000       제 51 기   72659080000000   1      KRW
# 1       989045000000       제 51 기    2081917000000   2      KRW
# 2     29101284000000       제 51 기   26501392000000   3      KRW
# 3     24736740000000       제 51 기   26255438000000   4      KRW
# 4      1898583000000       제 51 기    2406795000000   5      KRW
# ..               ...          ...              ...  ..      ...
# 111    4403893000000       제 51 기    4403893000000   6      KRW
# 112     897514000000       제 51 기     897514000000   6      KRW
# 113    -268785000000       제 51 기     280514000000   6      KRW
# 114  183316724000000       제 51 기  177870247000000   6      KRW
# 115  178284102000000       제 51 기  172288326000000   6      KRW
#
#     thstrm_add_amount
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 111               NaN
# 112               NaN
# 113               NaN
# 114               NaN
# 115               NaN
#
# [116 rows x 18 columns]

# %%
data
# Out:
# {'status': '000',
#  'message': '정상',
#  'list': [{'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentAssets',
#    'account_nm': '유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '2412771566068',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1782401903517',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '1014030589420',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CashAndCashEquivalents',
#    'account_nm': '현금및현금성자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1478675780625',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1356884920831',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '647121328668',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermDepositsNotClassifiedAsCashEquivalents',
#    'account_nm': '단기금융상품',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '255435276220',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '65497423866',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '15590476220',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentFinancialAssetsAtFairValueThroughProfitOrLossDesignatedUponInitialRecognition',
#    'account_nm': '당기손익-공정가치 측정 금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '267800193700',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_CurrentDerivativeAsset',
#    'account_nm': '파생상품자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '94116000',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '894102000',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ShortTermTradeReceivable',
#    'account_nm': '매출채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '152198881960',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '120477615976',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '94991384637',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_CurrentFinanceLeaseReceivables',
#    'account_nm': '단기금융리스채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '9774298496',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '5035417806',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '2306220898',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_OtherCurrentFinancialAssets',
#    'account_nm': '기타유동금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '190568812718',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '203640384338',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '222441824890',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Inventories',
#    'account_nm': '재고자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '20845094490',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '3989088538',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherCurrentAssets',
#    'account_nm': '기타유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '37473227859',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '30772024700',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '26696163569',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentAssets',
#    'account_nm': '비유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '7616731297777',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '5563104581267',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '5470330027390',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermDepositsNotClassifiedAsCashEquivalents',
#    'account_nm': '장기금융상품',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '10000000000',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '10000000000',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '10000000000',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentFinancialAssetsAtFairValueThroughProfitOrLossDesignatedUponInitialRecognition',
#    'account_nm': '당기손익-공정가치 측정 금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '86639621580',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '59626742668',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '45399230609',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome',
#    'account_nm': '기타포괄손익-공정가치 측정 금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '789169945252',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '536800669867',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '330410964621',
#    'ord': '14',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_InvestmentsInSubsidiariesJointVenturesAndAssociates',
#    'account_nm': '종속기업, 관계기업 및 공동기업투자',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '3547758071680',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '2393425547162',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '2212393967698',
#    'ord': '15',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_NoncurrentFinanceLeaseReceivable',
#    'account_nm': '장기금융리스채권',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '38839409746',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '16851382170',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '10458904481',
#    'ord': '16',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_OtherNoncurrentFinancialAssets',
#    'account_nm': '기타비유동금융자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '55198740862',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '22896754400',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '18147937101',
#    'ord': '17',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_PropertyPlantAndEquipment',
#    'account_nm': '유형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '312554741802',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '272117410599',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '248311163551',
#    'ord': '18',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherIntangibleAssetsGross',
#    'account_nm': '무형자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1573635018208',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '2106230935896',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '2458574528458',
#    'ord': '19',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_RightofuseAssets',
#    'account_nm': '사용권자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '836401029626',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '126831631071',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '101981843072',
#    'ord': '20',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_InvestmentProperty',
#    'account_nm': '투자부동산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '306535716457',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '21579864561',
#    'ord': '21',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_InvestedAssetForPostemploymentBenefit',
#    'account_nm': '퇴직연금운용자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '20496117057',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '7696112461',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '5811141742',
#    'ord': '22',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_DeferredTaxAssets',
#    'account_nm': '이연법인세자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '10072340841',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '23',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherNonCurrentAssets',
#    'account_nm': '기타비유동자산',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '29430544666',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '10627394973',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '7260481496',
#    'ord': '24',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Assets',
#    'account_nm': '자산총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '10029502863845',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '7345506484784',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '6484360616810',
#    'ord': '25',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentLiabilities',
#    'account_nm': '유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '2318866853953',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1436640086599',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '1382600790605',
#    'ord': '27',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_TradeAndOtherCurrentPayables',
#    'account_nm': '매입채무 및 기타채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '493501498065',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1035669215930',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '686649998624',
#    'ord': '28',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_ShorttermBorrowings',
#    'account_nm': '단기차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '342179346067',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '57987200330',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '429063108400',
#    'ord': '29',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_OtherCurrentFinancialLiabilities',
#    'account_nm': '기타유동금융부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '4995114000',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '2051114005',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '1805783602',
#    'ord': '30',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_PaymentsOfIncomeTaxesPayable',
#    'account_nm': '미지급법인세',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '55517525169',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '49822909677',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '38118923770',
#    'ord': '31',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_CurrentDerivativeLiabilities',
#    'account_nm': '파생상품부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '5871210000',
#    'ord': '32',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_CurrentLeaseLiabilities',
#    'account_nm': '단기리스부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '101724244061',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '37613103713',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '31494694565',
#    'ord': '33',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherCurrentLiabilities',
#    'account_nm': '기타유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1320949126591',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '253496542944',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '189597071644',
#    'ord': '34',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentLiabilities',
#    'account_nm': '비유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1171298508308',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '594790709830',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '252280099228',
#    'ord': '35',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermTradeAndOtherNonCurrentPayables',
#    'account_nm': '비유동매입채무 및 기타채무',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '16682848737',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '4590817184',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '2786603839',
#    'ord': '36',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_LongTermBorrowingsGross',
#    'account_nm': '장기차입금',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '321761482011',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '39965367209',
#    'ord': '37',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentProvisions',
#    'account_nm': '비유동충당부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '40680511420',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '10333202884',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '9461197949',
#    'ord': '38',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentLeaseLiabilities',
#    'account_nm': '장기리스부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1076109126631',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '121899752206',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '88642651025',
#    'ord': '39',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_NoncurrentProvisionsForEmployeeBenefits',
#    'account_nm': '기타장기종업원급여부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '35656381133',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '27047368083',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '25384985949',
#    'ord': '40',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_DeferredTaxLiabilities',
#    'account_nm': '이연법인세부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '104555660306',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '85219885413',
#    'ord': '41',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherNonCurrentLiabilities',
#    'account_nm': '기타비유동부채',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '2169640387',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '4602427156',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '819407844',
#    'ord': '42',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Liabilities',
#    'account_nm': '부채총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '3490165362261',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '2031430796429',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '1634880889833',
#    'ord': '43',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_IssuedCapital',
#    'account_nm': '자본금',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '44640599000',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '44300999000',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '43161318000',
#    'ord': '45',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_CapitalSurplus',
#    'account_nm': '자본잉여금',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '5489187456902',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '4986863484685',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '4462249633278',
#    'ord': '46',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_ElementsOfOtherStockholdersEquity',
#    'account_nm': '자본조정',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '77070391402',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '18616904707',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '41292768578',
#    'ord': '47',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'dart_OtherComprehensiveIncomeLossAccumulatedAmount',
#    'account_nm': '기타포괄손익누계액',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '240486698823',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '66513984520',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-2897079352',
#    'ord': '48',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_RetainedEarnings',
#    'account_nm': '이익잉여금(결손금)',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '687952355457',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '197780315443',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '305673086473',
#    'ord': '49',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '자본총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '6539337501584',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '5314075688355',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '4849479726977',
#    'ord': '50',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'BS',
#    'sj_nm': '재무상태표',
#    'account_id': 'ifrs-full_EquityAndLiabilities',
#    'account_nm': '부채와자본총계',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '10029502863845',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '7345506484784',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '6484360616810',
#    'ord': '51',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_GrossProfit',
#    'account_nm': '영업수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '2132915884804',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1779194942006',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '1513471072651',
#    'ord': '0',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_TotalSellingGeneralAdministrativeExpenses',
#    'account_nm': '영업비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1735549587803',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1482538724778',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '1319589780765',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OperatingIncomeLoss',
#    'account_nm': '영업이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '397366297001',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '296656217228',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '193881291886',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherGains',
#    'account_nm': '기타수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '60791399075',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '47553946693',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '10964194874',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherLosses',
#    'account_nm': '기타비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '35843565649',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '407293501258',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '438146371624',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_FinanceIncome',
#    'account_nm': '금융수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '228541511610',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '60093421952',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '54137000050',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_InterestIncomeFinanceIncome',
#    'account_nm': '이자수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '12820189678',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '8039964049',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '13962237560',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherFinancialIncome',
#    'account_nm': '기타금융수익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '215721321932',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '52053457903',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '40174762490',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_FinanceCosts',
#    'account_nm': '금융비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '46265725913',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '24019110306',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '18938613896',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '종속기업및관계기업투자 손상차손',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '34556414532',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '11491134087',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '34709203884',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ProfitLossBeforeTax',
#    'account_nm': '법인세비용차감전순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '570033501592',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-38500159778',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-232811702594',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_IncomeTaxExpenseContinuingOperations',
#    'account_nm': '법인세비용',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '66909879125',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '81916954774',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '28548425837',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ProfitLoss',
#    'account_nm': '당기순이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '503123622467',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-120417114552',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-261360128431',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_OtherComprehensiveIncome',
#    'account_nm': '기타포괄손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '173922941450',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '92348028682',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '3529024838',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeThatWillNotBeReclassifiedToProfitOrLossNetOfTax',
#    'account_nm': '후속적으로 당기손익으로 재분류될 수 없는 항목',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '173922941450',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '92348028682',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '3529024838',
#    'ord': '14',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'dart_OtherComprehensiveIncomeNetOfTaxGainsLossesOnRemeasurementsOfDefinedBenefitPlans',
#    'account_nm': '순확정급여부채의 재측정요소',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '-611152463',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1310593402',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-2246614769',
#    'ord': '15',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_OtherComprehensiveIncomeNetOfTaxGainsLossesFromInvestmentsInEquityInstruments',
#    'account_nm': '기타포괄손익-공정가치 측정 지분상품 평가손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '174534093913',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '91037435280',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '5775639607',
#    'ord': '16',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_ComprehensiveIncome',
#    'account_nm': '총포괄손익',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '677046563917',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-28069085870',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-257831103593',
#    'ord': '17',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_BasicEarningsLossPerShare',
#    'account_nm': '기본주당이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1164',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-284',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-656',
#    'ord': '19',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CIS',
#    'sj_nm': '포괄손익계산서',
#    'account_id': 'ifrs-full_DilutedEarningsLossPerShare',
#    'account_nm': '희석주당이익(손실)',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '1139',
#    'thstrm_add_amount': '',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-284',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-656',
#    'ord': '20',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInOperatingActivities',
#    'account_nm': '영업활동현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '815195396669',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '630615476829',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '533407163996',
#    'ord': '0',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_AdjustmentsForAssetsLiabilitiesOfOperatingActivities',
#    'account_nm': '영업으로부터 창출된 현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '826997250703',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '637883120009',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '596445478232',
#    'ord': '1',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_InterestReceivedClassifiedAsOperatingActivities',
#    'account_nm': '이자의 수취',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '10606981155',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '7225636252',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '20554211898',
#    'ord': '2',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_InterestPaidClassifiedAsOperatingActivities',
#    'account_nm': '이자의 지급',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '4713125863',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '4455052346',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '5021279146',
#    'ord': '3',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_DividendsReceivedClassifiedAsOperatingActivities',
#    'account_nm': '배당금 수입',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '77188550197',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '14375077409',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '9173049378',
#    'ord': '4',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_IncomeTaxesPaidRefundClassifiedAsOperatingActivities',
#    'account_nm': '법인세 납부',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '94884259523',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '24413304495',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '87744296366',
#    'ord': '5',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsFromUsedInInvestingActivities',
#    'account_nm': '투자활동현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '-698732086975',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-257556214225',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-341790656106',
#    'ord': '6',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfShortTermFinancialInstruments',
#    'account_nm': '단기금융상품의 증감',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '190062147646',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-49906947646',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '586121896559',
#    'ord': '7',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_PurchaseOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#    'account_nm': '유형자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '102780765323',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '110398002161',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '74994780712',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_ProceedsFromSalesOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
#    'account_nm': '유형자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '2129304945',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '12881217861',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '7503439586',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_PurchaseOfIntangibleAssetsClassifiedAsInvestingActivities',
#    'account_nm': '무형자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '9904727261',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '39229275903',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '20361579712',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_ProceedsFromSalesOfIntangibleAssetsClassifiedAsInvestingActivities',
#    'account_nm': '무형자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '274940433',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1075092376',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '104226134',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfInvestmentsInSubsidiariesJointVenturesAndAssociates',
#    'account_nm': '종속기업 및 관계기업투자의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '531968544864',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '54970649409',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '445482936042',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfInvestmentsInSubsidiariesJointVenturesAndAssociates',
#    'account_nm': '종속기업 및 관계기업투자의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '16620697087',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '50905790036',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '2440471890',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfFairValueFinancialAsset',
#    'account_nm': '당기손익-공정가치측정금융자산의취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '278019659344',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '5539425000',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '245407550000',
#    'ord': '14',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfFairValueFinancialAsset',
#    'account_nm': '당기손익-공정가치 측정 금융자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '101124858938',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '1000000000',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '241011864599',
#    'ord': '15',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfNonCurrentAvailableForSaleFinancialAssets',
#    'account_nm': '기타포괄손익-공정가치 측정 금융자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '18931466422',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '157043718950',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '325578599080',
#    'ord': '16',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfNonCurrentAvailableForSaleFinancialAssets',
#    'account_nm': '기타포괄손익-공정가치 측정 금융자산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '47110000',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '63813311416',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '17',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfOtherCurrentFinancialAssets',
#    'account_nm': '기타유동금융자산의 감소',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '500000000',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '18',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfOtherNonCurrentFinancialAssets',
#    'account_nm': '기타비유동금융자산의 취득',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '54874049735',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '4893643180',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '2096991701',
#    'ord': '19',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfOtherNonCurrentFinancialAssets',
#    'account_nm': '기타비유동금융자산의 증감',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '2644825881',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '648726797',
#    'ord': '20',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_ProceedsFromSalesOfInvestmentProperty',
#    'account_nm': '투자부동산의 처분',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '31414700000',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '21',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashAdvancesAndLoansMadeToOtherPartiesClassifiedAsInvestingActivities',
#    'account_nm': '장기선급금의 증가',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '20746913136',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '2702079205',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '22',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'dart_PurchaseOfGoodwill',
#    'account_nm': '사업양수로 인한 현금유출',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '5150000000',
#    'ord': '23',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '합병으로 인한 순현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '76234980061',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '3392589659',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '24',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': 'ifrs-full_CashFlowsUsedInObtainingControlOfSubsidiariesOrOtherBusinessesClassifiedAsInvestingActivities',
#    'account_nm': '종속기업 취득 및 연결범위변동으로 인한 순현금흐름',
#    'account_detail': '-',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '60548844424',
#    'ord': '25',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'CF',
#    'sj_nm': '현금흐름표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '사업분할로 인한 순현금흐름',
# ...
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_CompoundFinancialInstrumentIssue',
#    'account_nm': '전환권 대가',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_CompoundFinancialInstrumentIssue',
#    'account_nm': '전환권 대가',
#    'account_detail': '자본 [member]|자본잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_CompoundFinancialInstrumentIssue',
#    'account_nm': '전환권 대가',
#    'account_detail': '자본 [member]|자본조정',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '8',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '현금배당',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '12901809600',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '10412621288',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '10052593687',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '현금배당',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '현금배당',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '12901809600',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '10412621288',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '10052593687',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '현금배당',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '현금배당',
#    'account_detail': '자본 [member]|자본잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_DividendsPaid',
#    'account_nm': '현금배당',
#    'account_detail': '자본 [member]|자본조정',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '9',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-1359078093',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|자본잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '-1359078093',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_IncreaseDecreaseThroughBusinessCombinations',
#    'account_nm': '사업결합',
#    'account_detail': '자본 [member]|자본조정',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '10',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식 거래로 인한 증감',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식 거래로 인한 증감',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식 거래로 인한 증감',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식 거래로 인한 증감',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식 거래로 인한 증감',
#    'account_detail': '자본 [member]|자본잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'dart_TreasuryShareTransactions',
#    'account_nm': '자기주식 거래로 인한 증감',
#    'account_detail': '자본 [member]|자본조정',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '11',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '합병 및 분할로 인한 자본의 변동',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '243754233250',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '합병 및 분할로 인한 자본의 변동',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '합병 및 분할로 인한 자본의 변동',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '합병 및 분할로 인한 자본의 변동',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '0',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '합병 및 분할로 인한 자본의 변동',
#    'account_detail': '자본 [member]|자본잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '238551643106',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': '-표준계정코드 미사용-',
#    'account_nm': '합병 및 분할로 인한 자본의 변동',
#    'account_detail': '자본 [member]|자본조정',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '5202590144',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '0',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '0',
#    'ord': '12',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|자본잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '5489187456902',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '4986863484685',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '4462249633278',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|자본조정',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '77070391402',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '18616904707',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '41292768578',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '별도재무제표 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '6539337501584',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '5314075688355',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '4849479726977',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|기타포괄손익누계액 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '240486698823',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '66513984520',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '-2897079352',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|이익잉여금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '687952355457',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '197780315443',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '305673086473',
#    'ord': '13',
#    'currency': 'KRW'},
#   {'rcept_no': '20240320000386',
#    'reprt_code': '11011',
#    'bsns_year': '2021',
#    'corp_code': '00258801',
#    'sj_div': 'SCE',
#    'sj_nm': '자본변동표',
#    'account_id': 'ifrs-full_Equity',
#    'account_nm': '기말자본',
#    'account_detail': '자본 [member]|자본금 [member]',
#    'thstrm_nm': '제 27 기',
#    'thstrm_amount': '44640599000',
#    'frmtrm_nm': '제 26 기',
#    'frmtrm_amount': '44300999000',
#    'bfefrmtrm_nm': '제 25 기',
#    'bfefrmtrm_amount': '43161318000',
#    'ord': '13',
#    'currency': 'KRW'}]}

# %%
# 피클 임시저장용

import pickle

def save_pickle(obj, path: str):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"✅ 저장 완료 → {path}")

def load_pickle(path: str):
    with open(path, "rb") as f:
        obj = pickle.load(f)
    print(f"✅ 로드 완료 ← {path}")
    return obj

# %%
import itertools
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

def embed_and_compare(
    account_list: list[str],
    model_name: str = "snunlp/KR-SBERT-V40K-klueNLI-augSTS",
    top_k: int = 50
) -> pd.DataFrame:
    """
    account_list: 계정명 리스트
    model_name: 불러올 SentenceTransformer 모델
    top_k: 유사도 상위 N개 페어 반환
    """
    print(f"🔍 모델 로딩: {model_name}")
    model = SentenceTransformer(model_name)

    print(f"🔢 임베딩 중... ({len(account_list)}개)")
    embs = model.encode(account_list, convert_to_numpy=True)

    print(f"📐 유사도 계산...")
    sim = cosine_similarity(embs)
    pairs = [
        (account_list[i], account_list[j], sim[i, j])
        for i, j in itertools.combinations(range(len(account_list)), 2)
    ]
    top_pairs = sorted(pairs, key=lambda x: x[2], reverse=True)[:top_k]
    df = pd.DataFrame(top_pairs, columns=["Account1", "Account2", "Similarity"])
    return df

# %%
def match_with_targets(
    all_accounts: list[str],
    target_keywords: list[str],
    model_name: str = "snunlp/KR-SBERT-V40K-klueNLI-augSTS",
    top_k: int = 5
) -> pd.DataFrame:
    print("📦 모델 로딩 중...")
    model = SentenceTransformer(model_name)

    print("🔢 전체 계정명 임베딩 중...")
    all_embs = model.encode(all_accounts, convert_to_numpy=True)

    print("🎯 타겟 키워드 임베딩 중...")
    target_embs = model.encode(target_keywords, convert_to_numpy=True)

    results = []

    for i, keyword in enumerate(target_keywords):
        sims = cosine_similarity([target_embs[i]], all_embs)[0]
        top_indices = sims.argsort()[::-1][:top_k]

        for idx in top_indices:
            results.append((keyword, all_accounts[idx], sims[idx]))

    df_result = pd.DataFrame(results, columns=["TargetKeyword", "MatchedAccount", "Similarity"])
    return df_result.sort_values(by=["TargetKeyword", "Similarity"], ascending=[True, False])

# %%
corp_code_series = all_listed_corps.loc[all_listed_corps['corp_name'] == corp_name, 'corp_code']

if corp_code_series.empty:
    print(f"⚠️ {corp_name} - corp_code 없음")
    continue

corp_code = corp_code_series.values[0]
# Out:
#   File "/tmp/ipython-input-51-401734089.py", line 5
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop

# %%
top_500 = all_listed_corps.head(500)
corp_code_dict = dict(zip(top_500['corp_name'], top_500['corp_code']))

# %%
account_rows = []

for corp_name in top_500['corp_name']:
    corp_code = corp_code_dict.get(corp_name)

    if not corp_code:
        print(f"⚠️ {corp_name} - corp_code 없음")
        continue

    found = False  # 성공 여부 플래그

    for fs_div in ['OFS', 'CFS']:  # 별도 → 연결 순으로 시도
        for reprt_code in ['11011', '11014', '11012']:  # 사업→반기→1분기
            try:

                data = dart_fss.api.finance.fnltt_singl_acnt_all(
                    corp_code=corp_code,
                    bsns_year='2021',
                    reprt_code=reprt_code,
                    fs_div=fs_div
                )

                df = pd.DataFrame(data['list'])

                if not df.empty:
                    df['corp_name'] = corp_name
                    account_rows.append(df[['corp_name', 'account_id', 'account_nm']])
                    print(f"✅ {corp_name} ({corp_code}) - {len(df)} rows from {fs_div}/{reprt_code}")
                    found = True
                    break  # 성공 시 더 이상 반복 안 함

            except Exception as e:
                continue  # 다음 조합 시도

        if found:
            break  # 성공했으면 fs_div 루프도 종료

    if not found:
        print(f"❌ {corp_name} ({corp_code}) - 데이터 없음 (모든 조합 실패)")

# %%
account_rows = []

for corp_name in top_500['corp_name']:
    corp_code = corp_code_dict.get(corp_name)

    if not corp_code:
        print(f"⚠️ {corp_name} - corp_code 없음")
        continue

    try:
        data = dart_fss.api.finance.fnltt_singl_acnt_all(
            corp_code=corp_code,
            bsns_year='2021',
            reprt_code='11011',  # 사업보고서
            fs_div='OFS'         # 별도재무제표
        )
        df = pd.DataFrame(data['list'])

        if not df.empty:
            df['corp_name'] = corp_name
            # ✅ 필요한 컬럼만 선택해서 리스트에 저장
            account_rows.append(df[['corp_name', 'account_id', 'account_nm']])
            print(f"✅ {corp_name} ({corp_code}) - {len(df)} rows")

        else:
            print(f"⚠️ {corp_name} ({corp_code}) - 데이터 없음")

    except Exception as e:
        print(f"❌ {corp_name} ({corp_code}) - 에러 발생: {e}")
# Out:
# ❌ 한빛네트 (00260985) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엔플렉스 (00264529) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동서정보기술 (00358545) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 애드모바일 (00231567) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 리더컴 (00359614) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 허메스홀딩스 (00153551) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 유티엑스 (00344746) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 글로포스트 (00261188) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 쏠라엔텍 (00268020) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 보홍 (00269287) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동북아1호선박투자회사 (00475286) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에듀아크 (00250775) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 데코 (00114321) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엘앤씨피 (00191108) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 희훈디앤지 (00167378) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 퓨쳐인포넷 (00225210) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 쓰리디넷 (00223346) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제일저축은행 (00174129) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제일창업투자 (00114826) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 현대DSF (00173333) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 네프로아이티 (00687599) - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 자강 (00256292) - 에러 발생: 조회된 데이타가 없습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-34-1786425025.py in <cell line: 0>()
#       9
#      10     try:
# ---> 11         data = dart_fss.api.finance.fnltt_singl_acnt_all(
#      12             corp_code=corp_code,
#      13             bsns_year='2021',
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/finance/fnltt_singl_acnt_all.py in fnltt_singl_acnt_all(corp_code, bsns_year, reprt_code, fs_div, api_key)
#      33     path = '/api/fnlttSinglAcntAll.json'
#      34
# ---> 35     return api_request(
#      36         api_key=api_key,
#      37         path=path,
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/helper.py in api_request(path, corp_code, bsns_year, reprt_code, bgn_de, end_de, fs_div, sj_div, api_key)
#     110
#     111     # Request Data
# --> 112     resp = request.get(url=url, payload=payload)
#     113
#     114     # Convert Response to json
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/utils/request.py in get(self, url, payload, referer, stream, timeout)
#     171             Response
#     172         """
# --> 173         return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#     174
#     175     def post(self, url: str,
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/utils/request.py in request(self, url, method, payload, referer, stream, timeout)
#     141         req = requests.Request(method, url=url, params=payload, headers=headers)
#     142         prepped = self.s.prepare_request(req)
# --> 143         resp = self.s.send(prepped, stream=stream, timeout=timeout)
#     144         if self.delay is not None:
#     145             sleep(self.delay)
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
corp_code
# Out:
# '00686970'

# %%
name = all_listed_corps.head(500)['corp_name']
name
# Out:
# 1946                 한빛네트
# 1958                 엔플렉스
# 1959               동서정보기술
# 2699                애드모바일
# 3771                  리더컴
#                ...
# 28227    미래에셋새천년코리아벤처펀드일호
# 28292                하나은행
# 28321              에이스하이텍
# 28406               태창파로스
# 28455          평산차업집단유한공사
# Name: corp_name, Length: 500, dtype: object

# %%
name = all_listed_corps.head(500)['corp_name'].tolist()
name
# Out:
# ['한빛네트',
#  '엔플렉스',
#  '동서정보기술',
#  '애드모바일',
#  '리더컴',
#  '허메스홀딩스',
#  '유티엑스',
#  '글로포스트',
#  '쏠라엔텍',
#  '보홍',
#  '동북아1호선박투자회사',
#  '에듀아크',
#  '데코',
#  '엘앤씨피',
#  '희훈디앤지',
#  '퓨쳐인포넷',
#  '쓰리디넷',
#  '제일저축은행',
#  '제일창업투자',
#  '현대DSF',
#  '네프로아이티',
#  '자강',
#  '케이엠에스',
#  '에버리소스',
#  '제이에스',
#  '태창기업',
#  '에이치비이에너지',
#  '코어비트',
#  '동북아8호선박투자회사',
#  '한국통신데이타',
#  '케너텍',
#  '다휘',
#  '코오롱아이넷',
#  '캠브리지코오롱',
#  '네오세미테크',
#  '디에이치패션',
#  '핸디소프트',
#  '케이엠에이치',
#  '씨엘엘씨디',
#  '현대푸드시스템',
#  '메리츠종합금융',
#  '제넥셀세인',
#  '쓰리디월드',
#  '스톰이앤에프',
#  '소예',
#  '엠엔에프씨',
#  '하이트맥주',
#  '보광티에스',
#  '아인스엠앤엠',
#  '씨엔씨엔터프라이즈',
#  '아이알디',
#  '바이나믹',
#  '코크렙제7호위탁관리부동산투자회사',
#  '엔빅스',
#  '선팩테크',
#  '마이크로닉스',
#  '블루스톤디앤아이',
#  '신지소프트',
#  '맥쿼리센트럴오피스기업구조조정부동산투자회사',
#  '테스텍',
#  '중앙디자인',
#  '에코페트로시스템',
#  '한림창업투자',
#  '헤쎄나',
#  '미래에셋굿라이프혼합형자녀를위한투자회사10-1',
#  '일공공일안경콘택트',
#  '지앤알',
#  '셀런',
#  '한국베트남15-1유전해외자원개발투자회사',
#  '에이치원바이오',
#  '씨앤중공업',
#  'FnC코오롱',
#  '제너비오믹스',
#  '케드콤',
#  '지엔텍홀딩스',
#  '동부씨엔아이',
#  '아이피에스',
#  '에스브이에이치',
#  '제이콤',
#  '옥션',
#  '네이쳐글로벌',
#  'GB블루오션베트남주식혼합형투자회사1호',
#  '엠씨티티코어',
#  '에이스앤파트너스',
#  '지앤디윈텍',
#  '인터피온반도체',
#  '솔로몬저축은행',
#  '엠트론스토리지테크놀로지',
#  '에스티앤아이',
#  '유퍼트',
#  '엑스로드',
#  '선우중공업',
#  '남양',
#  '엘지데이콤',
#  'LG파워콤',
#  '동산진흥',
#  '티이씨',
#  '한국기술산업',
#  '스타맥스',
#  '유성티에스아이',
#  '네오리소스',
#  '케이알',
#  '씨앤상선',
#  '투미비티',
#  '코아정보시스템',
#  '케이에스리소스',
#  '세계투어',
#  '동양밸류오션기업인수목적',
#  '케이이엔지',
#  '사이버패스',
#  '산양전기',
#  '으뜸상호저축은행',
#  '국제개발',
#  '세신',
#  '골든브릿지더블유엠경매부동산일호투자회사',
#  '엘앤피아너스',
#  '에이스일렉트로닉스',
#  '디앤샵',
#  '더체인지',
#  '다산자기관리부동산투자회사',
#  '써니트렌드',
#  '뉴젠비아이티',
#  '룩소네이트',
#  '현대오토넷',
#  'LG마이크론',
#  '서광건설산업',
#  '플러스프로핏',
#  '한와이어리스',
#  '포휴먼',
#  '알이네트웍스',
#  '케이알제2호개발전문위탁관리부동산투자회사',
#  '미래에셋맵스오퍼튜니티베트남주식혼합형투자회사1호',
#  '씨티엘테크',
#  '이디디컴퍼니',
#  '케이티프리텔',
#  '메카포럼',
#  '에스피코프',
#  '이롬텍',
#  '이앤텍',
#  '맥스브로',
#  '토자이홀딩스',
#  '우방',
#  '동양매직',
#  '코웰이홀딩스유한공사',
#  '아구스',
#  '대한은박지',
#  '인스프리트',
#  '하이럭스',
#  '트리니티',
#  '카라반케이디이',
#  '더존디지털웨어',
#  '디보스',
#  '포네이처',
#  '테이크시스템즈',
#  '폴켐',
#  '유리이에스',
#  '에프아이투어',
#  '모빌탑',
#  '올리브나인',
#  '디패션',
#  '알덱스',
#  '오라바이오틱스',
#  '시노펙스그린테크',
#  '야호커뮤니케이션',
#  '브이케이',
#  '팬택앤큐리텔',
#  '팬텀엔터테인먼트그룹',
#  '삼성수산',
#  '동북아15호선박투자회사',
#  '쌈지',
#  '브이오산업',
#  '코디콤',
#  '제네시스엔알디',
#  '동북아6호선박투자회사',
#  '인네트',
#  '한국월드와이드아시아태평양특별자산1호투자회사',
#  '헤파호프코리아',
#  '휴리프',
#  '하이스마텍',
#  '삼성디지털이미징',
#  '씨제이인터넷',
#  '엠넷미디어',
#  '온미디어',
#  '유니텍전자',
#  '위더스기술금융',
#  '클라스타',
#  '아시아미디어홀딩스',
#  '아이스테이션',
#  '동북아21호선박투자회사',
#  '에이스디지텍',
#  '부산저축은행',
#  '에피밸리',
#  '오페스',
#  '액티투오',
#  '에이치에스씨홀딩스',
#  '한국고덴시',
#  '나리지*온',
#  '프로비타',
#  '제로원인터랙티브',
#  '제일화재해상보험',
#  '동북아9호선박투자회사',
#  '굿이엠지',
#  '아이드림',
#  '조인에너지',
#  '태광이엔시',
#  '렉스엘이앤지',
#  '코리아퍼시픽05호선박투자회사',
#  '엑큐리스',
#  '우경',
#  '세미텍',
#  '그린손해보험',
#  '대양글로벌',
#  '엔하이테크',
#  '제너시스템즈',
#  '엘트온',
#  '태산엘시디',
#  '성원건설',
#  '대우송도개발',
#  '현대금속',
#  '트라이써클',
#  '아이비케이에스스마트에스엠이기업인수목적1호',
#  '네스테크',
#  '동북아5호선박투자회사',
#  '파브코',
#  '우리기업인수목적1호',
#  '뉴젠아이씨티',
#  '인젠',
#  '지앤에스티',
#  '코크렙제8호위탁관리부동산투자회사',
#  '유니온스틸',
#  '경남모직',
#  '대우증권그린코리아기업인수목적회사',
#  '지노시스템',
#  '한국투자신성장1호기업인수목적회사',
#  '휴먼텍코리아',
#  '에스에스씨피',
#  '평산',
#  '지디코프',
#  '아시아퍼시픽2호선박투자회사',
#  '무한투자',
#  '동부티에스블랙펄기업인수목적',
#  '블루젬디앤씨',
#  '부국퓨쳐스타즈기업인수목적',
#  '예당컴퍼니',
#  '터보테크',
#  '케이비물산',
#  '연합과기공고유한공사',
#  '글로스텍',
#  '중국고섬공고유한공사',
#  '코리아퍼시픽06호선박투자회사',
#  '나노트로닉스',
#  '미래에셋제1호기업인수목적',
#  '에이원마이크로',
#  '에이프로테크놀로지',
#  '모린스',
#  '디지텍시스템스',
#  '배명금속',
#  '동북아4호선박투자회사',
#  '사라콤',
#  '폴리플러스',
#  '영찬테크',
#  '케이비부국제1호개발전문위탁관리부동산투자회사',
#  '아시아퍼시픽8호선박투자회사',
#  '진흥저축은행',
#  '에듀언스',
#  '성융광전투자유한공사',
#  '샤인시스템',
#  '씨모텍',
#  '에스컴',
#  '아시아퍼시픽1호선박투자회사',
#  '아시아퍼시픽3호선박투자회사',
#  '한국저축은행',
#  '미리넷',
#  '3노드디지탈그룹유한공사',
#  '유일엔시스',
#  '케이피케미칼',
#  '이루넷',
#  '대신증권그로쓰알파기업인수목적',
#  '유에이블',
#  '경윤하이드로에너지',
#  '롯데미도파',
#  '한화에스브이명장제1호기업인수목적',
#  '셀텍',
#  '에스비아이앤솔로몬드림기업인수목적',
#  '위다스',
#  '에스와이코퍼레이션',
#  '어울림네트웍스',
#  '에이디모터스',
#  '평안물산',
#  '아큐텍',
#  '히든챔피언제1호기업인수목적',
#  '동북아2호선박투자회사',
#  '금강제강',
#  '아라온테크',
#  '우리금융지주',
#  '대국',
#  '글로웍스',
#  '중국식품포장유한공사',
#  '동북아3호선박투자회사',
#  '지아이바이오',
#  '알에스넷',
#  '나이스메탈',
#  '하나IB증권',
#  '퓨쳐비젼',
#  '이레전자산업',
#  '레이더스컴퍼니',
#  '포이보스',
#  '미디어코프',
#  '케이디세코',
#  '이노블루',
#  '도움',
#  '엑스씨이',
#  '코오롱유화',
#  '세라온홀딩스',
#  '현대경매부동산일호투자회사',
#  '우수씨엔에스',
#  '동북아31호선박투자회사',
#  '후야인포넷',
#  '이레아이엔씨',
#  '카스코',
#  '모델라인',
#  '청람디지탈',
#  '한텔',
#  '코스모스피엘씨',
#  '나노하이텍',
#  '쓰리소프트',
#  '트라이콤',
#  '케이엔에스홀딩스',
#  '지비에스',
#  '피더블유제네틱스',
#  '엠텍반도체',
#  '세니콘',
#  '유씨아이콜스',
#  '코크렙제3호CR리츠',
#  '아이티센네트웍스',
#  '리얼티코리아제1호기업구조조정부동산투자',
#  'BHK',
#  '포넷',
#  '맥슨텔레콤',
#  '엔토리노',
#  '두림티앤씨',
#  '동북아27호선박투자회사',
#  '동북아28호선박투자회사',
#  '동북아30호선박투자회사',
#  '동북아29호선박투자회사',
#  '현주컴퓨터',
#  'LG석유화학',
#  '오브제',
#  '휴닉스',
#  '세이프아시아',
#  '코크렙제1호기업구조조정부동산투자회사',
#  '위너스인프라인',
#  'AP우주통신',
#  '조이토토',
#  '한도하이테크',
#  '에너윈',
#  '유레스메리츠제1호',
#  '교보메리츠퍼스트기업구조조정부동산투자회사',
#  '굿앤리치부동산공경매투자회사1호',
#  '한국합섬',
#  '굿앤리치부동산공경매투자회사2호',
#  '디에스피이엔티',
#  '시큐어소프트',
#  '동부일렉트로닉스',
#  '고려시멘트',
#  '베스트플로우',
#  '쿨투',
#  '우영',
#  '모빌링크텔레콤',
#  '극동제혁',
#  '한마음상호저축은행',
#  '그로웰전자',
#  '부흥',
#  '퍼시픽글라스',
#  '아이인프라',
#  '씨크롭',
#  '외환신용카드',
#  '삼화기연',
#  '대흥멀티미디어통신',
#  '텔슨정보통신',
#  '비이티',
#  '코오롱인터내셔널',
#  '엔써커뮤니티',
#  '써미트테크놀로지',
#  '코리아이앤디',
#  '트래픽아이티에스',
#  '호성',
#  '넥스텔',
#  '쓰리알',
#  '그로웰텔레콤',
#  '서통',
#  '테크메이트',
#  '한아시스템',
#  '엔에스아이',
#  '케이티씨텔레콤',
#  '신한SIT',
#  '스마텔',
#  '동방라이텍',
#  '아이텍스필',
#  '이수세라믹',
#  '코크렙제2호기업구조조정부동산투자회사',
#  '영풍산업',
#  '모닷텔',
#  '광덕물산',
#  '동원증권',
#  '우주통신',
#  '기라정보통신',
#  '텔슨전자',
#  '하이콤정보통신',
#  '미래에셋굿라이프혼합형자녀를위한펀드5-1',
#  '한메엔에스',
#  '이지클럽',
#  '넷컴스토리지',
#  '모디아',
#  '성진산업',
#  '아이엠아이티',
#  '맥시스템',
#  '슈마일렉트론',
#  '센추리',
#  '베네데스하이텍',
#  '에스오케이',
#  '세원텔레콤',
#  '한강구조조정기금',
#  '케이엔티',
#  '대아리드선',
#  '국민은행',
#  '월드텔레콤',
#  '업필',
#  '화림모드',
#  '대아건설',
#  '창민테크',
#  '씨제이엔터테인먼트',
#  '대백쇼핑',
#  '지니웍스',
#  '신광기업',
#  '유진종합개발',
#  '휘튼',
#  '엠바이엔',
#  '두산건설',
#  '대호',
#  '한신코퍼레이션',
#  '금강화섬',
#  '우리증권',
#  '피코소프트',
#  '바이오시스',
#  '윌텍정보통신',
#  '삼도물산',
#  '현대멀티캡',
#  '씨아이에스',
#  '코리아퍼시픽01호선박투자회사',
#  '코리아퍼시픽02호선박투자회사',
#  '신양오라컴디스플레이',
#  '미래에셋증권',
#  '이룸지엔지',
#  '에스와이이노베이션',
#  '코리아퍼시픽03호선박투자회사',
#  '코리아퍼시픽04호선박투자회사',
#  '유아이에너지',
#  '아시아퍼시픽14호선박투자회사',
#  '아시아퍼시픽13호선박투자회사',
#  '아시아퍼시픽10호선박투자회사',
#  '현대에이블기업인수목적1호',
#  '아시아퍼시픽11호선박투자회사',
#  '아시아퍼시픽12호선박투자회사',
#  '호반산업',
#  '실리콘화일',
#  '비엔씨컴퍼니',
#  '동북아11호선박투자회사',
#  '동북아14호선박투자회사',
#  '디아이디',
#  '부산방직공업',
#  '현대에이치씨엔동작방송',
#  '플렉스컴',
#  '웹솔루스',
#  '마이스코',
#  '솔트웍스',
#  '현대페인트',
#  '한진해운',
#  '글라소울',
#  '팬택자산관리',
#  '케이엔씨글로벌',
#  '아이디에스',
#  '훈영',
#  '한솔아트원제지',
#  '엠제이비',
#  '바다로3호선박투자회사',
#  '아이팩토리',
#  '거북선5호선박투자회사',
#  '거북선6호선박투자회사',
#  '삼성물산',
#  '피엘에이',
#  '닉스테크',
#  '아시아퍼시픽9호선박투자회사',
#  '거북선4호선박투자회사',
#  '중앙건설',
#  '미래에셋새천년코리아벤처펀드일호',
#  '하나은행',
#  '에이스하이텍',
#  '태창파로스',
#  '평산차업집단유한공사']

# %%
corp_name_list = ['한빛네트',
 '엔플렉스',
 '동서정보기술',
 '애드모바일',
 '리더컴',
 '허메스홀딩스',
 '유티엑스',
 '글로포스트',
 '쏠라엔텍',
 '보홍',
 '동북아1호선박투자회사',
 '에듀아크',
 '데코',
 '엘앤씨피',
 '희훈디앤지',
 '퓨쳐인포넷',
 '쓰리디넷',
 '제일저축은행',
 '제일창업투자',
 '현대DSF',
 '네프로아이티',
 '자강',
 '케이엠에스',
 '에버리소스',
 '제이에스',
 '태창기업',
 '에이치비이에너지',
 '코어비트',
 '동북아8호선박투자회사',
 '한국통신데이타',
 '케너텍',
 '다휘',
 '코오롱아이넷',
 '캠브리지코오롱',
 '네오세미테크',
 '디에이치패션',
 '핸디소프트',
 '케이엠에이치',
 '씨엘엘씨디',
 '현대푸드시스템',
 '메리츠종합금융',
 '제넥셀세인',
 '쓰리디월드',
 '스톰이앤에프',
 '소예',
 '엠엔에프씨',
 '하이트맥주',
 '보광티에스',
 '아인스엠앤엠',
 '씨엔씨엔터프라이즈',
 '아이알디',
 '바이나믹',
 '코크렙제7호위탁관리부동산투자회사',
 '엔빅스',
 '선팩테크',
 '마이크로닉스',
 '블루스톤디앤아이',
 '신지소프트',
 '맥쿼리센트럴오피스기업구조조정부동산투자회사',
 '테스텍',
 '중앙디자인',
 '에코페트로시스템',
 '한림창업투자',
 '헤쎄나',
 '미래에셋굿라이프혼합형자녀를위한투자회사10-1',
 '일공공일안경콘택트',
 '지앤알',
 '셀런',
 '한국베트남15-1유전해외자원개발투자회사',
 '에이치원바이오',
 '씨앤중공업',
 'FnC코오롱',
 '제너비오믹스',
 '케드콤',
 '지엔텍홀딩스',
 '동부씨엔아이',
 '아이피에스',
 '에스브이에이치',
 '제이콤',
 '옥션',
 '네이쳐글로벌',
 'GB블루오션베트남주식혼합형투자회사1호',
 '엠씨티티코어',
 '에이스앤파트너스',
 '지앤디윈텍',
 '인터피온반도체',
 '솔로몬저축은행',
 '엠트론스토리지테크놀로지',
 '에스티앤아이',
 '유퍼트',
 '엑스로드',
 '선우중공업',
 '남양',
 '엘지데이콤',
 'LG파워콤',
 '동산진흥',
 '티이씨',
 '한국기술산업',
 '스타맥스',
 '유성티에스아이',
 '네오리소스',
 '케이알',
 '씨앤상선',
 '투미비티',
 '코아정보시스템',
 '케이에스리소스',
 '세계투어',
 '동양밸류오션기업인수목적',
 '케이이엔지',
 '사이버패스',
 '산양전기',
 '으뜸상호저축은행',
 '국제개발',
 '세신',
 '골든브릿지더블유엠경매부동산일호투자회사',
 '엘앤피아너스',
 '에이스일렉트로닉스',
 '디앤샵',
 '더체인지',
 '다산자기관리부동산투자회사',
 '써니트렌드',
 '뉴젠비아이티',
 '룩소네이트',
 '현대오토넷',
 'LG마이크론',
 '서광건설산업',
 '플러스프로핏',
 '한와이어리스',
 '포휴먼',
 '알이네트웍스',
 '케이알제2호개발전문위탁관리부동산투자회사',
 '미래에셋맵스오퍼튜니티베트남주식혼합형투자회사1호',
 '씨티엘테크',
 '이디디컴퍼니',
 '케이티프리텔',
 '메카포럼',
 '에스피코프',
 '이롬텍',
 '이앤텍',
 '맥스브로',
 '토자이홀딩스',
 '우방',
 '동양매직',
 '코웰이홀딩스유한공사',
 '아구스',
 '대한은박지',
 '인스프리트',
 '하이럭스',
 '트리니티',
 '카라반케이디이',
 '더존디지털웨어',
 '디보스',
 '포네이처',
 '테이크시스템즈',
 '폴켐',
 '유리이에스',
 '에프아이투어',
 '모빌탑',
 '올리브나인',
 '디패션',
 '알덱스',
 '오라바이오틱스',
 '시노펙스그린테크',
 '야호커뮤니케이션',
 '브이케이',
 '팬택앤큐리텔',
 '팬텀엔터테인먼트그룹',
 '삼성수산',
 '동북아15호선박투자회사',
 '쌈지',
 '브이오산업',
 '코디콤',
 '제네시스엔알디',
 '동북아6호선박투자회사',
 '인네트',
 '한국월드와이드아시아태평양특별자산1호투자회사',
 '헤파호프코리아',
 '휴리프',
 '하이스마텍',
 '삼성디지털이미징',
 '씨제이인터넷',
 '엠넷미디어',
 '온미디어',
 '유니텍전자',
 '위더스기술금융',
 '클라스타',
 '아시아미디어홀딩스',
 '아이스테이션',
 '동북아21호선박투자회사',
 '에이스디지텍',
 '부산저축은행',
 '에피밸리',
 '오페스',
 '액티투오',
 '에이치에스씨홀딩스',
 '한국고덴시',
 '나리지*온',
 '프로비타',
 '제로원인터랙티브',
 '제일화재해상보험',
 '동북아9호선박투자회사',
 '굿이엠지',
 '아이드림',
 '조인에너지',
 '태광이엔시',
 '렉스엘이앤지',
 '코리아퍼시픽05호선박투자회사',
 '엑큐리스',
 '우경',
 '세미텍',
 '그린손해보험',
 '대양글로벌',
 '엔하이테크',
 '제너시스템즈',
 '엘트온',
 '태산엘시디',
 '성원건설',
 '대우송도개발',
 '현대금속',
 '트라이써클',
 '아이비케이에스스마트에스엠이기업인수목적1호',
 '네스테크',
 '동북아5호선박투자회사',
 '파브코',
 '우리기업인수목적1호',
 '뉴젠아이씨티',
 '인젠',
 '지앤에스티',
 '코크렙제8호위탁관리부동산투자회사',
 '유니온스틸',
 '경남모직',
 '대우증권그린코리아기업인수목적회사',
 '지노시스템',
 '한국투자신성장1호기업인수목적회사',
 '휴먼텍코리아',
 '에스에스씨피',
 '평산',
 '지디코프',
 '아시아퍼시픽2호선박투자회사',
 '무한투자',
 '동부티에스블랙펄기업인수목적',
 '블루젬디앤씨',
 '부국퓨쳐스타즈기업인수목적',
 '예당컴퍼니',
 '터보테크',
 '케이비물산',
 '연합과기공고유한공사',
 '글로스텍',
 '중국고섬공고유한공사',
 '코리아퍼시픽06호선박투자회사',
 '나노트로닉스',
 '미래에셋제1호기업인수목적',
 '에이원마이크로',
 '에이프로테크놀로지',
 '모린스',
 '디지텍시스템스',
 '배명금속',
 '동북아4호선박투자회사',
 '사라콤',
 '폴리플러스',
 '영찬테크',
 '케이비부국제1호개발전문위탁관리부동산투자회사',
 '아시아퍼시픽8호선박투자회사',
 '진흥저축은행',
 '에듀언스',
 '성융광전투자유한공사',
 '샤인시스템',
 '씨모텍',
 '에스컴',
 '아시아퍼시픽1호선박투자회사',
 '아시아퍼시픽3호선박투자회사',
 '한국저축은행',
 '미리넷',
 '3노드디지탈그룹유한공사',
 '유일엔시스',
 '케이피케미칼',
 '이루넷',
 '대신증권그로쓰알파기업인수목적',
 '유에이블',
 '경윤하이드로에너지',
 '롯데미도파',
 '한화에스브이명장제1호기업인수목적',
 '셀텍',
 '에스비아이앤솔로몬드림기업인수목적',
 '위다스',
 '에스와이코퍼레이션',
 '어울림네트웍스',
 '에이디모터스',
 '평안물산',
 '아큐텍',
 '히든챔피언제1호기업인수목적',
 '동북아2호선박투자회사',
 '금강제강',
 '아라온테크',
 '우리금융지주',
 '대국',
 '글로웍스',
 '중국식품포장유한공사',
 '동북아3호선박투자회사',
 '지아이바이오',
 '알에스넷',
 '나이스메탈',
 '하나IB증권',
 '퓨쳐비젼',
 '이레전자산업',
 '레이더스컴퍼니',
 '포이보스',
 '미디어코프',
 '케이디세코',
 '이노블루',
 '도움',
 '엑스씨이',
 '코오롱유화',
 '세라온홀딩스',
 '현대경매부동산일호투자회사',
 '우수씨엔에스',
 '동북아31호선박투자회사',
 '후야인포넷',
 '이레아이엔씨',
 '카스코',
 '모델라인',
 '청람디지탈',
 '한텔',
 '코스모스피엘씨',
 '나노하이텍',
 '쓰리소프트',
 '트라이콤',
 '케이엔에스홀딩스',
 '지비에스',
 '피더블유제네틱스',
 '엠텍반도체',
 '세니콘',
 '유씨아이콜스',
 '코크렙제3호CR리츠',
 '아이티센네트웍스',
 '리얼티코리아제1호기업구조조정부동산투자',
 'BHK',
 '포넷',
 '맥슨텔레콤',
 '엔토리노',
 '두림티앤씨',
 '동북아27호선박투자회사',
 '동북아28호선박투자회사',
 '동북아30호선박투자회사',
 '동북아29호선박투자회사',
 '현주컴퓨터',
 'LG석유화학',
 '오브제',
 '휴닉스',
 '세이프아시아',
 '코크렙제1호기업구조조정부동산투자회사',
 '위너스인프라인',
 'AP우주통신',
 '조이토토',
 '한도하이테크',
 '에너윈',
 '유레스메리츠제1호',
 '교보메리츠퍼스트기업구조조정부동산투자회사',
 '굿앤리치부동산공경매투자회사1호',
 '한국합섬',
 '굿앤리치부동산공경매투자회사2호',
 '디에스피이엔티',
 '시큐어소프트',
 '동부일렉트로닉스',
 '고려시멘트',
 '베스트플로우',
 '쿨투',
 '우영',
 '모빌링크텔레콤',
 '극동제혁',
 '한마음상호저축은행',
 '그로웰전자',
 '부흥',
 '퍼시픽글라스',
 '아이인프라',
 '씨크롭',
 '외환신용카드',
 '삼화기연',
 '대흥멀티미디어통신',
 '텔슨정보통신',
 '비이티',
 '코오롱인터내셔널',
 '엔써커뮤니티',
 '써미트테크놀로지',
 '코리아이앤디',
 '트래픽아이티에스',
 '호성',
 '넥스텔',
 '쓰리알',
 '그로웰텔레콤',
 '서통',
 '테크메이트',
 '한아시스템',
 '엔에스아이',
 '케이티씨텔레콤',
 '신한SIT',
 '스마텔',
 '동방라이텍',
 '아이텍스필',
 '이수세라믹',
 '코크렙제2호기업구조조정부동산투자회사',
 '영풍산업',
 '모닷텔',
 '광덕물산',
 '동원증권',
 '우주통신',
 '기라정보통신',
 '텔슨전자',
 '하이콤정보통신',
 '미래에셋굿라이프혼합형자녀를위한펀드5-1',
 '한메엔에스',
 '이지클럽',
 '넷컴스토리지',
 '모디아',
 '성진산업',
 '아이엠아이티',
 '맥시스템',
 '슈마일렉트론',
 '센추리',
 '베네데스하이텍',
 '에스오케이',
 '세원텔레콤',
 '한강구조조정기금',
 '케이엔티',
 '대아리드선',
 '국민은행',
 '월드텔레콤',
 '업필',
 '화림모드',
 '대아건설',
 '창민테크',
 '씨제이엔터테인먼트',
 '대백쇼핑',
 '지니웍스',
 '신광기업',
 '유진종합개발',
 '휘튼',
 '엠바이엔',
 '두산건설',
 '대호',
 '한신코퍼레이션',
 '금강화섬',
 '우리증권',
 '피코소프트',
 '바이오시스',
 '윌텍정보통신',
 '삼도물산',
 '현대멀티캡',
 '씨아이에스',
 '코리아퍼시픽01호선박투자회사',
 '코리아퍼시픽02호선박투자회사',
 '신양오라컴디스플레이',
 '미래에셋증권',
 '이룸지엔지',
 '에스와이이노베이션',
 '코리아퍼시픽03호선박투자회사',
 '코리아퍼시픽04호선박투자회사',
 '유아이에너지',
 '아시아퍼시픽14호선박투자회사',
 '아시아퍼시픽13호선박투자회사',
 '아시아퍼시픽10호선박투자회사',
 '현대에이블기업인수목적1호',
 '아시아퍼시픽11호선박투자회사',
 '아시아퍼시픽12호선박투자회사',
 '호반산업',
 '실리콘화일',
 '비엔씨컴퍼니',
 '동북아11호선박투자회사',
 '동북아14호선박투자회사',
 '디아이디',
 '부산방직공업',
 '현대에이치씨엔동작방송',
 '플렉스컴',
 '웹솔루스',
 '마이스코',
 '솔트웍스',
 '현대페인트',
 '한진해운',
 '글라소울',
 '팬택자산관리',
 '케이엔씨글로벌',
 '아이디에스',
 '훈영',
 '한솔아트원제지',
 '엠제이비',
 '바다로3호선박투자회사',
 '아이팩토리',
 '거북선5호선박투자회사',
 '거북선6호선박투자회사',
 '삼성물산',
 '피엘에이',
 '닉스테크',
 '아시아퍼시픽9호선박투자회사',
 '거북선4호선박투자회사',
 '중앙건설',
 '미래에셋새천년코리아벤처펀드일호',
 '하나은행',
 '에이스하이텍',
 '태창파로스',
 '평산차업집단유한공사']

# %%
data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2020', '11011', 'OFS')
df = pd.DataFrame(data['list'])
# Out:
# ---------------------------------------------------------------------------
# NoDataReceived                            Traceback (most recent call last)
# /tmp/ipython-input-71-3696646637.py in <cell line: 0>()
# ----> 1 data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2020', '11011', 'OFS')
#       2 df = pd.DataFrame(data['list'])
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/finance/fnltt_singl_acnt_all.py in fnltt_singl_acnt_all(corp_code, bsns_year, reprt_code, fs_div, api_key)
#      33     path = '/api/fnlttSinglAcntAll.json'
#      34
# ---> 35     return api_request(
#      36         api_key=api_key,
#      37         path=path,
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/helper.py in api_request(path, corp_code, bsns_year, reprt_code, bgn_de, end_de, fs_div, sj_div, api_key)
#     116
#     117     # Status Code Check
# --> 118     check_status(**dataset)
#     119     return dataset
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/errors/checker.py in check_status(**kwargs)
#      45     if err is not None:
#      46         msg = kwargs.get('message')
# ---> 47         raise err(msg)
#
# NoDataReceived: 조회된 데이타가 없습니다.

# %%
corp_name
# Out:
# '유티엑스'

# %%
# corp_name 기준 '카카오' 단일재무제표 전체 컬럼 확인
corp_code = all_listed_corps[all_listed_corps['corp_name'] == '삼성전자'].iloc[0,0]
data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2021', '11011', 'OFS')

pd.DataFrame(data['list'])
# Out:
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20220308000798      11011      2021  00126380     BS  재무상태표
# 1    20220308000798      11011      2021  00126380     BS  재무상태표
# 2    20220308000798      11011      2021  00126380     BS  재무상태표
# 3    20220308000798      11011      2021  00126380     BS  재무상태표
# 4    20220308000798      11011      2021  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 111  20220308000798      11011      2021  00126380    SCE  자본변동표
# 112  20220308000798      11011      2021  00126380    SCE  자본변동표
# 113  20220308000798      11011      2021  00126380    SCE  자본변동표
# 114  20220308000798      11011      2021  00126380    SCE  자본변동표
# 115  20220308000798      11011      2021  00126380    SCE  자본변동표
#
#                                             account_id account_nm  \
# 0                              ifrs-full_CurrentAssets       유동자산
# 1                     ifrs-full_CashAndCashEquivalents   현금및현금성자산
# 2    dart_ShortTermDepositsNotClassifiedAsCashEquiv...     단기금융상품
# 3                        dart_ShortTermTradeReceivable       매출채권
# 4                       dart_ShortTermOtherReceivables        미수금
# ..                                                 ...        ...
# 111                                   ifrs-full_Equity       기말자본
# 112                                   ifrs-full_Equity       기말자본
# 113                                   ifrs-full_Equity       기말자본
# 114                                   ifrs-full_Equity       기말자본
# 115                                   ifrs-full_Equity       기말자본
#
#                  account_detail thstrm_nm    thstrm_amount frmtrm_nm  \
# 0                             -    제 53 기   73553416000000    제 52 기
# 1                             -    제 53 기    3918872000000    제 52 기
# 2                             -    제 53 기   15000576000000    제 52 기
# 3                             -    제 53 기   33088247000000    제 52 기
# 4                             -    제 53 기    1832488000000    제 52 기
# ..                          ...       ...              ...       ...
# 111         자본 [member]|주식발행초과금    제 53 기    4403893000000    제 52 기
# 112    자본 [member]|자본금 [member]    제 53 기     897514000000    제 52 기
# 113          자본 [member]|기타자본항목    제 53 기    -882010000000    제 52 기
# 114             별도재무제표 [member]    제 53 기  193193732000000    제 52 기
# 115  자본 [member]|이익잉여금 [member]    제 53 기  188774335000000    제 52 기
#
#        frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord currency  \
# 0     73798549000000       제 51 기   72659080000000   1      KRW
# 1       989045000000       제 51 기    2081917000000   2      KRW
# 2     29101284000000       제 51 기   26501392000000   3      KRW
# 3     24736740000000       제 51 기   26255438000000   4      KRW
# 4      1898583000000       제 51 기    2406795000000   5      KRW
# ..               ...          ...              ...  ..      ...
# 111    4403893000000       제 51 기    4403893000000   6      KRW
# 112     897514000000       제 51 기     897514000000   6      KRW
# 113    -268785000000       제 51 기     280514000000   6      KRW
# 114  183316724000000       제 51 기  177870247000000   6      KRW
# 115  178284102000000       제 51 기  172288326000000   6      KRW
#
#     thstrm_add_amount
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 111               NaN
# 112               NaN
# 113               NaN
# 114               NaN
# 115               NaN
#
# [116 rows x 18 columns]

# %%
account_rows = []  # 전체 데이터를 담을 리스트

for corp_name in name:
    try:
        corp_code = all_listed_corps[all_listed_corps['corp_name'] == corp_name].iloc[0, 0]
        data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2021', '11011', 'OFS')
        df = pd.DataFrame(data['list'])

        # 계정명(account_nm)과 기업명 추가해서 저장
        if not df.empty:
            df['corp_name'] = corp_name
            account_rows.append(df[['corp_name', 'account_nm']])

        print(f"✅ {corp_name} ({corp_code}) - {len(df)} rows")
    except Exception as e:
        print(f"❌ {corp_name} - 에러 발생: {e}")
# Out:
# ❌ 한빛네트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엔플렉스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동서정보기술 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 애드모바일 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 리더컴 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 허메스홀딩스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 유티엑스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 글로포스트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 쏠라엔텍 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 보홍 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동북아1호선박투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에듀아크 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 데코 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엘앤씨피 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 희훈디앤지 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 퓨쳐인포넷 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 쓰리디넷 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제일저축은행 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제일창업투자 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 현대DSF - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 네프로아이티 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 자강 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 케이엠에스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에버리소스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제이에스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 태창기업 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에이치비이에너지 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 코어비트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동북아8호선박투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 한국통신데이타 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 케너텍 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 다휘 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 코오롱아이넷 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 캠브리지코오롱 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 네오세미테크 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 디에이치패션 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 핸디소프트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 케이엠에이치 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 씨엘엘씨디 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 현대푸드시스템 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 메리츠종합금융 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제넥셀세인 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 쓰리디월드 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 스톰이앤에프 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 소예 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엠엔에프씨 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 하이트맥주 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 보광티에스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 아인스엠앤엠 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 씨엔씨엔터프라이즈 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 아이알디 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 바이나믹 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 코크렙제7호위탁관리부동산투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엔빅스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 선팩테크 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 마이크로닉스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 블루스톤디앤아이 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 신지소프트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 맥쿼리센트럴오피스기업구조조정부동산투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 테스텍 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 중앙디자인 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에코페트로시스템 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 한림창업투자 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 헤쎄나 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 미래에셋굿라이프혼합형자녀를위한투자회사10-1 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 일공공일안경콘택트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 지앤알 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 셀런 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 한국베트남15-1유전해외자원개발투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에이치원바이오 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 씨앤중공업 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ FnC코오롱 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제너비오믹스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 케드콤 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 지엔텍홀딩스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동부씨엔아이 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 아이피에스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에스브이에이치 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 제이콤 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 옥션 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 네이쳐글로벌 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ GB블루오션베트남주식혼합형투자회사1호 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엠씨티티코어 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에이스앤파트너스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 지앤디윈텍 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 인터피온반도체 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 솔로몬저축은행 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엠트론스토리지테크놀로지 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에스티앤아이 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 유퍼트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엑스로드 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 선우중공업 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 남양 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엘지데이콤 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ LG파워콤 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동산진흥 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 티이씨 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 한국기술산업 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 스타맥스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 유성티에스아이 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 네오리소스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 케이알 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 씨앤상선 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 투미비티 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 코아정보시스템 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 케이에스리소스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 세계투어 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동양밸류오션기업인수목적 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 케이이엔지 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 사이버패스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 산양전기 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 으뜸상호저축은행 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 국제개발 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 세신 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 골든브릿지더블유엠경매부동산일호투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엘앤피아너스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에이스일렉트로닉스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 디앤샵 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 더체인지 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 다산자기관리부동산투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 써니트렌드 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 뉴젠비아이티 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 룩소네이트 - 에러 발생: 조회된 데이타가 없습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-76-4210023589.py in <cell line: 0>()
#       4     try:
#       5         corp_code = all_listed_corps[all_listed_corps['corp_name'] == corp_name].iloc[0, 0]
# ----> 6         data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2021', '11011', 'OFS')
#       7         df = pd.DataFrame(data['list'])
#       8
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/finance/fnltt_singl_acnt_all.py in fnltt_singl_acnt_all(corp_code, bsns_year, reprt_code, fs_div, api_key)
#      33     path = '/api/fnlttSinglAcntAll.json'
#      34
# ---> 35     return api_request(
#      36         api_key=api_key,
#      37         path=path,
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/helper.py in api_request(path, corp_code, bsns_year, reprt_code, bgn_de, end_de, fs_div, sj_div, api_key)
#     110
#     111     # Request Data
# --> 112     resp = request.get(url=url, payload=payload)
#     113
#     114     # Convert Response to json
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/utils/request.py in get(self, url, payload, referer, stream, timeout)
#     171             Response
#     172         """
# --> 173         return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#     174
#     175     def post(self, url: str,
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/utils/request.py in request(self, url, method, payload, referer, stream, timeout)
#     143         resp = self.s.send(prepped, stream=stream, timeout=timeout)
#     144         if self.delay is not None:
# --> 145             sleep(self.delay)
#     146         return resp
#     147
#
# KeyboardInterrupt:

# %%
account_rows
# Out:
# []

# %%
account_rows = []  # 전체 데이터를 담을 리스트

for corp_name in all_listed_corps.head(500)['corp_name']:
    try:
        corp_code = all_listed_corps[all_listed_corps['corp_name'] == corp_name].iloc[0, 0]
        data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2021', '11011', 'OFS')
        df = pd.DataFrame(data['list'])

        # 계정명(account_nm)과 기업명 추가해서 저장
        if not df.empty:
            df['corp_name'] = corp_name
            account_rows.append(df[['corp_name', 'account_nm']])

        print(f"✅ {corp_name} ({corp_code}) - {len(df)} rows")
    except Exception as e:
        print(f"❌ {corp_name} - 에러 발생: {e}")
# Out:
# ❌ 한빛네트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 엔플렉스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동서정보기술 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 애드모바일 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 리더컴 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 허메스홀딩스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 유티엑스 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 글로포스트 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 쏠라엔텍 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 보홍 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 동북아1호선박투자회사 - 에러 발생: 조회된 데이타가 없습니다.
# ❌ 에듀아크 - 에러 발생: 조회된 데이타가 없습니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-22-835104693.py in <cell line: 0>()
#       4     try:
#       5         corp_code = all_listed_corps[all_listed_corps['corp_name'] == corp_name].iloc[0, 0]
# ----> 6         data = dart_fss.api.finance.fnltt_singl_acnt_all(corp_code, '2021', '11011', 'OFS')
#       7         df = pd.DataFrame(data['list'])
#       8
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/finance/fnltt_singl_acnt_all.py in fnltt_singl_acnt_all(corp_code, bsns_year, reprt_code, fs_div, api_key)
#      33     path = '/api/fnlttSinglAcntAll.json'
#      34
# ---> 35     return api_request(
#      36         api_key=api_key,
#      37         path=path,
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/api/helper.py in api_request(path, corp_code, bsns_year, reprt_code, bgn_de, end_de, fs_div, sj_div, api_key)
#     110
#     111     # Request Data
# --> 112     resp = request.get(url=url, payload=payload)
#     113
#     114     # Convert Response to json
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/utils/request.py in get(self, url, payload, referer, stream, timeout)
#     171             Response
#     172         """
# --> 173         return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#     174
#     175     def post(self, url: str,
#
# /usr/local/lib/python3.11/dist-packages/dart_fss/utils/request.py in request(self, url, method, payload, referer, stream, timeout)
#     143         resp = self.s.send(prepped, stream=stream, timeout=timeout)
#     144         if self.delay is not None:
# --> 145             sleep(self.delay)
#     146         return resp
#     147
#
# KeyboardInterrupt:

# %%
def normalize_account_name(name: str) -> str:
    name = name.replace(" ", "")
    name = name.replace("-", "")
    name = name.replace("(", "").replace(")", "")
    name = name.lower()
    return name

# %%
# 전체 df 통합
df_all = pd.concat(account_rows, ignore_index=True)
# 중복제거
unique_accounts = df_all['account_nm'].dropna().unique().tolist()
# 전처리로 단순 표기 통합
df_all['normalized'] = df_all['account_nm'].fillna("").apply(normalize_account_name)
print(f"\n총 고유 계정명 수: {len(unique_accounts)}")
print(len(df_all['normalized']))
# Out:
# 총 고유 계정명 수: 1897
# 9813

# %%
# ✅ Step 0: 컬럼 정리
corp_columns = unique_accounts+ [
    ['매출액', '영업이익', '순이익'],
    ['매출', '영업수익', '당기순이익'],
    ['Revenue', 'OperatingProfit', 'NetIncome'],
    ['총매출액', '영업이득', 'Net Income'],
    ['매출총액', '영업이익', '순이익']
]

import re

def clean_name(name):
    # 한글, 알파벳, 숫자만 남기고 나머지 제거
    name = re.sub(r"[^가-힣a-zA-Z0-9]", "", name.lower())
    return name


all_columns = [clean_name(col) for corp in corp_columns for col in corp]
unique_columns = list(set(all_columns))


# ✅ Step 1: 컬럼명 임베딩 (의미 분석)
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
embeddings = model.encode(unique_columns)


# ✅ Step 2: 클러스터링 (비슷한 컬럼끼리 그룹)
clustering = DBSCAN(eps=0.5, min_samples=2, metric='cosine').fit(embeddings)

cluster_map = {}
for idx, label in enumerate(clustering.labels_):
    if label == -1:
        continue
    cluster_map.setdefault(label, []).append(unique_columns[idx])

# ✅ Step 3: 전체 컬럼 빈도 수 세기
column_counter = Counter(all_columns)


# ✅ Step 4: 각 그룹에서 가장 많이 쓰인 컬럼 1개 대표로 뽑기
cluster_representatives = {}
for label, cols in cluster_map.items():
    most_common = sorted(cols, key=lambda x: column_counter[x], reverse=True)[0]
    cluster_representatives[most_common] = cols


# 매핑
account_mapping = {}
for rep, synonyms in cluster_representatives.items():
    for s in synonyms:
        account_mapping[s] = rep


# ✅ Step 5: 대표 컬럼 중에서 사용 빈도 높은 순으로 정렬
rep_counter = {
    rep: sum(column_counter[c] for c in synonyms)
    for rep, synonyms in cluster_representatives.items()
}


top_features = sorted(rep_counter.items(), key=lambda x: x[1], reverse=True)[:50]


# ✅ 결과 보기
import json
for feature, freq in top_features:
    print(f"[{feature}] (빈도: {freq}) → 유사 컬럼들: {json.dumps(cluster_representatives[feature], ensure_ascii=False)}")
# Out:
# ⠦ Loading Companies in OpenDART[] (빈도: 21721) → 유사 컬럼들: ["", "령", "매", "매출총액", "연", "변", "경", "액", "효", "불", "타", "치", "퇴", "융", "도", "피", "표", "조", "6", "차", "희", "택", "사", "속", "본", "매출", "토", "게", "있", "평", "용", "른", "와", "제", "복", "4", "파", "수", "환", "적", "말", "우", "병", "잡", "획", "보", "으", "입", "중", "장", "임", "웨", "과", "순", "터", "유", "벤", "책", "항", "신", "설", "활", "특", "품", "소", "무", "약", "산", "교", "될", "체", "1", "권", "잉", "흐", "미", "운", "이", "량", "대", "동", "영업이익", "승", "의", "성", "단", "계", "현", "후", "로", "탁", "해", "등", "나", "일", "및", "당", "득", "익", "준", "g", "순이익", "발", "증", "측", "다", "개", "왑", "규", "상", "처", "담", "청", "총", "기", "총매출액", "출", "형", "초", "가", "손", "된", "화", "목", "전", "간", "양", "2", "트", "스", "급", "접", "호", "반", "작", "당기순이익", "5", "비", "누", "생", "국", "괄", "또", "각", "종", "판", "배", "않", "추", "어", "n", "구", "련", "법", "영", "주", "술", "공", "영업수익", "여", "망", "관", "시", "허", "통", "름", "폐", "고", "선", "충", "채", "범", "창", "멸", "매출액", "합", "0", "분", "거", "감", "류", "인", "능", "건", "면", "업", "영업이득", "을", "립", "9", "지", "원", "식", "m", "력", "모", "료", "e", "o", "귀", "프", "는", "한", "취", "태", "따", "결", "금", "위", "리", "석", "송", "t", "요", "직", "철", "3", "열", "행", "물", "되", "납", "율", "집", "에", "포", "없", "재", "험", "정", "실", "래", "서", "회", "확", "세", "부", "외", "예", "광", "자", "축", "할", "투"]

# %%
df_all['normalized'] = df_all['account_nm'].fillna('').apply(clean_name)
df_all['mapped'] = df_all['normalized'].map(account_mapping)

# %%
df_grouped = df_all.groupby(['corp_name', 'mapped']).size().unstack(fill_value=0)
display(df_grouped.head())
# Out:
# ⠇ Loading Companies in OpenDART
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-54-2009964310.py in <cell line: 0>()
# ----> 1 df_grouped = df_all.groupby(['corp_name', 'mapped']).size().unstack(fill_value=0)
#       2 display(df_grouped.head())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'mapped'

# %%
top_features
# Out:
# [('기타포괄손익-공정가치측정금융자산평가손익', 1908)]

# %%
all_columns
# Out:
# ['유',
#  '동',
#  '자',
#  '산',
#  '현',
#  '금',
#  '및',
#  '현',
#  '금',
#  '성',
#  '자',
#  '산',
#  '단',
#  '기',
#  '금',
#  '융',
#  '상',
#  '품',
#  '매',
#  '출',
#  '채',
#  '권',
#  '미',
#  '수',
#  '금',
#  '선',
#  '급',
#  '비',
#  '용',
#  '재',
#  '고',
#  '자',
#  '산',
#  '기',
#  '타',
#  '유',
#  '동',
#  '자',
#  '산',
#  '비',
#  '유',
#  '동',
#  '자',
#  '산',
#  '기',
#  '타',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '-',
#  '공',
#  '정',
#  '가',
#  '치',
#  '금',
#  '융',
#  '자',
#  '산',
#  '당',
#  '기',
#  '손',
#  '익',
#  '-',
#  '공',
#  '정',
#  '가',
#  '치',
#  '금',
#  '융',
#  '자',
#  '산',
#  '종',
#  '속',
#  '기',
#  '업',
#  ',',
#  '',
#  '관',
#  '계',
#  '기',
#  '업',
#  '',
#  '및',
#  '',
#  '공',
#  '동',
#  '기',
#  '업',
#  '',
#  '투',
#  '자',
#  '유',
#  '형',
#  '자',
#  '산',
#  '무',
#  '형',
#  '자',
#  '산',
#  '순',
#  '확',
#  '정',
#  '급',
#  '여',
#  '자',
#  '산',
#  '이',
#  '연',
#  '법',
#  '인',
#  '세',
#  '자',
#  '산',
#  '기',
#  '타',
#  '비',
#  '유',
#  '동',
#  '자',
#  '산',
#  '자',
#  '산',
#  '총',
#  '계',
#  '유',
#  '동',
#  '부',
#  '채',
#  '매',
#  '입',
#  '채',
#  '무',
#  '단',
#  '기',
#  '차',
#  '입',
#  '금',
#  '미',
#  '지',
#  '급',
#  '금',
#  '선',
#  '수',
#  '금',
#  '예',
#  '수',
#  '금',
#  '미',
#  '지',
#  '급',
#  '비',
#  '용',
#  '당',
#  '기',
#  '법',
#  '인',
#  '세',
#  '부',
#  '채',
#  '유',
#  '동',
#  '성',
#  '장',
#  '기',
#  '부',
#  '채',
#  '충',
#  '당',
#  '부',
#  '채',
#  '기',
#  '타',
#  '유',
#  '동',
#  '부',
#  '채',
#  '비',
#  '유',
#  '동',
#  '부',
#  '채',
#  '사',
#  '채',
#  '장',
#  '기',
#  '차',
#  '입',
#  '금',
#  '장',
#  '기',
#  '미',
#  '지',
#  '급',
#  '금',
#  '장',
#  '기',
#  '충',
#  '당',
#  '부',
#  '채',
#  '기',
#  '타',
#  '비',
#  '유',
#  '동',
#  '부',
#  '채',
#  '부',
#  '채',
#  '총',
#  '계',
#  '자',
#  '본',
#  '금',
#  '우',
#  '선',
#  '주',
#  '자',
#  '본',
#  '금',
#  '보',
#  '통',
#  '주',
#  '자',
#  '본',
#  '금',
#  '주',
#  '식',
#  '발',
#  '행',
#  '초',
#  '과',
#  '금',
#  '이',
#  '익',
#  '잉',
#  '여',
#  '금',
#  '(',
#  '결',
#  '손',
#  '금',
#  ')',
#  '기',
#  '타',
#  '자',
#  '본',
#  '항',
#  '목',
#  '자',
#  '본',
#  '총',
#  '계',
#  '부',
#  '채',
#  '와',
#  '자',
#  '본',
#  '총',
#  '계',
#  '수',
#  '익',
#  '(',
#  '매',
#  '출',
#  '액',
#  ')',
#  '매',
#  '출',
#  '원',
#  '가',
#  '매',
#  '출',
#  '총',
#  '이',
#  '익',
#  '판',
#  '매',
#  '비',
#  '와',
#  '관',
#  '리',
#  '비',
#  '영',
#  '업',
#  '이',
#  '익',
#  '기',
#  '타',
#  '수',
#  '익',
#  '기',
#  '타',
#  '비',
#  '용',
#  '금',
#  '융',
#  '수',
#  '익',
#  '금',
#  '융',
#  '비',
#  '용',
#  '법',
#  '인',
#  '세',
#  '비',
#  '용',
#  '차',
#  '감',
#  '전',
#  '순',
#  '이',
#  '익',
#  '(',
#  '손',
#  '실',
#  ')',
#  '법',
#  '인',
#  '세',
#  '비',
#  '용',
#  '계',
#  '속',
#  '영',
#  '업',
#  '이',
#  '익',
#  '(',
#  '손',
#  '실',
#  ')',
#  '당',
#  '기',
#  '순',
#  '이',
#  '익',
#  '(',
#  '손',
#  '실',
#  ')',
#  '기',
#  '본',
#  '주',
#  '당',
#  '이',
#  '익',
#  '(',
#  '손',
#  '실',
#  ')',
#  '희',
#  '석',
#  '주',
#  '당',
#  '이',
#  '익',
#  '(',
#  '손',
#  '실',
#  ')',
#  '기',
#  '타',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '후',
#  '속',
#  '적',
#  '으',
#  '로',
#  '',
#  '당',
#  '기',
#  '손',
#  '익',
#  '으',
#  '로',
#  '',
#  '재',
#  '분',
#  '류',
#  '되',
#  '지',
#  '',
#  '않',
#  '는',
#  '',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '기',
#  '타',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '-',
#  '공',
#  '정',
#  '가',
#  '치',
#  '금',
#  '융',
#  '자',
#  '산',
#  '평',
#  '가',
#  '손',
#  '익',
#  '순',
#  '확',
#  '정',
#  '급',
#  '여',
#  '부',
#  '채',
#  '(',
#  '자',
#  '산',
#  ')',
#  '',
#  '재',
#  '측',
#  '정',
#  '요',
#  '소',
#  '후',
#  '속',
#  '적',
#  '으',
#  '로',
#  '',
#  '당',
#  '기',
#  '손',
#  '익',
#  '으',
#  '로',
#  '',
#  '재',
#  '분',
#  '류',
#  '되',
#  '는',
#  '',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '총',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '영',
#  '업',
#  '활',
#  '동',
#  '',
#  '현',
#  '금',
#  '흐',
#  '름',
#  '영',
#  '업',
#  '에',
#  '서',
#  '',
#  '창',
#  '출',
#  '된',
#  '',
#  '현',
#  '금',
#  '흐',
#  '름',
#  '당',
#  '기',
#  '순',
#  '이',
#  '익',
#  '조',
#  '정',
#  '영',
#  '업',
#  '활',
#  '동',
#  '으',
#  '로',
#  '',
#  '인',
#  '한',
#  '',
#  '자',
#  '산',
#  '부',
#  '채',
#  '의',
#  '',
#  '변',
#  '동',
#  '이',
#  '자',
#  '의',
#  '',
#  '수',
#  '취',
#  '이',
#  '자',
#  '의',
#  '',
#  '지',
#  '급',
#  '배',
#  '당',
#  '금',
#  '',
#  '수',
#  '입',
#  '법',
#  '인',
#  '세',
#  '',
#  '납',
#  '부',
#  '액',
#  '투',
#  '자',
#  '활',
#  '동',
#  '',
#  '현',
#  '금',
#  '흐',
#  '름',
#  '단',
#  '기',
#  '금',
#  '융',
#  '상',
#  '품',
#  '의',
#  '',
#  '순',
#  '감',
#  '소',
#  '(',
#  '증',
#  '가',
#  ')',
#  '장',
#  '기',
#  '금',
#  '융',
#  '상',
#  '품',
#  '의',
#  '',
#  '처',
#  '분',
#  '기',
#  '타',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '-',
#  '공',
#  '정',
#  '가',
#  '치',
#  '금',
#  '융',
#  '자',
#  '산',
#  '의',
#  '',
#  '처',
#  '분',
#  '기',
#  '타',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '-',
#  '공',
#  '정',
#  '가',
#  '치',
#  '금',
#  '융',
#  '자',
#  '산',
#  '의',
#  '',
#  '취',
#  '득',
#  '당',
#  '기',
#  '손',
#  '익',
#  '-',
#  '공',
#  '정',
#  '가',
#  '치',
#  '금',
#  '융',
#  '자',
#  '산',
#  '의',
#  '',
#  '처',
#  '분',
#  '종',
#  '속',
#  '기',
#  '업',
#  ',',
#  '',
#  '관',
#  '계',
#  '기',
#  '업',
#  '',
#  '및',
#  '',
#  '공',
#  '동',
#  '기',
#  '업',
#  '',
#  '투',
#  '자',
#  '의',
#  '',
#  '처',
#  '분',
#  '종',
#  '속',
#  '기',
#  '업',
#  ',',
#  '',
#  '관',
#  '계',
#  '기',
#  '업',
#  '',
#  '및',
#  '',
#  '공',
#  '동',
#  '기',
#  '업',
#  '',
#  '투',
#  '자',
#  '의',
#  '',
#  '취',
#  '득',
#  '유',
#  '형',
#  '자',
#  '산',
#  '의',
#  '',
#  '처',
#  '분',
#  '유',
#  '형',
#  '자',
#  '산',
#  '의',
#  '',
#  '취',
#  '득',
#  '무',
#  '형',
#  '자',
#  '산',
#  '의',
#  '',
#  '처',
#  '분',
#  '무',
#  '형',
#  '자',
#  '산',
#  '의',
#  '',
#  '취',
#  '득',
#  '사',
#  '업',
#  '결',
#  '합',
#  '으',
#  '로',
#  '',
#  '인',
#  '한',
#  '',
#  '현',
#  '금',
#  '유',
#  '출',
#  '액',
#  '기',
#  '타',
#  '투',
#  '자',
#  '활',
#  '동',
#  '으',
#  '로',
#  '',
#  '인',
#  '한',
#  '',
#  '현',
#  '금',
#  '유',
#  '출',
#  '입',
#  '액',
#  '재',
#  '무',
#  '활',
#  '동',
#  '',
#  '현',
#  '금',
#  '흐',
#  '름',
#  '단',
#  '기',
#  '차',
#  '입',
#  '금',
#  '의',
#  '',
#  '순',
#  '증',
#  '가',
#  '(',
#  '감',
#  '소',
#  ')',
#  '사',
#  '채',
#  '',
#  '및',
#  '',
#  '장',
#  '기',
#  '차',
#  '입',
#  '금',
#  '의',
#  '',
#  '상',
#  '환',
#  '배',
#  '당',
#  '금',
#  '의',
#  '',
#  '지',
#  '급',
#  '외',
#  '화',
#  '환',
#  '산',
#  '으',
#  '로',
#  '',
#  '인',
#  '한',
#  '',
#  '현',
#  '금',
#  '의',
#  '',
#  '변',
#  '동',
#  '현',
#  '금',
#  '및',
#  '현',
#  '금',
#  '성',
#  '자',
#  '산',
#  '의',
#  '',
#  '순',
#  '증',
#  '감',
#  '기',
#  '초',
#  '의',
#  '',
#  '현',
#  '금',
#  '및',
#  '현',
#  '금',
#  '성',
#  '자',
#  '산',
#  '기',
#  '말',
#  '의',
#  '',
#  '현',
#  '금',
#  '및',
#  '현',
#  '금',
#  '성',
#  '자',
#  '산',
#  '기',
#  '초',
#  '자',
#  '본',
#  '배',
#  '당',
#  '기',
#  '말',
#  '자',
#  '본',
#  '단',
#  '기',
#  '투',
#  '자',
#  '자',
#  '산',
#  '기',
#  '타',
#  '수',
#  '취',
#  '채',
#  '권',
#  '당',
#  '기',
#  '법',
#  '인',
#  '세',
#  '자',
#  '산',
#  '종',
#  '속',
#  '기',
#  '업',
#  ',',
#  '',
#  '관',
#  '계',
#  '기',
#  '업',
#  '',
#  '및',
#  '',
#  '공',
#  '동',
#  '기',
#  '업',
#  '투',
#  '자',
#  '장',
#  '기',
#  '투',
#  '자',
#  '자',
#  '산',
#  '기',
#  '타',
#  '금',
#  '융',
#  '자',
#  '산',
#  '사',
#  '용',
#  '권',
#  '자',
#  '산',
#  '투',
#  '자',
#  '부',
#  '동',
#  '산',
#  '종',
#  '업',
#  '원',
#  '급',
#  '여',
#  '자',
#  '산',
#  '기',
#  '타',
#  '지',
#  '급',
#  '채',
#  '무',
#  '차',
#  '입',
#  '금',
#  '리',
#  '스',
#  '부',
#  '채',
#  '확',
#  '정',
#  '급',
#  '여',
#  '부',
#  '채',
#  '이',
#  '연',
#  '법',
#  '인',
#  '세',
#  '부',
#  '채',
#  '기',
#  '타',
#  '금',
#  '융',
#  '부',
#  '채',
#  '자',
#  '본',
#  '잉',
#  '여',
#  '금',
#  '기',
#  '타',
#  '자',
#  '본',
#  '기',
#  '타',
#  '포',
#  '괄',
#  '손',
#  '익',
#  '누',
#  '계',
#  '액',
#  '이',
#  '익',
#  '잉',
#  '여',
#  '금',
#  '부',
#  '채',
#  '및',
#  '자',
#  '본',
#  '총',
#  '계',
#  '매',
#  '출',
#  '액',
#  '기',
#  '타',
#  '영',
#  '업',
#  '외',
#  '수',
#  '익',
#  '기',
#  '타',
#  '영',
#  '업',
#  '외',
#  '비',
#  '용',
#  '법',
#  '인',
#  '세',
#  '비',
#  '용',
#  '차',
#  '감',
#  '전',
#  '순',
#  '이',
#  '익',
#  '법',
#  '인',
#  '세',
#  ...]

# %%
from sentence_transformers import SentenceTransformer, util
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

# 1. 모델 불러오기
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# 2. 텍스트 파일 읽기
file_path = '/content/drive/MyDrive/Colab Notebooks/SW엔지니어/data/2022_사업보고서_01_재무상태표_20250625.txt'  # txt 파일 경로 지정
with open(file_path, 'r', encoding='euc-kr') as f:
    lines = [line.strip() for line in f if line.strip()]  # 빈 줄 제거

# 3. 항목명 기준 전처리 (여기서는 한 줄에 하나씩 있다고 가정)
item_names = lines

# 4. 빈도수 계산
freq_counter = Counter(item_names)
freq_df = pd.DataFrame(freq_counter.items(), columns=['항목명', '빈도수']).sort_values(by='빈도수', ascending=False)

# 5. 임베딩 계산
embeddings = model.encode(item_names, convert_to_tensor=True)

# 6. 코사인 유사도 계산
cosine_sim_matrix = util.pytorch_cos_sim(embeddings, embeddings).numpy()

# 7. 유사도 정리 (예: 상위 유사 항목 5개씩 추출)
similarities = []
for idx, name in enumerate(item_names):
    sim_scores = list(enumerate(cosine_sim_matrix[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:6]  # 자기 자신 제외 상위 5개
    similar_items = [(item_names[i], float(score)) for i, score in sim_scores]
    similarities.append({'항목명': name, '유사항목(Top5)': similar_items})

# 8. 유사도 결과 출력 (상위 몇 개만 예시)
for s in similarities[:10]:
    print(f"📌 {s['항목명']}")
    for sim_item, score in s['유사항목(Top5)']:
        print(f"    ↪ {sim_item} (유사도: {score:.4f})")
    print()

# 9. 빈도 시각화 (선택사항)
freq_df.head(10).plot(kind='bar', x='항목명', y='빈도수', title='상위 10개 항목 빈도수', legend=False)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-81-1354945881.py in <cell line: 0>()
#      24
#      25 # 6. 코사인 유사도 계산
# ---> 26 cosine_sim_matrix = util.pytorch_cos_sim(embeddings, embeddings).numpy()
#      27
#      28 # 7. 유사도 정리 (예: 상위 유사 항목 5개씩 추출)
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/util.py in pytorch_cos_sim(a, b)
#      87         Tensor: Matrix with res[i][j] = cos_sim(a[i], b[j])
#      88     """
# ---> 89     return cos_sim(a, b)
#      90
#      91
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/util.py in cos_sim(a, b)
#     106     a_norm = normalize_embeddings(a)
#     107     b_norm = normalize_embeddings(b)
# --> 108     return torch.mm(a_norm, b_norm.transpose(0, 1))
#     109
#     110
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 42.35 GiB. GPU 0 has a total capacity of 14.74 GiB of which 13.70 GiB is free. Process 20082 has 1.04 GiB memory in use. Of the allocated memory 907.76 MiB is allocated by PyTorch, and 26.24 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
df['항목명']
# Out:
# 0             자산 [abstract]
# 1                      유동자산
# 2                  현금및현금성자산
# 3                    단기금융상품
# 4               매출채권 및 기타채권
#                 ...
# 106620                자본잉여금
# 106621             기타자본구성요소
# 106622           이익잉여금(결손금)
# 106623                 자본총계
# 106624              자본과부채총계
# Name: 항목명, Length: 106625, dtype: object

# %%
unique_items = df['항목명'].dropna().unique().tolist()
unique_items
unique_items = [item.strip() for item in unique_items]
unique_items
# 완전히 정제 후 유니크화
unique_items = list(set(item.strip() for item in df['항목명'].astype(str)))
unique_items
# Out:
# ['종속및관계기업투자자산',
#  '비유동금융부채',
#  '장기매출채권및기타채권',
#  '기타포괄손익-공정가치측정평가이익',
#  '기타금융자산(유동)',
#  '비유동리스채권',
#  '기타포괄-공정가치 측정 금융자산',
#  '비유동생물자산',
#  '1. 퇴직급여부채',
#  '종속ㆍ관계기업 투자주식',
#  '비유동성파생상품부채',
#  '미처분이익잉여금(미처리결손금)',
#  '종업원급여자산',
#  '회사채',
#  '미수대매금',
#  '부의지분법이익잉여금',
#  '유동성파생금융부채',
#  '기티비유동금융자산',
#  '비유동성채무상품',
#  '기타비유동부채(비유동)',
#  '유동성복구충당부채',
#  '당기손익-공정가치측정금융부채(유동)',
#  '유동성수입보증금',
#  '기타장기지급채무',
#  'Ⅱ.비 유 동 자 산',
#  '확정급여자산',
#  '퇴직급여부채',
#  '투자증권',
#  '장기금융리스부채',
#  '자기주식처분손익',
#  '당기손익인식지정금융부채',
#  '보증금(유동)',
#  '4. 기타유동부채',
#  '만기보유국공채',
#  '장기임차보증금',
#  '유동기타포괄손익공정가치측정금융자산',
#  '연차수당부채',
#  '기타자본잉여금',
#  '장기매출채권 및 장기대출채권',
#  '이익잉여금',
#  '원재료',
#  '기타채무(유동)',
#  '관계기업종속기업투자',
#  '유동확정계약부채',
#  '단기매입채무및기타채무',
#  '1.현금및현금성자산',
#  '유동파생금융상품자산',
#  '리스부채',
#  '유동성임대보증금',
#  '신주인수권부사채상환할증금',
#  '반품재고회수(비유동)',
#  '리스사용권자산',
#  '사용권자산상각누계',
#  '차량운반구감가상각누계액',
#  '유동파생상품자산',
#  '비융동성이연법인세자산',
#  '소송충당 부채',
#  '대손충당금, 단기미수금',
#  '기타',
#  '당기손익 공정가치측정 금융부채',
#  '유형자산(주석 13)',
#  '예수금',
#  '유동성장기채무',
#  '기타포괄손익-공정가치 측정 지분상품 투자',
#  '선급용역원가',
#  '기타포괄-공정가치 측정 지분증권',
#  '매입채무 및 기타부채',
#  '추심예수금',
#  '3. 확정급여채무',
#  '장기차입부채',
#  '유동성장기채권',
#  '종속기업 및 관계기업투자자산',
#  '반품제품회권',
#  '기타상각후원가측정금융자산',
#  '비유동기타부채',
#  '리스비유동채권',
#  '기타포괄손익-공정가치비유동금융자산',
#  '통화선도',
#  '비유동 공정가치 의무 측정 금융자산',
#  '유동차입금',
#  '장기미지급금 및 기타채무',
#  '유동이연법인세자산',
#  '조인트벤처에 대한 투자자산',
#  '순확정급여부채및기타장기급여부채',
#  '제품보증충당부채',
#  '비유동 당기손익-공정가치측정 금융자산',
#  '기타 유동부채',
#  '감가상각누계액, 차량운반구',
#  '기타 자본구성',
#  '이연수익',
#  '통화스왑파생부채',
#  '매각예정처분자산',
#  '유동배출권',
#  '기타포괄손익-공정가치측정금융상품',
#  '종속회사 및 관계회사 투자',
#  '7.관계기업투자',
#  '퇴직연금초과금',
#  '선물거래예치금',
#  '자산재평가적립금',
#  '장기미지급금 및 기타부채',
#  '당기손익-공정가치금융자산',
#  '7.기타유동자산',
#  '비유동이연법인',
#  '비유동금융리스부채',
#  '종속ㆍ관계기업투자',
#  '장기금융보증계약부채',
#  '반품환불부채',
#  '무형자산 및 영업권',
#  '유동부채(금융업)',
#  '단기종업원급여부채',
#  '금융기관예치금',
#  '예금잔액',
#  '7.미지급비용',
#  '공정가치 측정 금융자산',
#  '당기말',
#  '기타자산(비유동)',
#  '기타포괄손익-공정가치측정금융자산 평가손실',
#  '단기선수수익',
#  '장기당기손익인식금융자산',
#  '매각예정자산',
#  '장기대여금 및 관련채권',
#  '종속기업및관계기업투자',
#  '기타지급채무(비유동)',
#  '리스부채-비유동',
#  '종속,관계기업투자자산',
#  '유동지급보증충당부채',
#  '감가상각누계액',
#  '단기',
#  '해외사업환산이익',
#  '장기매출채권 및 비유동기타채권',
#  '유동성 장기차입금.',
#  '기타종업원급여부채',
#  '부채 총계',
#  '전환상환우선주',
#  '기타포괄-공정가치측정 금융자산',
#  '확정계약자산',
#  '단기보증금현재가치보증금현재가치할인차금',
#  '매입채무',
#  '미청구공사채권',
#  '종속기업, 공동기업 및 관계기업 투자',
#  '유동성장기차입금 및 유동성사채',
#  '기타수취채권(유동)',
#  '단기차입금및기타금융부채',
#  '상각후원가금융자산-유동',
#  '장기매도가능금융자산',
#  '단기파생상품부채',
#  '종속기업,관계기업및공동기업투자',
#  '종속기업,관계기업 및 공동기업 투자자산',
#  'I. 보통주자본금',
#  '3.기타금융부채(비유동)',
#  '당기손익측정금융자산',
#  '수탁금및기타부채',
#  '기타금융자산(비유동)',
#  '관계기업등에 대한 투자자산',
#  '당기법인세자산',
#  '자산재평가차익',
#  '단기손실부담계약충당부채',
#  '비유동미지급법인세',
#  '유동성파생상품금부채',
#  '3.퇴직급여채무',
#  '기타포괄손익-공정가치지분상품',
#  '손상차손누계액, 기타유형자산',
#  '2. 비유동리스부채',
#  '투자부동산',
#  '신주인수권부사채.',
#  '미처분이익잉여금(결손금)',
#  '종속기업및관계기업투자자산',
#  '장기파생상품금융자산',
#  '기타포괄손익-공정가치 측정 지정 지분상품 투자',
#  '유동성 기타포괄손익-공정가치 금융자산',
#  '8. 선수금',
#  '유동성사채',
#  '장기매출채권 및 기타비유동금융자산',
#  '단기금융자산',
#  '비유동 당기손익공정가치 금융자산',
#  '5. 충당부채',
#  '관계기업에 대한 대여금',
#  '유동성리스부채',
#  '당기손익 공정가치 측정 금융자산',
#  '관계기업 및 공동기업에 대한 지분',
#  '비유동종업원급여충당부채(기타장기종업원급여부채)',
#  '재공품',
#  '부채및자본총계',
#  '비유동공사손실충당부채',
#  '종속기업및 관계기업에 대한 투자자산',
#  '유동성전환사채파생상품부채',
#  '단기 상각후원가측정금융자산',
#  '파생금융부채',
#  '기타종업원장기급여',
#  '외상매입금',
#  '지분법적용 관계기업투자주식',
#  '기타자본요소',
#  '유동현금흐름위험회피파생자산',
#  '매입채무및기타채무(비유동)',
#  '기타금융부채(비유동)',
#  '계약부채',
#  '기타포괄손익-공정가치측정 금융자산(비유동)',
#  '수입보증금(유동)',
#  '매각예정유동자산',
#  'll. 이익잉여금',
#  '납입자본금',
#  '상각후원가측정 금융상품',
#  '매입채무 및 지급채무',
#  '차입금등(유동)',
#  '당기손익공정가치측정금융',
#  '비유동성계약자산',
#  '단기당기손익공정가치금융자산',
#  '8. 순확정급여자산',
#  '비유동 당기손익-공정가치 측정 금융자산',
#  '지분법적용주식',
#  '유동기타자산',
#  '금융리스부채(유동)',
#  'I.자본금',
#  '비상업적채권',
#  '비유동전환사채',
#  '종속,관계기업투자',
#  '당기손익-공정가치금융부채(비유동)',
#  '비유동사용권자산',
#  '비유동기타자산',
#  '장기대여금및수취채권',
#  '기타 수취 채권',
#  '파생상품금융부채',
#  '기타비유동금융리스부채',
#  '유동파생상품자산.',
#  '장기지급채무',
#  '유동성 장기차입금',
#  '유동매각예정자산',
#  '비유동충당부채',
#  '유동성 장기부채',
#  '매입채무외기타채무',
#  '매출채권 및 기타유동금융자산',
#  '매입채무 및 기타채무',
#  '유동금융부채',
#  '대손충당금, 단기선급비용',
#  '제작손실충당부채',
#  '사용권 자산(리스)',
#  '위탁대리점',
#  '1. 현금및현금성자산',
#  '장기차입금.',
#  '미청구용역',
#  '현금및현금성자산(주석 4,5,6,29,32)',
#  '단기사채',
#  '2. 관계기업투자',
#  '비유동 기타포괄손익-공정가치측정 금융자산',
#  '비유동 공정가치측정 금융자산',
#  '관계기업 및 공동기업투자',
#  '대손충당금, 장기임차보증금',
#  '보험수리적손익',
#  'II. 주식발행초과금',
#  '4. 차입금',
#  '유동장기부채',
#  '전대리스투자(유동)',
#  '장기계약자산',
#  '집기와비품',
#  '매출채권 및 기타수취채권',
#  '기타포괄손익-공정가치 측정 금융자산(유동)',
#  '매각예정분류자산',
#  '회생채권',
#  '사외적립자산',
#  '유동 당기손익-공정가치측정 금융자산',
#  '선급제세',
#  '자기주식처분이익',
#  '유동반환제품회수권',
#  '단기금융상품.',
#  '종속기업투자주식 등',
#  '관계기업에 대한 투자주식',
#  '부채 및 자본총계',
#  '당기손익-공정가치 측정 금융자산(유동)',
#  '관계및공동기업투자',
#  '장기유동화채무',
#  '비유동 당기손익-공정가치 측정  금융자산',
#  '단기차입금',
#  '환불충당부채',
#  '기타장기종업원급여충당부채',
#  '당기손익-공정가치측정금융부채',
#  '(대손충당금)',
#  '보증금부채',
#  '파생상품금융자산',
#  '자산 [abstract]',
#  '파생금자산',
#  '비유동기타포괄손익인식-공정가치측정금융자산',
#  '기타장기종업원부채.',
#  '리스채권_유동',
#  '대여금및기타수취채권',
#  '1. 기타의무형자산',
#  '단기선급비용',
#  '6.무형자산',
#  '종속기업,공동기업및관계기업투자',
#  '유동비금융부채',
#  '5.부가세예수금',
#  '충당부채(연월차)',
#  '유동하자보증충당부채',
#  '종속기업 등에 대한 투자자산',
#  '유동성환불부채및충당부채',
#  '장기미수채권',
#  '단기차입금 및 유동성장기부채',
#  '기타자산',
#  '토지',
#  '비유동성판매보증충당부채',
#  '전기공급설비',
#  'Ⅳ.이 익 잉 여 금',
#  '비유동 당기손익-공정가치 측정 지정 금융부채',
#  '유동교환사채',
#  '공동기업 및 관계기업에 투자',
#  '투자금융자산',
#  '당기손익인식금융자산(유동)',
#  '유동성기타채무',
#  '파생상품평가자산',
#  '재고자산',
#  '미지급담배소비세등',
#  '비유동매입채무 및 기타채무',
#  '비유동매입채무기타채무',
#  '유동금융보증충당부채',
#  '확정퇴직급여부채',
#  '반제품',
#  'II. 자본잉여금',
#  '유동성상각후원가측정유가증권',
#  '공구',
#  '5. 임대보증금',
#  '당기손익 공정가치측정 금융자산',
#  '유동당기손익-공정가치금융자산',
#  '비유동사채',
#  '초과청구매출채권',
#  '부채와자본 총계',
#  '장기금융상품',
#  '비유동기타채무',
#  'IV. 기타포괄손익누계액',
#  '단기 상각후원가측정금융부채',
#  '종속기업등에 대한 투자자산',
#  '전환우선주부채',
#  '장기기타채권(주석 4,5,8,30,32)',
#  '사채',
#  '장기예수금',
#  '보증금(비유동)',
#  '공기구비품',
#  '단기기타포괄손익-공정가치측정금융자산',
#  '차입금및사채(비유동)',
#  '관계회사대여금',
#  'Ⅲ.이익잉여금(결손금)',
#  '사용권자산(리스)',
#  '미지급세금',
#  '7. 기타유형자산',
#  '관계기업조합출자금',
#  '6. 예수금',
#  '단기매입채무',
#  '파생생품자산',
#  '반품추정자산',
#  '이연법인세자산',
#  '매각예정비유동자산',
#  '매각예정으로 분류된 부채',
#  '이익잉여금(미처리결손금)',
#  'Ⅴ. 이익잉여금',
#  '자본조정(자기주식)',
#  '자               산',
#  '유동재고자산',
#  '비유동성전환금융상품',
#  '비유동회생채무',
#  '자    본    총    계',
#  '관계기업 및 공동기업투자주식',
#  '유동부채',
#  '유동리스부채(주석 4,5,15,29,32)',
#  '장기성 당기손익-공정가치 측정 금융자산',
#  '장기투자금융상품',
#  '4.기타장기종업원급여',
#  'Ⅲ. 기타포괄손익누계액',
#  '상품',
#  '단기이자부차입금',
#  '비유동성상각후원가측정금융자산',
#  '비유동장기근속충당부채',
#  '장기차입금 및 장기리스부채',
#  '감가상각누계액(선박장비품)',
#  '유동 당기손익-공정가치금융자산',
#  '비유동매입채무및기타채무',
#  '단기수취채권',
#  '유동성회사채',
#  '리스채권(비유동)',
#  '종속회사 투자',
#  '유동성회원보증금',
#  '대손충당금(장기미수금)',
#  '종속기업및공동기업투자',
#  '반환재고회수권',
#  '당기손익-공정가치측정금융자산(비유동)',
#  '지방소득세부채',
#  '관계기업 및 종속기업투자자산',
#  '순환정급여자산',
#  '대행미지급금',
#  '종속기업 대한 투자자산',
#  '반환제품',
#  '파생상품부채(유동)',
#  '사용권자산(차량)',
#  '종속,관계기업및공동기업투자',
#  '매각예정으로 분류된 처분자산집단에 포함된 부채',
#  '광산복구충당부채',
#  '3. 기타유동부채',
#  'Ⅱ.비유동자산',
#  '유동기타수취채권',
#  '공동기업 및 관계기업투자',
#  '관계기업 및 종속기업투자자',
#  '매각계정비유동부채',
#  '주식할인발행차금',
#  '장기성매출채권및기타채권',
#  '2.초과청구공사',
#  '당기손익공정가치측정 금융자산',
#  '전환우선주',
#  '유동임대보증금',
#  '5.투자부동산',
#  '비유동비금융자산',
#  '법정적립금',
#  '비연결종속기업투자 및 관계기업투자',
#  '3. 유형자산',
#  '자산 총계',
#  '기타포괄손익-공정가치측정 금융자산 평가손익',
#  '선수수익',
#  '상각후원가측정채무상품',
#  '장기투자증권',
#  '단기미지급비용',
#  '당기손익공정가치금융자산',
#  '종속기업',
#  'Ⅴ.이익잉여금(결손금)',
#  '미청구자산',
#  '우선주자본금',
#  '금융선급금',
#  '단기대여금및수취채권',
#  '1. 기타금융자산',
#  '비유동지급채무',
#  '1. 자기주식',
#  '3.단기차입금',
#  '장기대여금손상차손누계액',
#  '관계기업투자및공동약정',
#  '종속 및 관계기업투자주식',
#  '종업원급여부채',
#  '비유동금융기관예치금',
#  '비유동금융자산',
#  '장기복구충당부채',
#  '파생금융부채(비유동)',
#  'Ⅱ.비유동부채',
#  '장기미지급금및기타부채',
#  '비유동법인세부채',
#  '비유동 상각후원가 측정 금융부채',
#  '종속,관계및공동기업투자주식',
#  '분양선수금',
#  '공정가치측정파생상품',
#  '비유동리스부채(주석 4,5,15,29,32)',
#  '단기매출채권',
#  '계약이행원가',
#  '장기기타수취채권',
#  '자기주식',
#  '유동성 관계기업투자',
#  '확정급여제도의 재측정손익',
#  '장기리스부채',
#  '유동성장기리스부채',
#  '당기손익-공정가치 금융부채',
#  '당기손익-공정가치 측정  금융자산',
#  '금융예수금',
#  '매입채무 및 기타유동채무',
#  '3. 매출채권',
#  '당기손익인식-공정가치금융자산',
#  '장기사용권자산',
#  '주임종단기채권',
#  '조인트벤처와 관계기업에 대한 투자자산',
#  '매출채권.',
#  '유동성 차입금 및 사채',
#  '전환사채전환권조정',
#  '비유동파생상품자산',
#  '상각후원가측정대출채권및기타금융자산',
#  '공동지배기업 및 관계기업에 대한 투자자산',
#  '자 산 총 계',
#  '자기주식의 취득',
#  '상각후원가 측정 금융부채',
#  '5. 무형자산',
#  '주식발행초과금',
#  '상각후원가측정금융자산(유동)',
#  '임차보증금',
#  '관계기업과 공동기업에 대한 투자자산',
#  '신주인수권부사채할인발행차금',
#  '유동 당기손익-공정가치 의무 측정 금융자산',
#  '매도가능금융자산(유동)',
#  '장비임대자산',
#  '자본금(주석 1,20)',
#  '당기손익-공정가치 측정 금융부채',
#  '기타장기종업원채무',
#  '장기 차입금 및 사채',
#  '사용수익기부자산',
#  '비유동보증금',
#  '장기투자자산',
#  '해외사업환산손익',
#  '투자부동산 및 기타투자자산',
#  '소유주분배예정부채',
#  '2. 미수금',
#  '종속기업투자',
#  '단기차입금및사채',
#  '장기기타채무',
#  '당기손익-공정가치금융상품(유동)',
#  '비지배지분',
#  '기타의자본잉여금',
#  '비유동전환상환우선주부채',
#  '확정급여부채및기타장기급여채무',
#  '거래가격차이 이연자산',
#  '기타포괄손익측정금융자산',
#  '부가세 예수금',
#  '비유동 매입채무 및 기타채무',
#  '기타잉여금',
#  '유동성환불부채',
#  '비유동 리스부채',
#  '기타자본구성요소',
#  '장기계약부채',
#  '시설이용권(회원권)',
#  '9.금융보증부채',
#  '대손충당금(미수금)',
#  '순확정급여부채',
#  '기타비금융자산',
#  '장기이자부차입금',
#  '기타포괄손익-공정가치측정금융자산(비유동)',
#  '부 채',
#  '유동파생상품',
#  '매입채무 및 기타비유동채무(비유동)',
#  '당기말자본',
#  '기타의 자본조정',
#  '유동성판매보증충당부채',
#  '장기수입보증금',
#  '4. 기타비유동부채',
#  '비유동당기손익인식금융부채',
#  '유동 당기손익-공정가치측정금융자산',
#  '종속기업및공동ㆍ관계기업투자',
#  '단기금융상품',
#  '유동성공정가치측정금융자산',
#  '유동성외화사채',
#  '장기금융자산',
#  '매도가능금융자산평가손익',
#  '미지급금및기타채무',
#  '장기성미지급금',
#  '기타자산(유동)',
#  '미수이자수익',
#  '4. 이연법인세자산',
#  '매출채권 및 기타채권',
#  '비유동 당기손익-공정가치 금융자산',
#  '비유동전환사채와일반사채',
#  '종속기업 및 관계기업주식',
#  '3. 무형자산',
#  '회원권',
#  '4. 차량',
#  '(1) 현금및현금성자산',
#  '매출채권외수취채권',
#  '금융상품',
#  '확정계약평가자산',
#  '공사손실충당부채',
#  '장기성기타채무',
#  '장기금융상품.',
#  '자본총계',
#  '2.유동성장기차입금',
#  '미환급세금',
#  '기타단기채권',
#  '당기손익공정가치금융부채',
#  '매각예정부채',
#  '법정준비금',
#  '기타포괄손익-공정가치측정 금융상품',
#  '당기손익인식공정가치금융자산',
#  '기타자본',
#  '퇴직급여자산',
#  '단기 당기손익-공정가치측정금융자산',
#  '리스장기부채',
#  '사모사채',
#  '관계기업지분투자',
#  'll. 비유동부채',
#  '장기이자율스왑부채',
#  '기타포괄손익 공정가치측정 지분증권',
#  '기타포괄손익-공정가치측정지분상품',
#  '(평가손실충당금)',
#  '유동사채',
#  '장기차입금',
#  '단기상각후원가측정채무상품',
#  '외화사채',
#  '1. 보통주자본금',
#  '설비자산',
#  '당기손익 -  공정가치 측정 금융자산',
#  '장기매출채권및기타비유동채권',
#  '기타유동부채(주석 17)',
#  '관계기업등투자자산',
#  '관계기업및 종속기업 투자',
#  '매출채권및미수금',
#  '장기수탁개발선수금',
#  '5. 기타유동자산',
#  '차입금 등',
#  '장기파생금융상품',
#  '반품권자산',
#  '상각후원가 금융자산',
#  '유동당기손익인식금융부채',
#  '장기종업원급여충당부채',
#  '개발장치',
#  '종속기업, 공동기업 및 관계기업투자',
#  '관계기업주식',
#  '기타포괄손익-공정가치측정 금융자산',
#  '유동 당기손익-공정가치금융부채',
#  '장기매입채무및기타지급채무',
#  '기타충당부채',
#  '4.장기리스미지급금',
#  '확정급여채무',
#  '계약부채(유동)',
#  '매입채무및타금융부채',
#  '기타유동자산(주석 12)',
#  '신주인수권대가',
#  '2.당기손익공정가치측정금융자산',
#  '보유현금',
#  '매출채권및기타수취채권',
#  '영업권및무형자산',
#  '지분법적용 투자주식',
#  '기타비유동금융부채.',
#  '그 밖의 기타단기충당부채',
#  '비유이연법인세자산',
#  '기타의무형자산',
#  '방송콘텐츠자산',
#  '위법행위미수금',
#  '재고자산평가충당금',
#  '공급설비',
#  '상각후원가측정 금융자산',
#  '반환부채',
#  '1. 단기금융상품',
#  'Ⅲ. 기타자본구성요소',
#  '선급주세',
#  '1. 투자부동산(토지)',
#  '비유동공정가치측정금융자산',
#  '손상차손누계액(무형자산)',
#  '투자주식',
#  '감가상각누계액(사용권자산 차량운반구)',
#  '6. 유동충당부채',
#  '(2) 유형자산',
#  '장기사채',
#  '비유동기타종업원급여부채',
#  '지분법자본변동',
#  '비유동성기타채무',
#  '당기손익-공정가치 측정 지정 금융유동부채',
#  '유동사채및장기차입금',
#  '기타유동채무',
#  '기타급여채무',
#  '비유동매각예정자산',
#  '장기매출채권및금융리스채권',
#  '단기차입금 및 사채',
#  '3.관계기업투자주식',
#  '퇴직급여충담금',
#  '유동성 예수보증금',
#  '종속 공동 관계기업에 대한 투자',
#  '기타유동금융자산(주석 4,5,9,32)',
#  '단기금융리스부채',
#  '관계종속기업투자',
#  '단기수탁개발선수금',
#  '단기기타금융상품',
#  'Ⅲ.기타포괄손익누계액',
#  '(1) 매입채무 및 기타유동채무',
#  '상표권',
#  '장기예치금',
#  '기타포괄손익-공정가치측정 금융자산(유동)',
#  '기타비유동부채.',
#  '단기차입금 등',
#  '유동성기타채권',
#  '손상차손누계액, 집기',
#  '기타포괄손익공정가치금융자산',
#  '비유동 상각후원가측정금융자산',
#  '환불자산',
#  '종소기업투자주식',
#  '유동기타금융부채',
#  '손상차손누계액(기계장치)',
#  '(2) 미지급배당금',
#  '종속기업 투자',
#  '유동자산(금융업)',
#  '공사자재',
#  '초과납입자본',
#  '관계기업, 종속기업에 대한 투자자산',
#  '관계기업투자주식평가이익',
#  '전환상환우선주부채.',
#  '전환상환우선주부채할인발행차금',
#  '9.사외적립자산',
#  '비유동수취채권',
#  '비유동 상각후원가 측정 금융자산',
#  '공정가치측정금융부채',
#  '매각예정 또는 소유주에 대한 분배예정으로 분류된 비유동자산이나 처분자산집단',
#  '장기차입금 및 전환사채',
#  '종속기업 투자주식',
#  '현재가치할인차금(장기수입보증금)',
#  '유동성신주인수권부사채',
#  '장기차입금 및 사채',
#  '기타포괄-공정가치측정금융자산',
#  '차량운반구',
#  '4.예수금',
#  '감가상각누계액(건물)',
#  '단기계약부채',
#  '장기충당부채',
#  'Ⅱ. 기타자본항목',
#  '단기투자예치금',
#  '사용권자산.',
#  '유동기타종업원급여부채',
#  '5.선급금',
#  '유동당기손익인식지정금융자산',
#  '유동 당기손익-공정가치 금융자산',
#  '유동 공정가치 의무 측정 금융자산',
#  '비유동기타채권',
#  '6. 당기법인세자산',
#  '종속기업및관계기업투자주식',
#  '장기성매출채권',
#  '단기환불부채',
#  '기타유동성수취채권',
#  '관계및공동기업투자주식',
#  '(4) 무형자산',
#  '사무용비품',
#  '기타채권(유동)',
#  '기타포괄손익-공정가치금융자',
#  '기타포괄손익-공정가치 측정 금융자산(비유동)',
#  '유동충당부채',
#  '이자율스왑평가손익',
#  '단기상각후원가측정유가증권',
#  'III. 금융업부채',
#  '유동성파생금융상품부채',
#  '유동당기손익인식지정금융부채',
#  '1. 매입채무',
#  '합병차손',
#  '비유동리스자산',
#  '투자자산',
#  '지분법기타포괄손익변동-재평가이익',
#  '관계회사지분증권',
#  '공정가치측정금융자산평가손익',
#  '비유동 당기손익-공정가치측정금융자산',
#  '당기법인세자산.',
#  '기타비유동자산.',
#  '사용권자산(주석 15)',
#  '기타 금융자산',
#  '기타단기금융부채',
#  '3. 미수수익',
#  'Ⅲ. 자본조정',
#  '비유동 당기손익-공정가치 측정 지정 금융자산',
#  '보증금자산',
#  '임대예수보증금',
#  '비연결종속기업투자',
#  '장기근속채무',
#  '확정급여부채 및 기타장기종업원급여부채',
#  '기타 비유동 부채',
#  'III. 금융업자산',
#  '기타지급부채',
#  '종속기업 및 관계기업 투자주식(유동)',
#  '기타비유동투자자산',
#  'Ⅰ.유동자산',
#  '종속기업, 관계기업투자주식',
#  '(1) 장기차입금',
#  '유동비금융자산',
#  '부               채',
#  '연차충당부채',
#  '종속기업및관계기업지분투자',
#  '전환사채',
#  '관계기업 투자주식',
#  '공구와기구비품',
#  '비유동 당기손익 공정가치 측정 금융자산',
#  '감가상각누계액, 건물',
#  '품질보증충당부채',
#  '건설장비',
#  '4. 기타유동자산',
#  '종속기업과 관계기업에 대한 투자자산',
#  '파생상품 자산',
#  '장기대여금및기타채권',
#  '기타단기채무',
#  '6. 기타금융자산',
#  '비유동 기타포괄손익-공정가치 측정 금융자산',
#  '선급부가세',
#  '합병차익',
#  '비유동성 기타포괄손익-공정가치 측정 금융자산',
#  '대손충당금(장기대여금)',
#  '이월결손금',
#  '종속기업 투자자산',
#  'II.비유동부채',
#  '관계기업및및종속기업투자',
#  '유동공정가치금융자산',
#  '퇴직연금자산',
#  '종속기업, 관계기업 및 공동기업 투자',
#  '충당자산',
#  '장기매출채권 및 기타금융자산',
#  '종속기업 및 관계기업 투자자산',
#  '사채(유동)',
#  '당기손익-공정가치측정비유동금융자산',
#  '시설이용권',
#  '비유동기타금융부채',
#  '비유동계약부채(주석 19)',
#  '비유동성 차입금 및 사채',
#  '종업원급여부채(유동)',
#  '지급보증충당부채',
#  '매각및소유주분배예정부채',
#  '당기손익-공정가치 측정금융자산',
#  '감가상각누계액(투자부동산)',
#  '리스유동채권',
#  '충당부채',
#  '유동차입부채',
#  '장기환불부채',
#  'Ⅴ.기타자본구성요소',
#  '(2) 기타유동금융자산',
#  '(4) 재고자산',
#  '매각예정비유동자',
#  '종속ㆍ관계기업주식',
#  '미수수익',
#  '자원개발자금',
#  '단기미수금 및 기타채권',
#  '이연법인세자산(주석 28)',
#  '관계기업 및 종속기업투자주식',
#  '유동성차입금및사채',
#  '유동당기손익인식-공정가치측정금융자산',
#  '리스자산',
#  '장금융부채',
#  '7.보증금',
#  '대손충당금',
#  '3.매출채권',
#  '관계기업및종속기업투자',
#  '반품재고회수권',
#  '단기 우선주부채',
#  '지분상품',
#  '9.재고자산',
#  '단기대출채권',
#  '6. 파생금융부채',
#  '대여금및기타채권',
#  '영업권 이외의 무형자산',
#  '미청구공사',
#  '자본잉여금.',
#  '장기성매입채무 및 기타채무',
#  '매출채권및 기타채권',
#  '단기투자주식',
#  '당기손익공정가치측정금융부채',
#  '장기성매입채무및기타채무',
#  '기타 유동 채권',
#  '유동성장기금융예치금',
#  '당기손익인식-공정가치측정금융자산',
#  '투자비유동금융자산',
#  '종속기업및공동기업투자주식',
#  '배출부채',
#  '대손충당금(단기대여금)',
#  '전환증권',
#  '당기손익-공정가치로 측정하는 금융상품',
#  '7. 기타비유동자산',
#  '종속기업,관계회사 및 공동투자기업',
#  '공동기업 투자',
#  '사용권(금융리스)자산',
#  '매입채무 및 기타금융부채(유동)',
#  '장기전환사채',
#  '지배기업의 소유주에게 귀속되는 자본',
#  '유동성장기차입금 및 사채',
#  '장기차입금 및 기타금융부채',
#  '기타포괄-공정가치금융자산',
#  '장기보증금현재가치할인차금',
#  '기타부채(유동)',
#  '비유동리스부채.',
#  '자본과 부채총계',
#  '1. 기타포괄손익-공정가치금융자산',
#  '유동리스부채',
#  '금융리스채권(비유동)',
#  '계약 자산',
#  '기타유동비금융부채',
#  '당기손익-공정가치측정 금융상품',
#  '비유동만기보유금융자산',
#  '비유동성복구충당부채',
#  '단기비금융부채',
#  '기타금융자산(장기)',
#  '종속기업및관계회사투자주식',
#  '종속기업 및 공동기업투자',
#  '단기매입채무(주석 4,5,16,32)',
#  '기타단기수취채권',
#  '리스채권_비유동',
#  '사내근로복지기금자산',
#  '회생채무',
#  '매입채무 및 미지급금',
#  '금융보증부채',
#  '장기매입채무 및 기타 비유동채무',
#  '신주인수권부사채상환할증',
#  '소프트웨어',
#  '3. 장기대여금',
#  '유동차입금및사채',
#  '장기비금융자산',
#  '기타유동금융자산',
#  '유동당기손익-공정가치 측정 금융자산',
#  '기타포괄손익-공정가치금융자산평가이익',
#  '장기이연수익',
#  '(1) 투자부동산',
#  '비유동파생상품부채',
#  '매각예정자산에 직접 관련된 부채',
#  '배출권자산',
#  '2. 파생금융상품',
#  '재고자산(주석 11)',
#  '유형자산',
#  '종속기업에대한투자자산',
#  '매출채권(비유동)',
#  '매출채권및기타채권',
#  '4.유형자산',
#  '비유동기타포괄손익공정가치측정금융자산',
#  '종속기업, 관계기업에 대한 투자자산',
#  '당기손익-공정가치측정금융자산(유동)',
#  '장기파생상품부채',
#  '종속 및 관계기업 투자',
#  '운용리스자산',
#  '기타채권(비유동)',
#  '장기성기타금융자산',
#  '퇴직보험',
#  '교환권조정',
#  '4. 재고자산',
#  'V. 기타자본',
#  '자산유동화차입금',
#  '전환사채할인발행차금',
#  '결손금',
#  '유동성장기금융자산',
#  '유동성기타장기종업원급여충당부채',
#  '자본조정',
#  '당기손익인식-공정가치 측정 금융자산',
#  '유동성계약부채',
#  '2. 매출채권 및 기타유동채권',
#  '종속기업투자자산',
#  '기타부채(비유동)',
#  '장기리스채권',
#  '장기매출채권 및 기타비유동채권',
#  '소송충당부채',
#  '매출채권 및 기타유동수취채권',
#  '수탁금',
#  '예치금',
#  '주임종장기대여금',
#  '단기금융예치금',
#  '유동성보증금',
#  '자본 [abstract]',
#  '종속기업,관계기업 및 공동기업투자주식',
#  '유동매출채권',
#  '반환상품',
#  '리스부채.',
#  '매각예정비유동부채',
#  '8.유동성장기차입금',
#  '관계기업 및 공동기업에 대한 투자자산',
#  '기타장기대여금및수취채권',
#  '채권할인차입금',
#  '기타불입자금',
#  '당기손익공정가치측정금융자산(비유동)',
#  'Ⅲ.이익잉여금',
#  'Ⅰ.자본금',
#  '단기투자채권',
#  '종속및관계기업투자주식',
#  '(4) 비유동리스부채',
#  '자산유동화채무',
#  '유동 당기손익-공정가치 측정 지정 금융부채',
#  '당좌자산',
#  '부 채 및 자 본 총 계',
#  '우선주부채',
#  '비유동 매출채권및기타채권',
#  '환경관리충당부채',
#  '주식매입선택권',
#  '비유동차입금 및 사채',
#  '자               본',
#  '기타자본조정',
#  '유동성신주인수부사채',
#  '단기 사후처리, 복구, 정화 비용을 위한 충당부채',
#  '장기대출채권',
#  '기타포괄손익-공정가치평가손익',
#  '2. 단기대여금',
#  '매각예정처분부채집단',
#  '감가상각누계액, 기계장치',
#  '유동성금융보증계약부채',
#  '선급공사원가',
#  '자  산  총  계',
#  '퇴직연금투자자산',
#  'Ⅰ.유 동 부 채',
#  '확정급여채무의현재가치',
#  '차입금(유동)',
#  '당기손익-공정가치 금융부채(유동)',
#  '만기보유금융자산',
#  'III. 이익잉여금(결손금)',
#  '장기미지급금및기타채무',
#  '손상차손누계액, 투자부동산',
#  '비유동차입금및사채',
#  '4. 기타유동금융자산',
#  '비유동파생부채',
#  '초과청구부채',
#  '당기손익-공정가치 측정 금융자산',
#  '당기손익인식측정금융자산',
#  '기타비유동채무',
#  '상각후원가측정금융자산(비유동)',
#  '유동성유가증권금융자산',
#  '리스채권(유동)',
#  '사모투자자산(관계기업투자)',
#  '기타자본구성항목',
#  '장기파생상품평가자산',
#  '유동성금융부채',
#  '매각예정유형자산',
#  '재평가잉여금',
#  '기타포괄손익공정가치금융상품',
#  '비유동판매보증충당부채',
#  '매출채권(주석 4,5,7,32)',
#  '단기차입부채',
#  '자본금과 적립금',
#  '장기당기손익공정가치금융자산',
#  '기타장기채권',
#  '하자보수충당부채(비유동)',
#  '선급금',
#  '확정급여부채.',
#  '재평가적립금',
#  '유동당기손익공정가치측정금융자산',
#  '당기손익-공정가치 측정 금융자산_',
#  '기타비유동부채(주석 17)',
#  '유동파생금융부',
#  '공동기업 및 관계기업투자자산',
#  '통화선도부채',
#  '7. 유동리스부채',
#  '기타포괄손익공정가치측정금융자산',
#  '종속,관계기업 및 공동기업투자',
#  '1. 토지',
#  ...]

# %%
# 3. 임베딩 모델 불러오기 (GPU 사용)
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
embeddings = model.encode(unique_items, convert_to_tensor=True, device='cuda')

# 4. 각 항목별 유사도 Top 50 추출 (전체 100개 항목만 출력)
similarities = []
for idx, name in enumerate(unique_items):
    query_embedding = embeddings[idx]
    sim_scores = util.pytorch_cos_sim(query_embedding, embeddings)[0]
    top_results = torch.topk(sim_scores, k=101)  # 자기 자신 포함
    similar_items = []
    for score, i in zip(top_results[0], top_results[1]):
        if i != idx:
            similar_items.append((unique_items[i], float(score)))
        if len(similar_items) == 50:
            break
    similarities.append({'항목명': name, '유사항목(Top50)': similar_items})

# 5. 상위 100개 항목에 대해 결과 출력
for s in similarities[:100]:
    print(f"\n📌 {s['항목명']}")
    for sim_item, score in s['유사항목(Top50)'][:5]:  # 보기 편하게 5개만 출력
        print(f"    ↪ {sim_item} (유사도: {score:.4f})")
# Out:
# 📌 종속및관계기업투자자산
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 비유동금융부채
#     ↪ 유동비금융부채 (유사도: 0.9958)
#     ↪ 비유동충당부채 (유사도: 0.9928)
#     ↪ 비유동비금융부채 (유사도: 0.9926)
#     ↪ 비유동 리스부채 (유사도: 0.9923)
#     ↪ 비유동리스부채 (유사도: 0.9919)
#
# 📌 장기매출채권및기타채권
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 기타포괄손익-공정가치측정평가이익
#     ↪ 기타포괄손익-공정가치평가손익 (유사도: 0.9955)
#     ↪ 기타포괄손익 공정가치측정 지분증권 (유사도: 0.9952)
#     ↪ 기타포괄손익-공정가치측정지분상품 (유사도: 0.9944)
#     ↪ 기타포괄-공정가치금융자산평가손익 (유사도: 0.9943)
#     ↪ 기타포괄손익-공정가치측정 금융자산 (유사도: 0.9936)
#
# 📌 기타금융자산(유동)
#     ↪ 기타금융자산(비유동) (유사도: 0.9935)
#     ↪ 파생금융자산(유동) (유사도: 0.9933)
#     ↪ 파생금융자산(비유동) (유사도: 0.9914)
#     ↪ 기타금융자산(장기) (유사도: 0.9895)
#     ↪ 신기술금융자산(유동) (유사도: 0.9880)
#
# 📌 비유동리스채권
#     ↪ 리스비유동채권 (유사도: 0.9952)
#     ↪ 비유동기타채권 (유사도: 0.9952)
#     ↪ 리스유동채권 (유사도: 0.9925)
#     ↪ 비유동성리스채권 (유사도: 0.9922)
#     ↪ 비유동대출채권 (유사도: 0.9914)
#
# 📌 기타포괄-공정가치 측정 금융자산
#     ↪ 기타포괄-공정가치측정 금융자산 (유사도: 0.9997)
#     ↪ 기타포괄-공정가치측정금융자산 (유사도: 0.9982)
#     ↪ 기타포괄-공정가치 측정 지분증권 (유사도: 0.9974)
#     ↪ 기타포괄손익-공정가치 금융자산 (유사도: 0.9958)
#     ↪ 기타포괄손익-공정가치금융자 (유사도: 0.9954)
#
# 📌 비유동생물자산
#     ↪ 소비용생물자산 (유사도: 0.9933)
#     ↪ 비유동금융자산 (유사도: 0.9914)
#     ↪ 비유동리스자산 (유사도: 0.9905)
#     ↪ 온실가스배출권 (유사도: 0.9904)
#     ↪ 유동생물자산 (유사도: 0.9902)
#
# 📌 1. 퇴직급여부채
#     ↪ 1.관계기업투자주식기타자본변동 (유사도: 1.0000)
#     ↪ 1.현금및현금성자산 (유사도: 1.0000)
#     ↪ 1. 현금및현금성자산 (유사도: 1.0000)
#     ↪ (1) 현금및현금성자산 (유사도: 0.9329)
#     ↪ 2. 관계기업투자 (유사도: 0.8957)
#
# 📌 종속ㆍ관계기업 투자주식
#     ↪ 관계기업 투자주식 (유사도: 1.0000)
#     ↪ 종속기업및관계기업 투자주식 (유사도: 1.0000)
#     ↪ 관계기업 투자지분 (유사도: 0.9859)
#     ↪ 종속기업및관계기업 투자자산 (유사도: 0.9850)
#     ↪ 관계기업에대한 투자자산 (유사도: 0.9850)
#
# 📌 비유동성파생상품부채
#     ↪ 비유동파생상품부채 (유사도: 0.9951)
#     ↪ 유동성파생상품금부채 (유사도: 0.9945)
#     ↪ 장기파생상품금융부채 (유사도: 0.9939)
#     ↪ 비유동손실충당부채 (유사도: 0.9938)
#     ↪ 유동성파생상품부채 (유사도: 0.9936)
#
# 📌 미처분이익잉여금(미처리결손금)
#     ↪ 미처분이익잉여금(결손금) (유사도: 0.9892)
#     ↪ 이익잉여금(미처리결손금) (유사도: 0.9861)
#     ↪ 현재가치할인차금(장기수입보증금) (유사도: 0.9838)
#     ↪ 당기손익-공정가치금융부채(비유동) (유사도: 0.9807)
#     ↪ 매입채무 및 기타비유동채무(비유동) (유사도: 0.9801)
#
# 📌 종업원급여자산
#     ↪ 장기종업원급여 (유사도: 0.9913)
#     ↪ 종업원장기대여금 (유사도: 0.9889)
#     ↪ 종업원단기대여금 (유사도: 0.9885)
#     ↪ 장기성선급비용 (유사도: 0.9885)
#     ↪ 장기금융자산 (유사도: 0.9882)
#
# 📌 회사채
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 미수대매금
#     ↪ 미지급금 (유사도: 0.9820)
#     ↪ 대행미수금 (유사도: 0.9809)
#     ↪ 임대보증금 (유사도: 0.9796)
#     ↪ 미환급세금 (유사도: 0.9778)
#     ↪ 유동지급채무 (유사도: 0.9775)
#
# 📌 부의지분법이익잉여금
#     ↪ 미처분이익잉여금 (유사도: 0.9890)
#     ↪ 미수법인세환급액 (유사도: 0.9827)
#     ↪ 지배기업의 소유주지분 (유사도: 0.9827)
#     ↪ 비유동미지급법인세 (유사도: 0.9821)
#     ↪ 지분법적용기업투자 (유사도: 0.9815)
#
# 📌 유동성파생금융부채
#     ↪ 유동성장기금융부채 (유사도: 0.9969)
#     ↪ 유동성파생상품부채 (유사도: 0.9960)
#     ↪ 유동성기타금융부채 (유사도: 0.9955)
#     ↪ 유동성금융보증부채 (유사도: 0.9952)
#     ↪ 유동성복합금융부채 (유사도: 0.9942)
#
# 📌 기티비유동금융자산
#     ↪ 기타비유동금융자산 (유사도: 0.9989)
#     ↪ 기타유동비금융자산 (유사도: 0.9984)
#     ↪ 기타비유동비금융자산 (유사도: 0.9976)
#     ↪ 기타의 비유동금융자산 (유사도: 0.9968)
#     ↪ 기타비유동성금융자산 (유사도: 0.9964)
#
# 📌 비유동성채무상품
#     ↪ 비유동금융상품 (유사도: 0.9933)
#     ↪ 비유동성기타채무 (유사도: 0.9923)
#     ↪ 비유동파생상품부채 (유사도: 0.9901)
#     ↪ 비유동성차입금 (유사도: 0.9900)
#     ↪ 장기금융보증채무 (유사도: 0.9896)
#
# 📌 기타비유동부채(비유동)
#     ↪ 당기법인세부채(비유동) (유사도: 0.9934)
#     ↪ 기타충당부채(비유동) (유사도: 0.9925)
#     ↪ 기타금융부채(비유동) (유사도: 0.9922)
#     ↪ 기타지급채무(비유동) (유사도: 0.9889)
#     ↪ 복구충당부채(비유동) (유사도: 0.9879)
#
# 📌 유동성복구충당부채
#     ↪ 유동성금융보증부채 (유사도: 0.9950)
#     ↪ 유동성복합금융부채 (유사도: 0.9946)
#     ↪ 유동 법적소송충당부채 (유사도: 0.9941)
#     ↪ 비유동복구충당부채 (유사도: 0.9937)
#     ↪ 유동성통화선도부채 (유사도: 0.9933)
#
# 📌 당기손익-공정가치측정금융부채(유동)
#     ↪ 당기손익-공정가치 측정 금융부채(유동) (유사도: 0.9989)
#     ↪ 당기손익-공정가치 측정 금융부채(비유동) (유사도: 0.9978)
#     ↪ 당기손익-공정가치측정 금융자산(유동) (유사도: 0.9961)
#     ↪ 당기손익-공정가치측정금융자산(유동) (유사도: 0.9960)
#     ↪ 당기손익-공정가치 측정 금융자산(유동) (유사도: 0.9957)
#
# 📌 유동성수입보증금
#     ↪ 유동성임대보증금 (유사도: 0.9966)
#     ↪ 유동성 임대보증금 (유사도: 0.9943)
#     ↪ 유동성장기미지급금 (유사도: 0.9940)
#     ↪ 유동성장기차입금 (유사도: 0.9937)
#     ↪ 유동성이자부차입금 (유사도: 0.9936)
#
# 📌 기타장기지급채무
#     ↪ 기타장기급여채무 (유사도: 0.9966)
#     ↪ 기타유동지급채무 (유사도: 0.9955)
#     ↪ 단기기타지급채무 (유사도: 0.9953)
#     ↪ 장기기타지급채무 (유사도: 0.9944)
#     ↪ 기타비유동지급채무 (유사도: 0.9930)
#
# 📌 Ⅱ.비 유 동 자 산
#     ↪ Ⅰ.유 동 자 산 (유사도: 0.9910)
#     ↪ Ⅱ.비 유 동 부 채 (유사도: 0.9729)
#     ↪ 종속회사에 대한 주식 (유사도: 0.9665)
#     ↪ Ⅱ.비유동자산 (유사도: 0.9660)
#     ↪ Ⅱ. 비유동자산 (유사도: 0.9660)
#
# 📌 확정급여자산
#     ↪ 순급여확정자산 (유사도: 0.9887)
#     ↪ 순확정급여자산 (유사도: 0.9887)
#     ↪ 현금성자산 (유사도: 0.9865)
#     ↪ 순확정급여 자산 (유사도: 0.9863)
#     ↪ 순확정급여자 (유사도: 0.9861)
#
# 📌 퇴직급여부채
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 투자증권
#     ↪ 투자주식 (유사도: 0.9837)
#     ↪ 투자유가증권 (유사도: 0.9781)
#     ↪ 지분증권 (유사도: 0.9722)
#     ↪ 투자자산 (유사도: 0.9719)
#     ↪ 유가증권 (유사도: 0.9698)
#
# 📌 장기금융리스부채
#     ↪ 장기기타금융부채 (유사도: 0.9958)
#     ↪ 단기금융리스부채 (유사도: 0.9955)
#     ↪ 장기금융보증부채 (유사도: 0.9948)
#     ↪ 장기금융상품부채 (유사도: 0.9934)
#     ↪ 단기기타금융부채 (유사도: 0.9919)
#
# 📌 자기주식처분손익
#     ↪ 자기주식처분이익 (유사도: 0.9970)
#     ↪ 자기주식처분손실 (유사도: 0.9929)
#     ↪ 종소기업투자주식 (유사도: 0.9908)
#     ↪ 장기성미지급비용 (유사도: 0.9898)
#     ↪ 종속기업투자주식 (유사도: 0.9896)
#
# 📌 당기손익인식지정금융부채
#     ↪ 당기손익공정가치금융부채 (유사도: 0.9958)
#     ↪ 당기손익인식금융부채 (유사도: 0.9949)
#     ↪ 당기손익공정가치측정금융부채 (유사도: 0.9936)
#     ↪ 비유동당기손익인식금융부채 (유사도: 0.9926)
#     ↪ 유동당기손익인식금융부채 (유사도: 0.9924)
#
# 📌 보증금(유동)
#     ↪ 보증금(비유동) (유사도: 0.9850)
#     ↪ 차입금(유동) (유사도: 0.9842)
#     ↪ 차입금등(유동) (유사도: 0.9819)
#     ↪ 수입보증금(유동) (유사도: 0.9778)
#     ↪ 차입금(비유동) (유사도: 0.9775)
#
# 📌 4. 기타유동부채
#     ↪ 4.기타유동부채 (유사도: 1.0000)
#     ↪ 4. 기타비유동부채 (유사도: 0.9951)
#     ↪ 4. 기타유동자산 (유사도: 0.9728)
#     ↪ 4. 선급법인세 (유사도: 0.9718)
#     ↪ 4. 충당부채 (유사도: 0.9694)
#
# 📌 만기보유국공채
#     ↪ 단기지급보증부채 (유사도: 0.9896)
#     ↪ 단기복구충당부채 (유사도: 0.9884)
#     ↪ 기타장기금융부채 (유사도: 0.9878)
#     ↪ 장기비금융부채 (유사도: 0.9876)
#     ↪ 기타장기급여부채 (유사도: 0.9874)
#
# 📌 장기임차보증금
#     ↪ 장기임대보증금 (유사도: 0.9968)
#     ↪ 장기이자부차입금 (유사도: 0.9962)
#     ↪ 장기기타보증금 (유사도: 0.9961)
#     ↪ 장기수입보증금 (유사도: 0.9943)
#     ↪ 단기임차보증금 (유사도: 0.9943)
#
# 📌 유동기타포괄손익공정가치측정금융자산
#     ↪ 유동성당기손익-공정가치측정금융자산 (유사도: 0.9972)
#     ↪ 유동성기타포괄손익-공정가치 측정 금융자산 (유사도: 0.9970)
#     ↪ 비유동기타포괄손익 공정가치측정금융자산 (유사도: 0.9959)
#     ↪ 유동당기손익인식-공정가치측정금융자산 (유사도: 0.9956)
#     ↪ 유동당기손익공정가치측정금융자산 (유사도: 0.9955)
#
# 📌 연차수당부채
#     ↪ 연차충당부채 (유사도: 0.9959)
#     ↪ 유동충당부채 (유사도: 0.9862)
#     ↪ 기타 충당부채 (유사도: 0.9845)
#     ↪ 반품충당부채 (유사도: 0.9843)
#     ↪ 장기충당부채 (유사도: 0.9840)
#
# 📌 기타자본잉여금
#     ↪ 기타의자본잉여금 (유사도: 0.9947)
#     ↪ 기타의자본항목 (유사도: 0.9923)
#     ↪ 단기기타금융자 (유사도: 0.9918)
#     ↪ 장기기타보증금 (유사도: 0.9913)
#     ↪ 단기기타보증금 (유사도: 0.9911)
#
# 📌 장기매출채권 및 장기대출채권
#     ↪ 장기매출채권 및 기타비채권 (유사도: 0.9959)
#     ↪ 장기매출채권 및 기타비유동채권 (유사도: 0.9955)
#     ↪ 장기매출채권 및 비유동기타채권 (유사도: 0.9952)
#     ↪ 장기성매출채권 및 기타채권 (유사도: 0.9944)
#     ↪ 장기매출채권 및 기타채권 (유사도: 0.9917)
#
# 📌 이익잉여금
#     ↪ 기타잉여금 (유사도: 0.9899)
#     ↪ 이익준비금 (유사도: 0.9859)
#     ↪ Ⅴ. 이익잉여금 (유사도: 0.9805)
#     ↪ Ⅲ.이익잉여금 (유사도: 0.9805)
#     ↪ Ⅳ. 이익잉여금 (유사도: 0.9805)
#
# 📌 원재료
#     ↪ 배출권 (유사도: 0.9554)
#     ↪ 대출채권 (유사도: 0.9537)
#     ↪ 대여금 (유사도: 0.9521)
#     ↪ 부재료 (유사도: 0.9389)
#     ↪ 영업권 (유사도: 0.9376)
#
# 📌 기타채무(유동)
#     ↪ 기타부채(유동) (유사도: 0.9973)
#     ↪ 기타채무(비유동) (유사도: 0.9881)
#     ↪ 기타채권(유동) (유사도: 0.9872)
#     ↪ 기타부채(비유동) (유사도: 0.9869)
#     ↪ 충당부채(유동) (유사도: 0.9819)
#
# 📌 관계기업종속기업투자
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 유동확정계약부채
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 단기매입채무및기타채무
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 1.현금및현금성자산
#     ↪ 1.관계기업투자주식기타자본변동 (유사도: 1.0000)
#     ↪ 1. 퇴직급여부채 (유사도: 1.0000)
#     ↪ 1. 현금및현금성자산 (유사도: 1.0000)
#     ↪ (1) 현금및현금성자산 (유사도: 0.9329)
#     ↪ 2. 관계기업투자 (유사도: 0.8957)
#
# 📌 유동파생금융상품자산
#     ↪ 유동성파생금융상품자산 (유사도: 0.9974)
#     ↪ 유동성파생상품금융자산 (유사도: 0.9973)
#     ↪ 유동성파생금융자산 (유사도: 0.9950)
#     ↪ 유동성유가증권금융자산 (유사도: 0.9939)
#     ↪ 유동성기타금융자산 (유사도: 0.9936)
#
# 📌 리스부채
#     ↪ 리스 부채 (유사도: 0.9928)
#     ↪ 차입부채 (유사도: 0.9790)
#     ↪ 유동부채 (유사도: 0.9778)
#     ↪ 리스채권 (유사도: 0.9757)
#     ↪ 파생부채 (유사도: 0.9751)
#
# 📌 유동성임대보증금
#     ↪ 유동성 임대보증금 (유사도: 0.9977)
#     ↪ 유동성수입보증금 (유사도: 0.9966)
#     ↪ 유동임대보증금 (유사도: 0.9937)
#     ↪ 비유동임대보증금 (유사도: 0.9934)
#     ↪ 유동성장기임대보증금 (유사도: 0.9934)
#
# 📌 신주인수권부사채상환할증금
#     ↪ 신주인수권부사채할인발행차금 (유사도: 0.9970)
#     ↪ 신주인수권부사채상환할증 (유사도: 0.9960)
#     ↪ 상환우선주부채상환할증금 (유사도: 0.9928)
#     ↪ 단기상각후원가측정채무상품 (유사도: 0.9887)
#     ↪ 상각후원가측정금융자산 (유사도: 0.9875)
#
# 📌 반품재고회수(비유동)
#     ↪ 매출채권및상각후원가측정금융자산(비유동) (유사도: 1.0000)
#     ↪ 매입채무및기타채무(비유동) (유사도: 1.0000)
#     ↪ 차입금및사채(비유동) (유사도: 1.0000)
#     ↪ 계약부채(비유동) (유사도: 1.0000)
#     ↪ 계약자산(비유동) (유사도: 1.0000)
#
# 📌 리스사용권자산
#     ↪ 리스사용권 자산 (유사도: 0.9966)
#     ↪ 기타사용권자산 (유사도: 0.9928)
#     ↪ 비유동사용권자산 (유사도: 0.9905)
#     ↪ 방송콘텐츠자산 (유사도: 0.9895)
#     ↪ 비유동기타자산 (유사도: 0.9893)
#
# 📌 사용권자산상각누계
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 차량운반구감가상각누계액
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 유동파생상품자산
#     ↪ 유동 파생상품자산 (유사도: 0.9983)
#     ↪ 유동성파생상품자산 (유사도: 0.9966)
#     ↪ 유동파생금융자산 (유사도: 0.9959)
#     ↪ 비유동파생상품자산 (유사도: 0.9936)
#     ↪ 유동성파생금융자산 (유사도: 0.9930)
#
# 📌 비융동성이연법인세자산
#     ↪ 비유동이연법인세자산 (유사도: 0.9947)
#     ↪ 비유동성유가증권금융자산 (유사도: 0.9903)
#     ↪ 비유동성파생상품금융자산 (유사도: 0.9901)
#     ↪ 비유동만기보유금융자산 (유사도: 0.9898)
#     ↪ 당기손익측정금융자산 (유사도: 0.9898)
#
# 📌 소송충당 부채
#     ↪ 소송충당부채 (유사도: 0.9969)
#     ↪ 손실충당부채 (유사도: 0.9896)
#     ↪ 비유동성 사채 (유사도: 0.9869)
#     ↪ 장기충당부채 (유사도: 0.9853)
#     ↪ 보증충당부채 (유사도: 0.9850)
#
# 📌 대손충당금, 단기미수금
#     ↪ 대손충당금, 단기선급금 (유사도: 0.9976)
#     ↪ 대손충당금, 단기대여금 (유사도: 0.9973)
#     ↪ 대손충당금, 단기미수수익 (유사도: 0.9947)
#     ↪ 대손충당금, 단기선급비용 (유사도: 0.9931)
#     ↪ 대손충당금, 장기임차보증금 (유사도: 0.9908)
#
# 📌 기타
#     ↪ 기말 (유사도: 0.9667)
#     ↪ 단기 (유사도: 0.9447)
#     ↪ 장기 매출채권및기타채권 (유사도: 0.9349)
#     ↪ 기타 수취 채권 (유사도: 0.9302)
#     ↪ 개발비 (유사도: 0.9300)
#
# 📌 당기손익 공정가치측정 금융부채
#     ↪ 당기손익 공정가치 측정 금융부채 (유사도: 0.9997)
#     ↪ 당기손익공정가치측정금융부채 (유사도: 0.9979)
#     ↪ 당기손익-공정가치측정 금융부채 (유사도: 0.9978)
#     ↪ 당기손익-공정가치 측정 금융부채 (유사도: 0.9977)
#     ↪ 당기손익-공정가치측정금융부채 (유사도: 0.9971)
#
# 📌 유형자산(주석 13)
#     ↪ 영업권 이외의 무형자산(주석 14) (유사도: 0.9631)
#     ↪ 사용권자산(주석 15) (유사도: 0.9610)
#     ↪ 기타유동자산(주석 12) (유사도: 0.9536)
#     ↪ 재고자산(주석 11) (유사도: 0.9523)
#     ↪ 전환사채(유동) (유사도: 0.9427)
#
# 📌 예수금
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 유동성장기채무
#     ↪ 유동성기타채무 (유사도: 0.9960)
#     ↪ 유동성장기부채 (유사도: 0.9940)
#     ↪ 유동성장기채권 (유사도: 0.9927)
#     ↪ 유동성 장기부채 (유사도: 0.9924)
#     ↪ 유동성기타채권 (유사도: 0.9922)
#
# 📌 기타포괄손익-공정가치 측정 지분상품 투자
#     ↪ 기타포괄손익-공정가치 측정 지정 지분상품 (유사도: 0.9984)
#     ↪ 기타포괄손익-공정가치 측정 지정 금융자산 (유사도: 0.9972)
#     ↪ 기타포괄손익-공정가치측정금융상품 (유사도: 0.9968)
#     ↪ 기타포괄손익-공정가치측정 금융상품 (유사도: 0.9966)
#     ↪ 기타포괄손익-공정가치측정지분상품 (유사도: 0.9958)
#
# 📌 선급용역원가
#     ↪ 선급공사원가 (유사도: 0.9852)
#     ↪ 순확정급여자 (유사도: 0.9838)
#     ↪ 순급여확정자산 (유사도: 0.9813)
#     ↪ 선급부가가치세 (유사도: 0.9809)
#     ↪ 순확정급여자산 (유사도: 0.9797)
#
# 📌 기타포괄-공정가치 측정 지분증권
#     ↪ 기타포괄-공정가치 측정 금융자산 (유사도: 0.9974)
#     ↪ 기타포괄-공정가치측정 금융자산 (유사도: 0.9971)
#     ↪ 기타포괄-공정가치측정금융자산 (유사도: 0.9956)
#     ↪ 기타포괄손익-공정가치 측정 (유사도: 0.9933)
#     ↪ 기타포괄손익-공정가치금융자 (유사도: 0.9928)
#
# 📌 매입채무 및 기타부채
#     ↪ 매입채무 및 기타채무 (유사도: 0.9963)
#     ↪ 매입채무 및 지급채무 (유사도: 0.9912)
#     ↪ 매입채무 및 기타유동부채 (유사도: 0.9902)
#     ↪ 매입채무 및 기타유동채무 (유사도: 0.9892)
#     ↪ 매입채무기타채무 (유사도: 0.9887)
#
# 📌 추심예수금
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 3. 확정급여채무
#     ↪ 확정급여채무 (유사도: 0.9561)
#     ↪ 3. 매출채권 (유사도: 0.9559)
#     ↪ 3.매출채권 (유사도: 0.9559)
#     ↪ 3.유동리스부채 (유사도: 0.9536)
#     ↪ 3. 기타금융부채 (유사도: 0.9513)
#
# 📌 장기차입부채
#     ↪ 단기차입부채 (유사도: 0.9941)
#     ↪ 장기기타부채 (유사도: 0.9941)
#     ↪ 장기리스부채 (유사도: 0.9934)
#     ↪ 장기 리스부채 (유사도: 0.9925)
#     ↪ 장기충당부채 (유사도: 0.9914)
#
# 📌 유동성장기채권
#     ↪ 유동성기타채권 (유사도: 0.9960)
#     ↪ 유동성장기차입 (유사도: 0.9932)
#     ↪ 유동성장기채무 (유사도: 0.9927)
#     ↪ 유동성리스채권 (유사도: 0.9925)
#     ↪ 유동성 리스채권 (유사도: 0.9920)
#
# 📌 종속기업 및 관계기업투자자산
#     ↪ 종속기업 및 관계기업주식 (유사도: 1.0000)
#     ↪ 종속기업 및 관계기업투자지분 (유사도: 1.0000)
#     ↪ 종속기업 및 관계기업투자 (유사도: 1.0000)
#     ↪ 종속기업 및 관계기업투자주식 (유사도: 1.0000)
#     ↪ 종속기업,공동기업및관계기업투자 (유사도: 0.9909)
#
# 📌 반품제품회권
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 기타상각후원가측정금융자산
#     ↪ 단기상각후원가측정금융자산 (유사도: 0.9978)
#     ↪ 단기 상각후원가측정금융자산 (유사도: 0.9969)
#     ↪ 장기상각후원가측정금융자산 (유사도: 0.9963)
#     ↪ 기타 상각후원가 측정 금융자산 (유사도: 0.9958)
#     ↪ 단기상각후원가측정유가증권 (유사도: 0.9951)
#
# 📌 비유동기타부채
#     ↪ 비유동리스부채 (유사도: 0.9953)
#     ↪ 비유동기타채무 (유사도: 0.9946)
#     ↪ 비유동차입부채 (유사도: 0.9946)
#     ↪ 비유동 리스부채 (유사도: 0.9941)
#     ↪ 기타비유동부채 (유사도: 0.9940)
#
# 📌 리스비유동채권
#     ↪ 리스유동채권 (유사도: 0.9958)
#     ↪ 비유동리스채권 (유사도: 0.9952)
#     ↪ 비유동기타채권 (유사도: 0.9931)
#     ↪ 리스채권_비유동 (유사도: 0.9928)
#     ↪ 비유동대출채권 (유사도: 0.9910)
#
# 📌 기타포괄손익-공정가치비유동금융자산
#     ↪ 기타포괄손익-공정가치측정금융자산 (유사도: 0.9986)
#     ↪ 기타포괄손익_공정가치측정금융자산 (유사도: 0.9978)
#     ↪ 비유동기타포괄손익-공정가치금융자산 (유사도: 0.9974)
#     ↪ 기타포괄손익공정가치측정금융자산 (유사도: 0.9973)
#     ↪ 기타포괄손익공정자치측정금융자산 (유사도: 0.9972)
#
# 📌 통화선도
#     ↪ 종속기업 (유사도: 0.9720)
#     ↪ 통화선도부채 (유사도: 0.9719)
#     ↪ 통화선도자산 (유사도: 0.9680)
#     ↪ 복구자산 (유사도: 0.9672)
#     ↪ 공동기업 (유사도: 0.9667)
#
# 📌 비유동 공정가치 의무 측정 금융자산
#     ↪ 유동 공정가치 의무 측정 금융자산 (유사도: 0.9950)
#     ↪ 비유동 공정가치측정 금융자산 (유사도: 0.9937)
#     ↪ 비유동 상각후원가 측정 금융자산 (유사도: 0.9915)
#     ↪ 비유동 상각후원가 측정 금융부채 (유사도: 0.9913)
#     ↪ 비유동 당기손익-공정가치금융부채 (유사도: 0.9907)
#
# 📌 유동차입금
#     ↪ 유동 차입금 (유사도: 0.9975)
#     ↪ 유동성차입금 (유사도: 0.9925)
#     ↪ 유동기타채무 (유사도: 0.9898)
#     ↪ 유동보증금 (유사도: 0.9892)
#     ↪ 유동차입부채 (유사도: 0.9890)
#
# 📌 장기미지급금 및 기타채무
#     ↪ 장기미지급금 및 기타부채 (유사도: 0.9960)
#     ↪ 단기미지급금 및 기타채무 (유사도: 0.9951)
#     ↪ 장기대여금 및 기타미수금 (유사도: 0.9940)
#     ↪ 장기미수금 및 기타채권 (유사도: 0.9931)
#     ↪ 장기매입채무 및 기타지급채무 (유사도: 0.9928)
#
# 📌 유동이연법인세자산
#     ↪ 유동이자율스왑자산 (유사도: 0.9947)
#     ↪ 비유이연법인세자산 (유사도: 0.9946)
#     ↪ 비유동이연법인세자산 (유사도: 0.9941)
#     ↪ 유동성기타금융자산 (유사도: 0.9912)
#     ↪ 유동기타비금융자산 (유사도: 0.9911)
#
# 📌 조인트벤처에 대한 투자자산
#     ↪ 조인트벤처와 관계기업에 대한 투자자산 (유사도: 0.9934)
#     ↪ 종속기업에 대한 투자자산 (유사도: 0.9900)
#     ↪ 종속기업등에 대한 투자자산 (유사도: 0.9889)
#     ↪ 종속기업 등에 대한 투자자산 (유사도: 0.9887)
#     ↪ 종속기업에대한투자자산 (유사도: 0.9883)
#
# 📌 순확정급여부채및기타장기급여부채
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 제품보증충당부채
#     ↪ 지급보증충당부채 (유사도: 0.9909)
#     ↪ 판매보증충당부채 (유사도: 0.9855)
#     ↪ 전환우선주금융부채 (유사도: 0.9844)
#     ↪ 전환권대가금융부채 (유사도: 0.9839)
#     ↪ 유동복구충당부채 (유사도: 0.9825)
#
# 📌 비유동 당기손익-공정가치측정 금융자산
#     ↪ 비유동 당기손익-공정가치 측정 금융자산 (유사도: 0.9998)
#     ↪ 비유동 당기손익-공정가치 측정  금융자산 (유사도: 0.9998)
#     ↪ 비유동당기손익-공정가치 측정 금융자산 (유사도: 0.9996)
#     ↪ 비유동 당기손익-공정가치측정금융자산 (유사도: 0.9996)
#     ↪ 비유동당기손익-공정가치측정금융자산 (유사도: 0.9988)
#
# 📌 기타 유동부채
#     ↪ 기타유동부채 (유사도: 0.9956)
#     ↪ 유동기타채무 (유사도: 0.9924)
#     ↪ 기타 충당부채 (유사도: 0.9922)
#     ↪ 기타유동채무 (유사도: 0.9919)
#     ↪ 유동장기부채 (유사도: 0.9910)
#
# 📌 감가상각누계액, 차량운반구
#     ↪ 감가상각누계액, 기계장치 (유사도: 1.0000)
#     ↪ 부채및자본 총계 (유사도: 0.9775)
#     ↪ Ⅲ. 기타포괄손익누계액 (유사도: 0.9710)
#     ↪ Ⅲ.기타포괄손익누계액 (유사도: 0.9710)
#     ↪ Ⅳ. 기타포괄손익누계액 (유사도: 0.9710)
#
# 📌 기타 자본구성
#     ↪ 기타무형자산 (유사도: 0.9917)
#     ↪ 기타자본 항목 (유사도: 0.9884)
#     ↪ 기타금융 자산 (유사도: 0.9872)
#     ↪ 기타의 자본조정 (유사도: 0.9864)
#     ↪ 기타장기채무 (유사도: 0.9864)
#
# 📌 이연수익
#     ↪ 시설이용권 (유사도: 0.9748)
#     ↪ 신주인수권 (유사도: 0.9736)
#     ↪ 선수수익 (유사도: 0.9727)
#     ↪ 이익잉여금 (유사도: 0.9709)
#     ↪ 실용신안권 (유사도: 0.9679)
#
# 📌 통화스왑파생부채
#     ↪ 유동파생상품부채 (유사도: 0.9877)
#     ↪ 파생상품평가부채 (유사도: 0.9875)
#     ↪ 장기급여충당부채 (유사도: 0.9874)
#     ↪ 유동파생금융부채 (유사도: 0.9869)
#     ↪ 장기파생금융부채 (유사도: 0.9868)
#
# 📌 매각예정처분자산
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 유동배출권
#     ↪ 유동매출채권 (유사도: 0.9939)
#     ↪ 유동성배출권 (유사도: 0.9898)
#     ↪ 유동기타채무 (유사도: 0.9881)
#     ↪ 유동배출부채 (유사도: 0.9878)
#     ↪ 유동지급채무 (유사도: 0.9873)
#
# 📌 기타포괄손익-공정가치측정금융상품
#     ↪ 기타포괄손익-공정가치측정 금융상품 (유사도: 0.9993)
#     ↪ 기타포괄손익-공정가치측정지분상품 (유사도: 0.9981)
#     ↪ 기타포괄손익공정가치측정지분상품 (유사도: 0.9969)
#     ↪ 기타포괄손익-공정가치 측정 지분상품 투자 (유사도: 0.9968)
#     ↪ 기타포괄손익-공정가치 측정 지정 지분상품 (유사도: 0.9966)
#
# 📌 종속회사 및 관계회사 투자
#     ↪ 종속회사 투자 (유사도: 0.9754)
#     ↪ 관계기업 투자 (유사도: 0.9754)
#     ↪ 종속기업및관계기업 투자 (유사도: 0.9754)
#     ↪ 자본 및 부채총계 (유사도: 0.9292)
#     ↪ 계약 자산 (유사도: 0.9259)
#
# 📌 7.관계기업투자
#     ↪ 7. 부가가치세예수금 (유사도: 1.0000)
#     ↪ 6. 예수금 (유사도: 0.8448)
#     ↪ 9.사외적립자산 (유사도: 0.8363)
#     ↪ 9. 계약부채 (유사도: 0.8363)
#     ↪ 5.부가세예수금 (유사도: 0.8169)
#
# 📌 퇴직연금초과금
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 퇴직급여부채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#
# 📌 선물거래예치금
#     ↪ 종속및관계기업투자자산 (유사도: 1.0000)
#     ↪ 장기매출채권및기타채권 (유사도: 1.0000)
#     ↪ 회사채 (유사도: 1.0000)
#     ↪ 관계기업종속기업투자 (유사도: 1.0000)
#     ↪ 유동확정계약부채 (유사도: 1.0000)
#
# 📌 자산재평가적립금
#     ↪ 재고자산평가충당금 (유사도: 0.9931)
#     ↪ 장기파생금융상품 (유사도: 0.9912)
#     ↪ 장기성기타지급채무 (유사도: 0.9903)
#     ↪ 장기금융보증채무 (유사도: 0.9892)
#     ↪ 종업원장기대여금 (유사도: 0.9888)
#
# 📌 장기미지급금 및 기타부채
#     ↪ 장기미지급금 및 기타채무 (유사도: 0.9960)
#     ↪ 장기차입금 및 장기리스부채 (유사도: 0.9933)
#     ↪ 장기미수금 및 기타채권 (유사도: 0.9927)
#     ↪ 장기차입금 및 기타금융부채 (유사도: 0.9927)
#     ↪ 장기대여금 및 기타미수금 (유사도: 0.9917)

# %%
from sentence_transformers import SentenceTransformer, util
import torch

# 1. 모델 불러오기 (Ko-SBERT, GPU 사용)
model = SentenceTransformer('jhgan/ko-sbert-sts')
model = model.to('cuda')  # GPU 사용

# 2. unique_items 리스트 임베딩
embeddings = model.encode(unique_items, convert_to_tensor=True, device='cuda')

# 3. 각 항목별 유사도 Top 50 추출
similarities = []
for idx, name in enumerate(unique_items):
    query_embedding = embeddings[idx]
    sim_scores = util.pytorch_cos_sim(query_embedding, embeddings)[0]
    top_results = torch.topk(sim_scores, k=101)  # 자기 자신 포함
    similar_items = []
    for score, i in zip(top_results[0], top_results[1]):
        if i != idx:
            similar_items.append((unique_items[i], float(score)))
        if len(similar_items) == 50:
            break
    similarities.append({'항목명': name, '유사항목(Top50)': similar_items})

# 4. 상위 100개 항목에 대해 결과 출력
for s in similarities[:100]:
    print(f"\n📌 {s['항목명']}")
    for sim_item, score in s['유사항목(Top50)'][:5]:  # 상위 5개만 표시
        print(f"    ↪ {sim_item} (유사도: {score:.4f})")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 📌 종속및관계기업투자자산
#     ↪ 종속기업및관계기업투자자산 (유사도: 0.9635)
#     ↪ 종속및관계기업투자 (유사도: 0.9468)
#     ↪ 종속,관계기업투자자산 (유사도: 0.9366)
#     ↪ 종속및관계기업 투자자산 (유사도: 0.9324)
#     ↪ 종속및관계기업투자주식 (유사도: 0.9298)
#
# 📌 비유동금융부채
#     ↪ 비유동비금융부채 (유사도: 0.9728)
#     ↪ 비유동기타금융부채 (유사도: 0.9623)
#     ↪ 비유동금융리스부채 (유사도: 0.9453)
#     ↪ 비유동금융보증부채 (유사도: 0.9400)
#     ↪ 비유동성금융리스부채 (유사도: 0.9302)
#
# 📌 장기매출채권및기타채권
#     ↪ 장기성매출채권및기타채권 (유사도: 0.9804)
#     ↪ 장기매출채권및기타수취채권 (유사도: 0.9802)
#     ↪ 장기매출채권및기타비유동채권 (유사도: 0.9343)
#     ↪ 장기매출채권 및 기타채권 (유사도: 0.9152)
#     ↪ 장기매출채권 및 장기대출채권 (유사도: 0.9126)
#
# 📌 기타포괄손익-공정가치측정평가이익
#     ↪ 기타포괄손익-공정가치평가손익 (유사도: 0.9590)
#     ↪ 기타포괄손익-공정가치측정지분상품 (유사도: 0.9361)
#     ↪ 기타포괄손익 -공정가치측정 금융자산평가손익 (유사도: 0.9259)
#     ↪ 기타포괄손익-공정가치측정금융자산평가이익 (유사도: 0.9255)
#     ↪ 기타포괄손익-공정가치측정 금융상품 평가손익 (유사도: 0.9168)
#
# 📌 기타금융자산(유동)
#     ↪ 기타자산(유동) (유사도: 0.9516)
#     ↪ 기타금융부채(유동) (유사도: 0.8973)
#     ↪ 기타유동성금융자산 (유사도: 0.8752)
#     ↪ 기타금융 자산 (유사도: 0.8711)
#     ↪ 기타채권(유동) (유사도: 0.8634)
#
# 📌 비유동리스채권
#     ↪ 비유동금융리스채권 (유사도: 0.9693)
#     ↪ 비유동성리스채권 (유사도: 0.9669)
#     ↪ 비유동리스자산 (유사도: 0.9312)
#     ↪ 금융리스채권(비유동) (유사도: 0.9167)
#     ↪ 비유동리스부채 (유사도: 0.9158)
#
# 📌 기타포괄-공정가치 측정 금융자산
#     ↪ 기타포괄-공정가치측정 금융자산 (유사도: 0.9653)
#     ↪ 기타포괄손익-공정가치 측정 금융자산 (유사도: 0.9374)
#     ↪ 기타포괄손익 -  공정가치 측정 금융자산 (유사도: 0.9374)
#     ↪ 기타포괄손익-공정가치측정 금융자산 (유사도: 0.9291)
#     ↪ 기타포괄-공정가치측정금융자산 (유사도: 0.9258)
#
# 📌 비유동생물자산
#     ↪ 비유동성계약자산 (유사도: 0.8549)
#     ↪ 비유동계약자산 (유사도: 0.8451)
#     ↪ 비유동성금융자산 (유사도: 0.8348)
#     ↪ 비유동성유가증권금융자산 (유사도: 0.8308)
#     ↪ 비유동확정계약자산 (유사도: 0.8169)
#
# 📌 1. 퇴직급여부채
#     ↪ 퇴직급여부채 (유사도: 0.9452)
#     ↪ 퇴직급여채무 (유사도: 0.8953)
#     ↪ 퇴직급여충당부채 (유사도: 0.8910)
#     ↪ 퇴직급여 순채무 (유사도: 0.8523)
#     ↪ 확정퇴직급여부채 (유사도: 0.8352)
#
# 📌 종속ㆍ관계기업 투자주식
#     ↪ 종속및관계기업투자주식 (유사도: 0.9423)
#     ↪ 종속 및 관계기업투자주식 (유사도: 0.9407)
#     ↪ 종속기업, 관계기업투자주식 (유사도: 0.9395)
#     ↪ 종속기업 투자주식 (유사도: 0.9369)
#     ↪ 종속기업 및 관계기업투자주식 (유사도: 0.9345)
#
# 📌 비유동성파생상품부채
#     ↪ 비유동파생상품부채 (유사도: 0.9675)
#     ↪ 비유동파생부채 (유사도: 0.8698)
#     ↪ 비유동성파생상품자산 (유사도: 0.8677)
#     ↪ 비유동성파생상품금융자산 (유사도: 0.8516)
#     ↪ 비유동성채무상품 (유사도: 0.8407)
#
# 📌 미처분이익잉여금(미처리결손금)
#     ↪ 이익잉여금(미처리결손금) (유사도: 0.9016)
#     ↪ 미처분이익잉여금 (유사도: 0.8797)
#     ↪ 미처분이익잉여금(결손금) (유사도: 0.8633)
#     ↪ 5. 미처분이익잉여금 (유사도: 0.8302)
#     ↪ 미처리결손금 (유사도: 0.7734)
#
# 📌 종업원급여자산
#     ↪ 종업원급여충당부채 (유사도: 0.8471)
#     ↪ 종업원급여채무 (유사도: 0.8296)
#     ↪ 종업원급여부채 (유사도: 0.8250)
#     ↪ 종업원급여부채(유동) (유사도: 0.7684)
#     ↪ 종업원대여금 (유사도: 0.7414)
#
# 📌 회사채
#     ↪ 유동성 회사채 (유사도: 0.8104)
#     ↪ 유동사채 (유사도: 0.7786)
#     ↪ 유동 전환사채 (유사도: 0.7455)
#     ↪ 사채(유동) (유사도: 0.7375)
#     ↪ 사채 (유사도: 0.7346)
#
# 📌 미수대매금
#     ↪ 미수금 (유사도: 0.8843)
#     ↪ 미수금및기타채권 (유사도: 0.7855)
#     ↪ 미수금및기타수취채권 (유사도: 0.7809)
#     ↪ 미수금및수취채권 (유사도: 0.7746)
#     ↪ 미수수익 (유사도: 0.7552)
#
# 📌 부의지분법이익잉여금
#     ↪ 이익잉여금 (유사도: 0.7142)
#     ↪ Ⅴ. 이익잉여금 (유사도: 0.7077)
#     ↪ Ⅴ.이익잉여금 (유사도: 0.7077)
#     ↪ Ⅳ.이익잉여금 (유사도: 0.7077)
#     ↪ Ⅳ. 이익잉여금 (유사도: 0.7077)
#
# 📌 유동성파생금융부채
#     ↪ 유동파생금융부채 (유사도: 0.9778)
#     ↪ 유동성파생상품금융부채 (유사도: 0.9623)
#     ↪ 유동성파생금융상품부채 (유사도: 0.9613)
#     ↪ 유동성파생금융자산 (유사도: 0.9378)
#     ↪ 유동성금융부채 (유사도: 0.9192)
#
# 📌 기티비유동금융자산
#     ↪ 비유동기타비금융자산 (유사도: 0.8350)
#     ↪ 비유동기타금융자산 (유사도: 0.8263)
#     ↪ 투자비유동금융자산 (유사도: 0.8132)
#     ↪ 비유동비금융자산 (유사도: 0.7921)
#     ↪ 비유동성금융자산 (유사도: 0.7910)
#
# 📌 비유동성채무상품
#     ↪ 비유동성파생상품부채 (유사도: 0.8407)
#     ↪ 비유동파생상품부채 (유사도: 0.8221)
#     ↪ 비유동채무 (유사도: 0.8162)
#     ↪ 비유동성충당부채 (유사도: 0.8092)
#     ↪ 비유동기타지급채무 (유사도: 0.8033)
#
# 📌 기타비유동부채(비유동)
#     ↪ 기타부채(비유동) (유사도: 0.8834)
#     ↪ 기타비유동부채 (유사도: 0.8783)
#     ↪ 기타비유동부채. (유사도: 0.8678)
#     ↪ 기타충당부채(비유동) (유사도: 0.8629)
#     ↪ 매입채무 및 기타비유동채무(비유동) (유사도: 0.8612)
#
# 📌 유동성복구충당부채
#     ↪ 유동복구충당부채 (유사도: 0.9810)
#     ↪ 유동성충당부채 (유사도: 0.9400)
#     ↪ 유동충당부채 (유사도: 0.9217)
#     ↪ 유동성하자보수충당부채 (유사도: 0.9112)
#     ↪ 유동연차충당부채 (유사도: 0.9105)
#
# 📌 당기손익-공정가치측정금융부채(유동)
#     ↪ 당기손익-공정가치금융부채(유동) (유사도: 0.9715)
#     ↪ 당기손익-공정가치측정금융자산(유동) (유사도: 0.9694)
#     ↪ 당기손익-공정가치 금융부채(유동) (유사도: 0.9527)
#     ↪ 당기손익-공정가치금융자산(유동) (유사도: 0.9470)
#     ↪ 유동성 당기손익-공정가치측정 금융부채 (유사도: 0.9436)
#
# 📌 유동성수입보증금
#     ↪ 유동성보증금 (유사도: 0.9586)
#     ↪ 유동성예수보증금 (유사도: 0.9555)
#     ↪ 유동보증금 (유사도: 0.9338)
#     ↪ 유동성보증 (유사도: 0.9153)
#     ↪ 유동성임대보증금 (유사도: 0.9034)
#
# 📌 기타장기지급채무
#     ↪ 기타지급채무 (유사도: 0.8152)
#     ↪ 기타장기급여채무 (유사도: 0.7682)
#     ↪ 기타장기급여부채 (유사도: 0.7307)
#     ↪ 기타장기충당부채 (유사도: 0.7247)
#     ↪ 기타유동지급채무 (유사도: 0.7239)
#
# 📌 Ⅱ.비 유 동 자 산
#     ↪ Ⅰ.유 동 자 산 (유사도: 0.8512)
#     ↪ Ⅱ.비 유 동 부 채 (유사도: 0.7558)
#     ↪ 자               산 (유사도: 0.6865)
#     ↪ 자 산 (유사도: 0.6865)
#     ↪ 자 산 총 계 (유사도: 0.6105)
#
# 📌 확정급여자산
#     ↪ 확정계약자산 (유사도: 0.8607)
#     ↪ 순급여확정자산 (유사도: 0.8551)
#     ↪ 퇴직급여자산 (유사도: 0.8493)
#     ↪ 확정계약평가자산 (유사도: 0.8362)
#     ↪ 순확정급여자산 (유사도: 0.8294)
#
# 📌 퇴직급여부채
#     ↪ 1. 퇴직급여부채 (유사도: 0.9452)
#     ↪ 퇴직급여충당부채 (유사도: 0.9405)
#     ↪ 퇴직급여채무 (유사도: 0.9389)
#     ↪ 퇴직급여 순채무 (유사도: 0.8880)
#     ↪ 확정퇴직급여부채 (유사도: 0.8865)
#
# 📌 투자증권
#     ↪ 투자유가증권 (유사도: 0.8431)
#     ↪ 투자금융자산 (유사도: 0.8195)
#     ↪ 장기투자금융자산 (유사도: 0.7745)
#     ↪ 단기투자금융자산 (유사도: 0.7682)
#     ↪ 사모투자자산 (유사도: 0.7609)
#
# 📌 장기금융리스부채
#     ↪ 장기리스부채 (유사도: 0.9442)
#     ↪ 단기금융리스부채 (유사도: 0.9392)
#     ↪ 장기성리스부채 (유사도: 0.9316)
#     ↪ 금융리스부채 (유사도: 0.9248)
#     ↪ 장기금융부채 (유사도: 0.9170)
#
# 📌 자기주식처분손익
#     ↪ 자기주식처분이익 (유사도: 0.9535)
#     ↪ 자기주식처분손실 (유사도: 0.8977)
#     ↪ 신주인수권처분이익 (유사도: 0.7505)
#     ↪ 자기주식의 취득 (유사도: 0.7498)
#     ↪ 지분법기타포괄손익변동 (유사도: 0.7335)
#
# 📌 당기손익인식지정금융부채
#     ↪ 당기손익인식금융부채 (유사도: 0.9647)
#     ↪ 당기손익인식금융자산 (유사도: 0.9272)
#     ↪ 당기손익인식측정금융자산 (유사도: 0.9044)
#     ↪ 당기손익인식가치금융자산 (유사도: 0.9027)
#     ↪ 당기손익금융자산 (유사도: 0.8690)
#
# 📌 보증금(유동)
#     ↪ 임차보증금(유동) (유사도: 0.8241)
#     ↪ 수입보증금(유동) (유사도: 0.8051)
#     ↪ 유동임대보증금 (유사도: 0.7939)
#     ↪ 보증금 (유사도: 0.7916)
#     ↪ 유동보증금 (유사도: 0.7828)
#
# 📌 4. 기타유동부채
#     ↪ 4.기타유동부채 (유사도: 1.0000)
#     ↪ 4. 기타비유동부채 (유사도: 0.9652)
#     ↪ 3. 기타유동부채 (유사도: 0.9016)
#     ↪ 기타유동부채 (유사도: 0.8825)
#     ↪ 기타비유동부채 (유사도: 0.8620)
#
# 📌 만기보유국공채
#     ↪ 유동만기보유국공채 (유사도: 0.8901)
#     ↪ 만기보유금융자산 (유사도: 0.6425)
#     ↪ 금융보증추정부채 (유사도: 0.6083)
#     ↪ 보증충당부채 (유사도: 0.6066)
#     ↪ 장기공연투자자산 (유사도: 0.6025)
#
# 📌 장기임차보증금
#     ↪ 단기임차보증금 (유사도: 0.9559)
#     ↪ 장기임대보증금 (유사도: 0.9330)
#     ↪ 단기임대보증금 (유사도: 0.8909)
#     ↪ 장기보증금 (유사도: 0.8730)
#     ↪ 임차보증금 (유사도: 0.8256)
#
# 📌 유동기타포괄손익공정가치측정금융자산
#     ↪ 유동공정가치측정금융자산 (유사도: 0.9159)
#     ↪ 유동당기손익공정가치측정금융자산 (유사도: 0.9126)
#     ↪ 유동성공정가치측정금융자산 (유사도: 0.9101)
#     ↪ 단기기타포괄손익-공정가치측정금융자산 (유사도: 0.9099)
#     ↪ 비유동기타포괄손익공정가치측정금융자산 (유사도: 0.9048)
#
# 📌 연차수당부채
#     ↪ 연차충당부채 (유사도: 0.9225)
#     ↪ 확정급여부채 (유사도: 0.7081)
#     ↪ 장기급여충당부채 (유사도: 0.6943)
#     ↪ 급여부채 (유사도: 0.6931)
#     ↪ 확정급여부채. (유사도: 0.6884)
#
# 📌 기타자본잉여금
#     ↪ 기타의자본잉여금 (유사도: 0.9196)
#     ↪ 기타불입자금 (유사도: 0.7656)
#     ↪ 기타자본잉여금(주석 20) (유사도: 0.7580)
#     ↪ 기타잉여금 (유사도: 0.7468)
#     ↪ 기타적립금 (유사도: 0.7311)
#
# 📌 장기매출채권 및 장기대출채권
#     ↪ 장기매출채권 등 (유사도: 0.9171)
#     ↪ 장기매출채권 (유사도: 0.9139)
#     ↪ 장기매출채권및기타채권 (유사도: 0.9126)
#     ↪ 1. 장기매출채권 (유사도: 0.9077)
#     ↪ 장기매출채권및기타수취채권 (유사도: 0.9043)
#
# 📌 이익잉여금
#     ↪ Ⅴ. 이익잉여금 (유사도: 0.9431)
#     ↪ Ⅳ. 이익잉여금 (유사도: 0.9431)
#     ↪ Ⅴ.이익잉여금 (유사도: 0.9431)
#     ↪ Ⅳ.이익잉여금 (유사도: 0.9431)
#     ↪ ll. 이익잉여금 (유사도: 0.9087)
#
# 📌 원재료
#     ↪ 음식원재료 (유사도: 0.6064)
#     ↪ 제품 (유사도: 0.5778)
#     ↪ 미착원재료 (유사도: 0.5606)
#     ↪ 반제품 (유사도: 0.4853)
#     ↪ 부재료 (유사도: 0.4841)
#
# 📌 기타채무(유동)
#     ↪ 기타부채(유동) (유사도: 0.9009)
#     ↪ 기타지급채무(유동) (유사도: 0.8999)
#     ↪ 기타금융부채(유동) (유사도: 0.8512)
#     ↪ 기타수취채권(유동) (유사도: 0.8386)
#     ↪ 기타 유동부채 (유사도: 0.8317)
#
# 📌 관계기업종속기업투자
#     ↪ 관계기업및종속기업투자 (유사도: 0.9290)
#     ↪ 관계기업투자 (유사도: 0.8930)
#     ↪ 관계기업및종속기업투자자산 (유사도: 0.8734)
#     ↪ 관계기업및및종속기업투자 (유사도: 0.8728)
#     ↪ 관계기업투자지분 (유사도: 0.8635)
#
# 📌 유동확정계약부채
#     ↪ 유동성확정계약부채 (유사도: 0.9822)
#     ↪ 유동계약부채 (유사도: 0.9655)
#     ↪ 유동성계약부채 (유사도: 0.9534)
#     ↪ 계약부채(유동) (유사도: 0.9246)
#     ↪ 유동확정계약자산 (유사도: 0.9097)
#
# 📌 단기매입채무및기타채무
#     ↪ 단기매입채무 (유사도: 0.9093)
#     ↪ 장기매입채무및기타지급채무 (유사도: 0.8959)
#     ↪ 장기매입채무및기타채무 (유사도: 0.8815)
#     ↪ 장기매입채무및기타비유동채무 (유사도: 0.8795)
#     ↪ 장기성매입채무및기타채무 (유사도: 0.8628)
#
# 📌 1.현금및현금성자산
#     ↪ 1. 현금및현금성자산 (유사도: 1.0000)
#     ↪ (1) 현금및현금성자산 (유사도: 0.9773)
#     ↪ 현금및현금성자산 (유사도: 0.9564)
#     ↪ 현금 및 현금성자산 (유사도: 0.9350)
#     ↪ 현금성자산 (유사도: 0.8913)
#
# 📌 유동파생금융상품자산
#     ↪ 유동성파생금융상품자산 (유사도: 0.9739)
#     ↪ 유동파생금융자산 (유사도: 0.9684)
#     ↪ 유동성파생상품금융자산 (유사도: 0.9684)
#     ↪ 유동파생상품자산 (유사도: 0.9602)
#     ↪ 유동파생금융상품 (유사도: 0.9582)
#
# 📌 리스부채
#     ↪ 리스부채. (유사도: 0.9764)
#     ↪ 리스유동부채 (유사도: 0.9170)
#     ↪ 장기 리스부채 (유사도: 0.9143)
#     ↪ 유동 리스부채 (유사도: 0.8885)
#     ↪ 리스비유동부채 (유사도: 0.8856)
#
# 📌 유동성임대보증금
#     ↪ 유동임대보증금 (유사도: 0.9676)
#     ↪ 유동성장기임대보증금 (유사도: 0.9386)
#     ↪ 유동성 임대보증금 (유사도: 0.9290)
#     ↪ 유동성보증금 (유사도: 0.9261)
#     ↪ 유동보증금 (유사도: 0.9204)
#
# 📌 신주인수권부사채상환할증금
#     ↪ 신주인수권부사채상환할증 (유사도: 0.9791)
#     ↪ 신주인수권부사채할인발행차금 (유사도: 0.9601)
#     ↪ 신주인수권부사채 (유사도: 0.9367)
#     ↪ 신주인수권부사채조정 (유사도: 0.9243)
#     ↪ 신주인수권부사채. (유사도: 0.9148)
#
# 📌 반품재고회수(비유동)
#     ↪ 반품재고회수(유동) (유사도: 0.8514)
#     ↪ 반품재고회수권 (유사도: 0.7912)
#     ↪ 반품충당부채 (유사도: 0.7571)
#     ↪ 반품부채 (유사도: 0.7485)
#     ↪ 반품회수권 (유사도: 0.7425)
#
# 📌 리스사용권자산
#     ↪ 사용권자산(리스) (유사도: 0.9159)
#     ↪ 리스사용권 자산 (유사도: 0.9008)
#     ↪ 리스사용권 (유사도: 0.8932)
#     ↪ 사용권 자산(리스) (유사도: 0.8808)
#     ↪ 리스채권 (유사도: 0.8238)
#
# 📌 사용권자산상각누계
#     ↪ 감가상각누계액(사용권자산) (유사도: 0.8132)
#     ↪ 사용권자산 (유사도: 0.7639)
#     ↪ 감가상각누계액(사용권자산 건물) (유사도: 0.7619)
#     ↪ 감가상각누계액(사용권자산 토지) (유사도: 0.7546)
#     ↪ 사용권자산 이외의 유형자산 (유사도: 0.7406)
#
# 📌 차량운반구감가상각누계액
#     ↪ 감가상각누계액, 차량운반구 (유사도: 0.8343)
#     ↪ 감가상각누계액(사용권자산 차량운반구) (유사도: 0.8053)
#     ↪ 비품감가상각누계액 (유사도: 0.7992)
#     ↪ 건물감가상각누계액 (유사도: 0.7661)
#     ↪ 감가상각누계액 (유사도: 0.7092)
#
# 📌 유동파생상품자산
#     ↪ 유동파생상품자산. (유사도: 0.9833)
#     ↪ 유동성파생상품자산 (유사도: 0.9719)
#     ↪ 유동파생금융상품자산 (유사도: 0.9602)
#     ↪ 유동성파생금융상품자산 (유사도: 0.9302)
#     ↪ 유동성파생상품금융자산 (유사도: 0.9266)
#
# 📌 비융동성이연법인세자산
#     ↪ 유동이연법인세자산 (유사도: 0.8031)
#     ↪ 비유이연법인세자산 (유사도: 0.7654)
#     ↪ 비유동이연법인세자산 (유사도: 0.7569)
#     ↪ 당기법인세자산 (유사도: 0.7469)
#     ↪ 당기법인세자산. (유사도: 0.7319)
#
# 📌 소송충당 부채
#     ↪ 소송충당부채 (유사도: 0.9190)
#     ↪ 소송손실충당부채 (유사도: 0.8900)
#     ↪ 법적소송충당부채 (유사도: 0.8827)
#     ↪ 유동 법적소송충당부채 (유사도: 0.8452)
#     ↪ 장기법적소송충당부채 (유사도: 0.8212)
#
# 📌 대손충당금, 단기미수금
#     ↪ 대손충당금, 단기미수수익 (유사도: 0.9578)
#     ↪ 대손충당금(장기미수금) (유사도: 0.9441)
#     ↪ 대손충당금, 단기대여금 (유사도: 0.9320)
#     ↪ 대손충당금(단기대여금) (유사도: 0.9136)
#     ↪ 대손충당금, 단기선급금 (유사도: 0.9049)
#
# 📌 기타
#     ↪ 기타장기부채 (유사도: 0.7466)
#     ↪ 기타재고 (유사도: 0.7390)
#     ↪ 기타잉여금 (유사도: 0.7252)
#     ↪ 기타채무 (유사도: 0.7201)
#     ↪ 기타부채 (유사도: 0.6962)
#
# 📌 당기손익 공정가치측정 금융부채
#     ↪ 당기손익-공정가치측정 금융부채 (유사도: 0.9817)
#     ↪ 당기손익 공정가치 측정 금융부채 (유사도: 0.9674)
#     ↪ 당기손익-공정가치 측정 금융부채 (유사도: 0.9605)
#     ↪ 당기손익인식 공정가치 측정 금융부채 (유사도: 0.9581)
#     ↪ 당기손익인식-공정가치 측정 금융부채 (유사도: 0.9547)
#
# 📌 유형자산(주석 13)
#     ↪ 재고자산(주석 11) (유사도: 0.7347)
#     ↪ 유형자산 (유사도: 0.6708)
#     ↪ (2) 유형자산 (유사도: 0.6618)
#     ↪ 2. 유형자산 (유사도: 0.6524)
#     ↪ 6.무형자산 (유사도: 0.6440)
#
# 📌 예수금
#     ↪ 6. 예수금 (유사도: 0.8543)
#     ↪ 예수보증금 (유사도: 0.8130)
#     ↪ 4.예수금 (유사도: 0.8067)
#     ↪ 예수부채 (유사도: 0.7374)
#     ↪ 부가세 예수금 (유사도: 0.7334)
#
# 📌 유동성장기채무
#     ↪ 유동성장기차입채무 (유사도: 0.9452)
#     ↪ 유동성장기부채 (유사도: 0.9293)
#     ↪ 유동성장기유동화채무 (유사도: 0.9187)
#     ↪ 유동성장기채권 (유사도: 0.9173)
#     ↪ 유동성장기차입부채 (유사도: 0.9126)
#
# 📌 기타포괄손익-공정가치 측정 지분상품 투자
#     ↪ 기타포괄손익-공정가치 측정 지정 지분상품 투자 (유사도: 0.9810)
#     ↪ 기타포괄손익-공정가치 측정 지정 지분상품 (유사도: 0.9623)
#     ↪ 기타포괄손익 공정가치측정 지분증권 (유사도: 0.9243)
#     ↪ 기타포괄-공정가치 측정 지분증권 (유사도: 0.9185)
#     ↪ 비유동 기타포괄손익-공정가치 측정 지분상품 (유사도: 0.9167)
#
# 📌 선급용역원가
#     ↪ 선급공사원가 (유사도: 0.8518)
#     ↪ 선급비용 (유사도: 0.7969)
#     ↪ 선급계약원가 (유사도: 0.7584)
#     ↪ 선급공사비 (유사도: 0.7483)
#     ↪ 단기선급공사원가 (유사도: 0.6790)
#
# 📌 기타포괄-공정가치 측정 지분증권
#     ↪ 기타포괄손익 공정가치측정 지분증권 (유사도: 0.9394)
#     ↪ 기타포괄손익-공정가치 측정 지분상품 투자 (유사도: 0.9185)
#     ↪ 기타포괄손익-공정가치 측정 지정 지분상품 (유사도: 0.9096)
#     ↪ 기타포괄손익-공정가치 측정 지정 지분상품 투자 (유사도: 0.9016)
#     ↪ 당기손익-공정가치 측정 지분증권 (유사도: 0.9015)
#
# 📌 매입채무 및 기타부채
#     ↪ 매입채무 및 기타채무 (유사도: 0.9561)
#     ↪ 매입채무 및 기타유동부채 (유사도: 0.9544)
#     ↪ 매입채무 및 기타금융부채 (유사도: 0.9537)
#     ↪ 매입채무 및 기타지급채무 (유사도: 0.9361)
#     ↪ 매입채무 및 기타유동채무 (유사도: 0.9299)
#
# 📌 추심예수금
#     ↪ 미지급금 (유사도: 0.6639)
#     ↪ 미수대매금 (유사도: 0.6604)
#     ↪ 미수금 (유사도: 0.6574)
#     ↪ 보증예수금 (유사도: 0.6567)
#     ↪ 대여금및수취채권 (유사도: 0.6504)
#
# 📌 3. 확정급여채무
#     ↪ 3.퇴직급여채무 (유사도: 0.8756)
#     ↪ 1.확정급여채무 (유사도: 0.8688)
#     ↪ 확정급여채무 (유사도: 0.8600)
#     ↪ 1.확정급여부채 (유사도: 0.8081)
#     ↪ 확정급여부채. (유사도: 0.8078)
#
# 📌 장기차입부채
#     ↪ 단기차입부채 (유사도: 0.9114)
#     ↪ 장기차입금 및 장기리스부채 (유사도: 0.8579)
#     ↪ 유동차입부채 (유사도: 0.8540)
#     ↪ 장기환불부채 (유사도: 0.8338)
#     ↪ 장기차입부채(유동) (유사도: 0.8257)
#
# 📌 유동성장기채권
#     ↪ 유동성장기채무 (유사도: 0.9173)
#     ↪ 유동성장기차입채무 (유사도: 0.8930)
#     ↪ 유동성장기부채 (유사도: 0.8910)
#     ↪ 유동성장기부채및사채 (유사도: 0.8888)
#     ↪ 유동성장기차입부채 (유사도: 0.8837)
#
# 📌 종속기업 및 관계기업투자자산
#     ↪ 관계기업 및 종속기업투자자산 (유사도: 0.9791)
#     ↪ 종속기업투자자산 및 관계기업투자자산 (유사도: 0.9728)
#     ↪ 종속기업및관계기업투자자산 (유사도: 0.9687)
#     ↪ 종속기업 및 관계기업투자 (유사도: 0.9507)
#     ↪ 종속기업 및 관계기업투자지분 (유사도: 0.9489)
#
# 📌 반품제품회권
#     ↪ 반품제품회수권 (유사도: 0.9691)
#     ↪ 반품회수권 (유사도: 0.9294)
#     ↪ 반품권 (유사도: 0.9104)
#     ↪ 반품재고회수권 (유사도: 0.8853)
#     ↪ 반품재고 회수권 (유사도: 0.8483)
#
# 📌 기타상각후원가측정금융자산
#     ↪ 장기상각후원가측정금융자산 (유사도: 0.9197)
#     ↪ 단기상각후원가측정금융자산 (유사도: 0.9166)
#     ↪ 매출채권및상각후원가측정금융자산 (유사도: 0.9126)
#     ↪ 유동상각후원가측정금융자산 (유사도: 0.9076)
#     ↪ 유동성상각후원가측정금융자산 (유사도: 0.9003)
#
# 📌 비유동기타부채
#     ↪ 비유동부채 (유사도: 0.9009)
#     ↪ 비유동기타지급채무 (유사도: 0.8980)
#     ↪ 비유동기타채무 (유사도: 0.8748)
#     ↪ 비유동파생부채 (유사도: 0.8684)
#     ↪ ll. 비유동부채 (유사도: 0.8428)
#
# 📌 리스비유동채권
#     ↪ 리스유동채권 (유사도: 0.9495)
#     ↪ 리스비유동부채 (유사도: 0.9303)
#     ↪ 리스유동부채 (유사도: 0.9167)
#     ↪ 리스채권 (유사도: 0.8675)
#     ↪ 리스채권(비유동) (유사도: 0.8616)
#
# 📌 기타포괄손익-공정가치비유동금융자산
#     ↪ 기타포괄손익-공정가치금융자산 (유사도: 0.9598)
#     ↪ 기타포괄손익 공정가치금융자산 (유사도: 0.9520)
#     ↪ 기타포괄손익-공정가치측정금융자산 (유사도: 0.9500)
#     ↪ 기타포괄손익-공정가치금융자산평가손익 (유사도: 0.9457)
#     ↪ 기타포괄손익-공정가치 금융자산 (유사도: 0.9439)
#
# 📌 통화선도
#     ↪ 통화선도부채 (유사도: 0.7009)
#     ↪ 통화선도자산 (유사도: 0.6612)
#     ↪ 전신전화가입권 (유사도: 0.5708)
#     ↪ 교환사채 (유사도: 0.5645)
#     ↪ 유동성통화선도부채 (유사도: 0.5163)
#
# 📌 비유동 공정가치 의무 측정 금융자산
#     ↪ 비유동 공정가치측정 금융자산 (유사도: 0.9571)
#     ↪ 비유동 당기손익-공정가치 측정 지정 금융자산 (유사도: 0.9255)
#     ↪ 비유동 당기손익-공정가치 의무 측정 금융자산 (유사도: 0.9248)
#     ↪ 비유동 당기손익-공정가치 금융자산 (유사도: 0.9152)
#     ↪ 비유동 기타포괄손익 공정가치 측정 금융자산 (유사도: 0.9102)
#
# 📌 유동차입금
#     ↪ 유동성차입금 (유사도: 0.9585)
#     ↪ 유동장기차입금 (유사도: 0.9399)
#     ↪ 유동성이자부차입금 (유사도: 0.9174)
#     ↪ 유동성 장기차입금 (유사도: 0.8901)
#     ↪ 유동성장기차입금 (유사도: 0.8895)
#
# 📌 장기미지급금 및 기타채무
#     ↪ 단기미지급금 및 기타채무 (유사도: 0.9482)
#     ↪ 장기미지급금 및 기타부채 (유사도: 0.9477)
#     ↪ 장기미지급금 및 장기기타채무 (유사도: 0.9194)
#     ↪ 장기미지급금및기타채무 (유사도: 0.8989)
#     ↪ 장기미지급금및기타지급채무 (유사도: 0.8789)
#
# 📌 유동이연법인세자산
#     ↪ 장기이연법인세자산 (유사도: 0.8209)
#     ↪ 비유이연법인세자산 (유사도: 0.8058)
#     ↪ 비융동성이연법인세자산 (유사도: 0.8031)
#     ↪ 당기법인세자산 (유사도: 0.7660)
#     ↪ 비유동이연법인세자산 (유사도: 0.7625)
#
# 📌 조인트벤처에 대한 투자자산
#     ↪ 조인트벤처와 관계기업에 대한 투자자산 (유사도: 0.9683)
#     ↪ 종속기업, 조인트벤처와 관계기업에 대한 투자자산 (유사도: 0.8722)
#     ↪ 공동기업투자주식 (유사도: 0.7841)
#     ↪ 공동기업투자지분 (유사도: 0.7834)
#     ↪ 공동기업에 대한 투자자산 (유사도: 0.7799)
#
# 📌 순확정급여부채및기타장기급여부채
#     ↪ 순확정급여부채및기타장기종업원급여부채 (유사도: 0.9688)
#     ↪ 순확정급여부채 (유사도: 0.8902)
#     ↪ 확정급여부채및기타장기급여채무 (유사도: 0.8486)
#     ↪ 순확정여부채 (유사도: 0.8424)
#     ↪ 순확정급여채무 (유사도: 0.8127)
#
# 📌 제품보증충당부채
#     ↪ 품질보증충당부채 (유사도: 0.8679)
#     ↪ 장기제품보증충당부채 (유사도: 0.8313)
#     ↪ 판매보증충당부채 (유사도: 0.7801)
#     ↪ 단기제품보증충당부채 (유사도: 0.7596)
#     ↪ 보증충당부채 (유사도: 0.7575)
#
# 📌 비유동 당기손익-공정가치측정 금융자산
#     ↪ 비유동 당기손익-공정가치 측정 금융자산 (유사도: 0.9814)
#     ↪ 비유동 당기손익-공정가치 측정  금융자산 (유사도: 0.9814)
#     ↪ 비유동 당기손익-공정가치측정금융자산 (유사도: 0.9765)
#     ↪ 비유동 당기손익-공정가치 금융자산 (유사도: 0.9763)
#     ↪ 비유동 당기손익 공정가치 측정 금융자산 (유사도: 0.9752)
#
# 📌 기타 유동부채
#     ↪ 기타부채(유동) (유사도: 0.9373)
#     ↪ 기타금융부채(유동) (유사도: 0.8931)
#     ↪ 기타 유동 채권 (유사도: 0.8664)
#     ↪ 유동부채 (유사도: 0.8661)
#     ↪ 유동충당부채 (유사도: 0.8582)
#
# 📌 감가상각누계액, 차량운반구
#     ↪ 감가상각누계액(사용권자산 차량운반구) (유사도: 0.9485)
#     ↪ 차량운반구감가상각누계액 (유사도: 0.8343)
#     ↪ 감가상각누계액 (유사도: 0.8054)
#     ↪ (감가상각누계액) (유사도: 0.7698)
#     ↪ 감가상각누계액, 구축물 (유사도: 0.7539)
#
# 📌 기타 자본구성
#     ↪ 기타의 자본항목 (유사도: 0.8602)
#     ↪ 기타자본항목(자본) (유사도: 0.8509)
#     ↪ 기타의 자본조정 (유사도: 0.8006)
#     ↪ 기타불입자본(자본잉여금) (유사도: 0.7805)
#     ↪ 자본 총계 (유사도: 0.7351)
#
# 📌 이연수익
#     ↪ 이연수익(유동) (유사도: 0.7802)
#     ↪ 거래가격차이 이연자산 (유사도: 0.7351)
#     ↪ 이연법인세자산 (유사도: 0.6955)
#     ↪ 이연법인세자산. (유사도: 0.6886)
#     ↪ 이연법인세부채 (유사도: 0.6875)
#
# 📌 통화스왑파생부채
#     ↪ 장기이자율스왑부채 (유사도: 1.0000)
#     ↪ 이자율스왑평가손익 (유사도: 1.0000)
#     ↪ 유동성장기이자율스왑 (유사도: 1.0000)
#     ↪ 장기이자율스왑자산 (유사도: 1.0000)
#     ↪ 유동이자율스왑자산 (유사도: 1.0000)
#
# 📌 매각예정처분자산
#     ↪ 매각예정자산 (유사도: 0.9438)
#     ↪ 매각예정분류자산 (유사도: 0.9246)
#     ↪ 매각예정처분자산집단 (유사도: 0.9147)
#     ↪ 매각예정유형자산 (유사도: 0.9132)
#     ↪ 매각예정 자산 (유사도: 0.9066)
#
# 📌 유동배출권
#     ↪ 유동성배출권 (유사도: 0.9565)
#     ↪ 유동배출부채 (유사도: 0.7973)
#     ↪ 유동성전환권조정 (유사도: 0.7840)
#     ↪ 유동수취채권 (유사도: 0.7580)
#     ↪ 유동반환제품회수권 (유사도: 0.7523)
#
# 📌 기타포괄손익-공정가치측정금융상품
#     ↪ 기타포괄손익-공정가치금융상품 (유사도: 0.9672)
#     ↪ 기타포괄손익-공정가치측정 금융상품 (유사도: 0.9670)
#     ↪ 기타포괄손익-공정가치측정금융자산 (유사도: 0.9629)
#     ↪ 기타포괄손익_공정가치측정금융자산 (유사도: 0.9512)
#     ↪ 기타포괄손익-공정가치측정금융자산평가이익 (유사도: 0.9496)
#
# 📌 종속회사 및 관계회사 투자
#     ↪ 종속회사 및 관계회사투자 (유사도: 0.9711)
#     ↪ 종속회사및관계회사투자 (유사도: 0.9353)
#     ↪ 종속기업 및 관계기업 투자 (유사도: 0.9326)
#     ↪ 종속 및 관계기업 투자 (유사도: 0.9305)
#     ↪ 종속기업 및 관계기업투자 (유사도: 0.9200)
#
# 📌 7.관계기업투자
#     ↪ 관계기업투자 (유사도: 0.8543)
#     ↪ 관계기업 투자 (유사도: 0.8404)
#     ↪ 2. 관계기업투자 (유사도: 0.8313)
#     ↪ 관계기업투자 및 공동기업투자 (유사도: 0.8262)
#     ↪ 관계기업투자지분 (유사도: 0.8220)
#
# 📌 퇴직연금초과금
#     ↪ 퇴직연금자산 (유사도: 0.8606)
#     ↪ 퇴직보험예치금 (유사도: 0.8461)
#     ↪ 퇴직연금투자자산 (유사도: 0.8321)
#     ↪ 퇴직연금운용자산 (유사도: 0.8234)
#     ↪ 퇴직급여자산/퇴직연금운용자산 (유사도: 0.8104)
#
# 📌 선물거래예치금
#     ↪ 단기예치금 (유사도: 0.7470)
#     ↪ 주식발행초과금 (유사도: 0.7276)
#     ↪ 금융예수금 (유사도: 0.7117)
#     ↪ 단기투자예치금 (유사도: 0.7091)
#     ↪ 단기예수금 (유사도: 0.7013)
#
# 📌 자산재평가적립금
#     ↪ 재평가적립금 (유사도: 0.8067)
#     ↪ 수탁재고자산 (유사도: 0.7794)
#     ↪ 확정계약평가자산 (유사도: 0.7682)
#     ↪ 투자실적자산 (유사도: 0.7674)
#     ↪ 확정급여자산 (유사도: 0.7660)
#
# 📌 장기미지급금 및 기타부채
#     ↪ 장기미지급금 및 기타채무 (유사도: 0.9477)
#     ↪ 단기미지급금 및 기타채무 (유사도: 0.9116)
#     ↪ 장기미지급금및기타부채 (유사도: 0.8942)
#     ↪ 장기미지급금 및 장기기타채무 (유사도: 0.8681)
#     ↪ 장기미지급금및기타지급채무 (유사도: 0.8631)

# %%
df_sim = embed_and_compare(unique_accounts, top_k=100)
display(df_sim.head(100))
# Out:
# 🔍 모델 로딩: snunlp/KR-SBERT-V40K-klueNLI-augSTS
# 🔢 임베딩 중... (1150개)
# 📐 유사도 계산...
#                      Account1                  Account2  Similarity
# 0                    영업이익(손실)                 영업이익 (손실)    1.000000
# 1   기타포괄손익 - 공정가치측정 금융자산 평가손익   기타포괄손익-공정가치측정 금융자산 평가손익    1.000000
# 2       당기손익-공정가치 측정 금융자산의 취득    당기손익-공정가치 측정 금융자산의  취득    1.000000
# 3     기타포괄손익-공정가치 측정 금융자산평가손익  기타포괄손익-공정가치 측정 금융자산 평가손익    0.994729
# 4   기타포괄손익 - 공정가치측정 금융자산 평가손익   기타포괄손익-공정가치측정  금융자산평가손익    0.993682
# ..                        ...                       ...         ...
# 95      기타포괄손익-공정가치측정금융자산평가손익  기타포괄손익 - 공정가치측정금융자산 처분손익    0.971627
# 96                   이자수익의 수취                   이자수익 수취    0.971611
# 97             기타유동자산의 감소(증가)           기타비유동자산의 감소(증가)    0.971495
# 98    기타포괄손익-공정가치 측정 금융자산의 처분     기타포괄손익-공정가치측정 금융자산 처분    0.970935
# 99      기타포괄손익-공정가치측정 금융자산 처분     기타포괄손익-공정가치측정 금융자산 취득    0.970710
#
# [100 rows x 3 columns]

# %%
df_match = match_with_targets(unique_accounts, target_keywords, top_k=5)
display(df_match)
# Out:
# 📦 모델 로딩 중...
# 🔢 전체 계정명 임베딩 중...
# 🎯 타겟 키워드 임베딩 중...
#    TargetKeyword  MatchedAccount  Similarity
# 30           R&D  관계기업 및 공동기업 투자    0.442394
# 31           R&D  사업양도로 인한 순현금흐름    0.433830
# 32           R&D         수익(매출액)    0.431510
# 33           R&D    관계기업및공동기업 투자    0.409476
# 34           R&D   관계기업 및 공동기업투자    0.408766
# 10         당기순이익           당기순이익    1.000000
# 11         당기순이익       당기순이익(손실)    0.838863
# 12         당기순이익            영업이익    0.811462
# 13         당기순이익             매출액    0.805640
# 14         당기순이익         당기의 순이익    0.765554
# 0            매출액             매출액    1.000000
# 1            매출액              매출    0.854189
# 2            매출액           매출총이익    0.824860
# 3            매출액            영업이익    0.814007
# 4            매출액           당기순이익    0.805640
# 35          부채비율       부채 및 자본총계    0.793348
# 36          부채비율         부채및자본총계    0.786754
# 37          부채비율            충당부채    0.785861
# 38          부채비율        부채와 자본총계    0.781949
# 39          부채비율            부채총계    0.778989
# 25         연구개발비            영업비용    0.603624
# 26         연구개발비           영업외비용    0.525339
# 27         연구개발비             판매비    0.523444
# 28         연구개발비           법인세비용    0.506684
# 29         연구개발비         판매비와관리비    0.497988
# 5           영업이익            영업이익    1.000000
# 6           영업이익             매출액    0.814007
# 7           영업이익           당기순이익    0.811462
# 8           영업이익              매출    0.808875
# 9           영업이익        영업이익(손실)    0.785191
# 40          유동비율            유동부채    0.770218
# 41          유동비율            유동자산    0.765533
# 42          유동비율          유동리스부채    0.719060
# 43          유동비율          유동충당부채    0.679643
# 44          유동비율           유동화채무    0.674617
# 45        자기자본비율            자본조정    0.717105
# 46        자기자본비율             자본금    0.700966
# 47        자기자본비율         부채및자본총계    0.697518
# 48        자기자본비율            유동부채    0.695765
# 49        자기자본비율             차입금    0.695584
# 15           직원수             매출액    0.624359
# 16           직원수           종업원급여    0.616430
# 17           직원수              매출    0.607440
# 18           직원수         종업원급여자산    0.589362
# 19           직원수            영업이익    0.544665
# 20        평균 인건비           종업원급여    0.605356
# 21        평균 인건비            선급비용    0.588019
# 22        평균 인건비            영업비용    0.581088
# 23        평균 인건비             관리비    0.533284
# 24        평균 인건비           비용가산:    0.509007

# %%
df_sim
# Out:
#                      Account1                   Account2  Similarity
# 0    기타포괄손익 - 공정가치측정금융자산 처분손익     기타포괄손익-공정가치측정금융자산 처분손익    1.000000
# 1    기타포괄손익-공정가치 측정 지분상품 평가손익  기타포괄손익-공정가치 측정 지분상품  평가손익    1.000000
# 2       당기손익-공정가치 측정 금융자산의 처분     당기손익-공정가치 측정  금융자산의 처분    1.000000
# 3       당기손익-공정가치 측정 금융자산의 취득     당기손익-공정가치 측정 금융자산의  취득    1.000000
# 4                    영업이익(손실)                  영업이익 (손실)    1.000000
# ..                        ...                        ...         ...
# 95                   파생금융상품자산                   파생상품금융자산    0.982393
# 96  기타포괄손익 - 공정가치측정 금융자산 평가손익     기타포괄손익-공정가치측정 금융자산처분손익    0.982324
# 97                   종속기업투자주식                  종속기업 투자주식    0.982173
# 98      기타포괄손익-공정가치측정금융자산평가손익  기타포괄손익 - 공정가치측정 금융자산 평가손익    0.982131
# 99   기타포괄손익 - 공정가치측정금융자산 평가손익     기타포괄손익-공정가치측정 금융자산평가손익    0.982075
#
# [100 rows x 3 columns]
