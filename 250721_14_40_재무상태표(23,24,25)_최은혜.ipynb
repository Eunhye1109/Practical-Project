# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunhye1109/Practical-Project/blob/EH/250721_14_40_%EC%9E%AC%EB%AC%B4%EC%83%81%ED%83%9C%ED%91%9C(23%2C24%2C25)_%EC%B5%9C%EC%9D%80%ED%98%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dart-fss
# !pip install OpenDartReader
# !pip install FinanceDataReader
# Out:
# Collecting dart-fss
#   Downloading dart_fss-0.4.13-py3-none-any.whl.metadata (3.6 kB)
# Collecting xmltodict (from dart-fss)
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.32.3)
# Collecting arelle-release (from dart-fss)
#   Downloading arelle_release-2.37.37-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from dart-fss) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from dart-fss) (4.67.1)
# Collecting yaspin (from dart-fss)
#   Downloading yaspin-3.1.0-py3-none-any.whl.metadata (14 kB)
# Collecting fake-useragent>=1.5 (from dart-fss)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from dart-fss) (4.13.4)
# Collecting appdirs (from dart-fss)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting bottle<0.14,>=0.13 (from arelle-release->dart-fss)
#   Downloading bottle-0.13.4-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.18.0)
# Requirement already satisfied: jsonschema==4.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (4.24.0)
# Collecting isodate==0.* (from arelle-release->dart-fss)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: lxml<6,>=4 in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (5.4.0)
# Requirement already satisfied: openpyxl==3.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.1.5)
# Requirement already satisfied: pillow<12,>=10 in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (11.2.1)
# Requirement already satisfied: pyparsing==3.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (3.2.3)
# Requirement already satisfied: python-dateutil==2.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2.9.0.post0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (2024.11.6)
# Collecting truststore==0.* (from arelle-release->dart-fss)
#   Downloading truststore-0.10.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: typing-extensions==4.* in /usr/local/lib/python3.11/dist-packages (from arelle-release->dart-fss) (4.14.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema==4.*->arelle-release->dart-fss) (0.26.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl==3.*->arelle-release->dart-fss) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil==2.*->arelle-release->dart-fss) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->dart-fss) (2.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->dart-fss) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->dart-fss) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dart-fss) (2.4.0)
# Collecting termcolor<2.4.0,>=2.2.0 (from yaspin->dart-fss)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Downloading dart_fss-0.4.13-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 8.9 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 9.2 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading arelle_release-2.37.37-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 91.0 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading truststore-0.10.1-py3-none-any.whl (18 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Downloading yaspin-3.1.0-py3-none-any.whl (18 kB)
# Downloading bottle-0.13.4-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 4.5 MB/s eta 0:00:00
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Installing collected packages: bottle, appdirs, xmltodict, truststore, termcolor, isodate, fake-useragent, yaspin, arelle-release, dart-fss
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.1.0
#     Uninstalling termcolor-3.1.0:
#       Successfully uninstalled termcolor-3.1.0
# Successfully installed appdirs-1.4.4 arelle-release-2.37.37 bottle-0.13.4 dart-fss-0.4.13 fake-useragent-2.2.0 isodate-0.7.2 termcolor-2.3.0 truststore-0.10.1 xmltodict-0.14.2 yaspin-3.1.0
# Collecting OpenDartReader
#   Downloading OpenDartReader-0.2.3-py3-none-any.whl.metadata (913 bytes)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (2.2.2)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (2.32.3)
# Collecting requests-file (from OpenDartReader)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (5.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (4.13.4)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (2025.7.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->OpenDartReader) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->OpenDartReader) (4.14.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->OpenDartReader) (1.17.0)
# Downloading OpenDartReader-0.2.3-py3-none-any.whl (27 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: requests-file, OpenDartReader
# Successfully installed OpenDartReader-0.2.3 requests-file-2.1.0
# ERROR: Could not find a version that satisfies the requirement FinanceDataReader (from versions: none)
# ERROR: No matching distribution found for FinanceDataReader

# %%
import os
import pandas as pd
input_path = '/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기'
output_path = '/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과'

# %%
os.listdir(input_path)
# Out:
# ['2025_1분기보고서_01_재무상태표_연결_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_은행_연결_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_은행_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_금융기타_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_증권_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_금융기타_연결_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_보험_연결_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_증권_연결_20250606.txt',
#  '2025_1분기보고서_01_재무상태표_보험_20250606.txt',
#  '2024_사업보고서_01_재무상태표_금융기타_연결_20250606.txt',
#  '2024_사업보고서_01_재무상태표_보험_20250606.txt',
#  '2024_사업보고서_01_재무상태표_20250606.txt',
#  '2024_사업보고서_01_재무상태표_보험_연결_20250606.txt',
#  '2024_사업보고서_01_재무상태표_금융기타_20250606.txt',
#  '2024_사업보고서_01_재무상태표_증권_연결_20250606.txt',
#  '2024_사업보고서_01_재무상태표_은행_연결_20250606.txt',
#  '2024_사업보고서_01_재무상태표_증권_20250606.txt',
#  '2024_사업보고서_01_재무상태표_은행_20250606.txt',
#  '2024_사업보고서_01_재무상태표_연결_20250606.txt',
#  '2023_사업보고서_01_재무상태표_금융기타_20241101.txt',
#  '2023_사업보고서_01_재무상태표_20241101.txt',
#  '2023_사업보고서_01_재무상태표_보험_연결_20241101.txt',
#  '2023_사업보고서_01_재무상태표_금융기타_연결_20241101.txt',
#  '2023_사업보고서_01_재무상태표_보험_20241101.txt',
#  '2023_사업보고서_01_재무상태표_은행_20241101.txt',
#  '2023_사업보고서_01_재무상태표_증권_연결_20241101.txt',
#  '2023_사업보고서_01_재무상태표_은행_연결_20241101.txt',
#  '2023_사업보고서_01_재무상태표_증권_20241101.txt',
#  '2023_사업보고서_01_재무상태표_연결_20241101.txt',
#  '2022_사업보고서_01_재무상태표_연결_20250625.txt',
#  '2022_사업보고서_01_재무상태표_20250625.txt']

# %%
import os

def extract_balance_sheet_indicators(input_path):
    indicators = set()
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            if '\t' in line:
                columns = line.strip().split('\t')
                for col in columns:
                    # 숫자가 아닌 컬럼명만 추출
                    if not any(char.isdigit() for char in col) and len(col.strip()) > 1:
                        indicators.add(col.strip())
    return indicators

# %%
import os

# 경로 및 대상 파일
input_path = "/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기"
target_files = [f for f in os.listdir(input_path) if "연결" in f and f.endswith(".txt")]

# 확인용: 첫 번째 파일만 미리 보기
if target_files:
    test_file = os.path.join(input_path, target_files[0])
    print(f"\n✅ 테스트 파일: {target_files[0]}\n")
    try:
        with open(test_file, encoding='utf-8') as f:
            for i in range(20):
                print(f"{i+1:02d}: {f.readline().strip()}")
    except UnicodeDecodeError:
        with open(test_file, encoding='cp949') as f:
            for i in range(20):
                print(f"{i+1:02d}: {f.readline().strip()}")
else:
    print("❌ '연결' 포함된 txt 파일이 없습니다.")
# Out:
# ❌ '연결' 포함된 txt 파일이 없습니다.

# %%
import unicodedata
import os

# 경로 설정
input_path = "/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기"

# 파일명 유니코드 정규화 후 '연결' 포함 여부 판단
all_files = os.listdir(input_path)
target_files = [
    f for f in all_files if "연결" in unicodedata.normalize('NFC', f) and f.endswith('.txt')
]

# 결과 확인
print("📂 '연결' 포함된 txt 파일 개수:", len(target_files))
for f in target_files:
    print(" -", f)
# Out:
# 📂 '연결' 포함된 txt 파일 개수: 16
#  - 2025_1분기보고서_01_재무상태표_연결_20250606.txt
#  - 2025_1분기보고서_01_재무상태표_은행_연결_20250606.txt
#  - 2025_1분기보고서_01_재무상태표_금융기타_연결_20250606.txt
#  - 2025_1분기보고서_01_재무상태표_보험_연결_20250606.txt
#  - 2025_1분기보고서_01_재무상태표_증권_연결_20250606.txt
#  - 2024_사업보고서_01_재무상태표_금융기타_연결_20250606.txt
#  - 2024_사업보고서_01_재무상태표_보험_연결_20250606.txt
#  - 2024_사업보고서_01_재무상태표_증권_연결_20250606.txt
#  - 2024_사업보고서_01_재무상태표_은행_연결_20250606.txt
#  - 2024_사업보고서_01_재무상태표_연결_20250606.txt
#  - 2023_사업보고서_01_재무상태표_보험_연결_20241101.txt
#  - 2023_사업보고서_01_재무상태표_금융기타_연결_20241101.txt
#  - 2023_사업보고서_01_재무상태표_증권_연결_20241101.txt
#  - 2023_사업보고서_01_재무상태표_은행_연결_20241101.txt
#  - 2023_사업보고서_01_재무상태표_연결_20241101.txt
#  - 2022_사업보고서_01_재무상태표_연결_20250625.txt

# %%
# 첫 번째 파일 경로 설정
import unicodedata
test_file = os.path.join(input_path, target_files[0])

# 20줄만 출력해서 포맷 확인
try:
    with open(test_file, encoding='utf-8') as f:
        print(f"\n🧾 파일: {unicodedata.normalize('NFC', target_files[0])}\n")
        for i in range(20):
            print(f"{i+1:02d}: {f.readline().strip()}")
except UnicodeDecodeError:
    with open(test_file, encoding='cp949') as f:
        print(f"\n🧾 파일 (cp949): {unicodedata.normalize('NFC', target_files[0])}\n")
        for i in range(20):
            print(f"{i+1:02d}: {f.readline().strip()}")
# Out:
# 🧾 파일: 2025_1분기보고서_01_재무상태표_연결_20250606.txt
#
#
# 🧾 파일 (cp949): 2025_1분기보고서_01_재무상태표_연결_20250606.txt
#
# 01: 재무제표종류	종목코드	회사명	시장구분	업종	업종명	결산월	결산기준일	보고서종류	통화	항목코드	항목명	당기 1분기말	전기말	전전기말
# 02: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_Assets	         자산총계	1,758,818,519,349	1,717,770,434,389
# 03: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_CurrentAssets	         유동자산	375,615,889,471	304,434,525,487
# 04: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_CashAndCashEquivalents	            현금및현금성자산	175,812,900,163	105,005,298,611
# 05: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_CurrentFinancialAssetsAtFairValueThroughProfitOrLossMandatorilyMeasuredAtFairValue	            당기손익-공정가치측정 금융자산	1,888,758,984	1,886,700,667
# 06: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_CurrentTradeReceivables	            매출채권	103,822,311,024	111,197,248,052
# 07: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_Inventories	            재고자산	25,912,850,152	25,129,909,338
# 08: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_OtherCurrentAssets	            기타유동자산	16,986,597,099	21,640,939,199
# 09: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_OtherCurrentFinancialAssets	            기타유동금융자산	51,192,472,049	39,574,429,620
# 10: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_NoncurrentAssets	         비유동자산	1,383,202,629,878	1,381,384,440,192
# 11: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	dart_RentalAssetNet	            렌탈자산	775,352,266,046	772,085,585,192	773,760,341,000
# 12: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_DeferredTaxAssets	            이연법인세자산	829,370,233	722,516,821
# 13: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_IntangibleAssetsAndGoodwill	            무형자산	28,990,380,399	29,151,684,095	22,359,494,000
# 14: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_InvestmentProperty	            투자부동산	160,511,073,021	151,409,298,351	98,412,560,000
# 15: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_InvestmentsInAssociates	            관계기업투자주식	29,587,478,426	29,349,418,483
# 16: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_NoncurrentFinancialAssetsAtFairValueThroughProfitOrLossMandatorilyMeasuredAtFairValue	            당기손익-공정가치측정 금융자산	18,854,392,336	18,825,892,915
# 17: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_NoncurrentFinancialAssetsMeasuredAtFairValueThroughOtherComprehensiveIncome	            기타포괄손익-공정가치 측정 금융자산	14,354,530,986	14,350,415,787
# 18: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_OtherNoncurrentAssets	            기타비유동자산	4,735,749,271	6,809,111,985
# 19: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_OtherNoncurrentFinancialAssets	            기타비유동금융자산	40,674,345,000	40,616,527,417
# 20: 재무상태표, 유동/비유동법 - 연결	[095570]	AJ네트웍스	유가증권시장상장법인	763	산업용 기계 및 장비 임대업	12	2025-03-31	1분기보고서	KRW	ifrs-full_PropertyPlantAndEquipment	            유형자산	261,060,967,175	269,546,792,811	280,183,984,000

# %%
import os
print(os.listdir("/content/drive/MyDrive/Colab Notebooks"))
# Out:
# ['.ipynb_checkpoints', 'SW 엔지니어', 'kiwipiepy (1).ipynb', 'RETRY_네이버영화평점리뷰.ipynb', 'kiwipiepy.ipynb', 'etc', 'Analysis _for_Environment_gamification.ipynb', 'sf 키워드 추출.ipynb', 'Untitled0.ipynb', 'EX01) 유방암 데이터 분류(이진 분류).ipynb', 'DeepLearning 맛보기.ipynb', 'ex02) 손글씨 데이터 분류.ipynb', 'ex03-2) 강아지 고양이 이진분류.ipynb의 사본', 'ex03-1)강아지 고양이 데이터 전처리 .ipynb', 'ex03-2) 강아지 고양이 이진분류(cnn).ipynb', 'Untitled (1)', 'ex04_RNN.ipynb', 'ex05_RNN 활용하기 (2).ipynb', 'ex05_RNN 활용하기 (1).ipynb', 'ex05_RNN 활용하기.ipynb', 'ex06_ 도시 소음 분류 LSTM.ipynb', 'ex06_ 도시 소음 분류 LSTM (1).ipynb', 'ex07_Hugging_Face_Transformers.ipynb', 'ex08_HuggingFace Model FineTuning.ipynb', 'ex08_HuggingFace_Model_FineTuning.ipynb', '[스마트인재개발원] Deeplearning 테스트_코드 답안.ipynb', 'Untitled', '실전프로젝트']
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.13.0

# %%
# import os
# import pandas as pd
# from collections import defaultdict, Counter
# #from difflib import get_close_matches
# from rapidfuzz import process, fuzz
# import unicodedata

# # ✅ 경로 설정
# input_path = "/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기"
# output_path = "/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과"

# # ✅ 1. '연결' 포함된 파일 필터링
# print("🔍 파일 목록 확인 중...")
# all_files = os.listdir(input_path)
# target_files = [f for f in all_files if "연결" in unicodedata.normalize('NFC', f) and f.endswith(".txt")]
# print(f"📁 '연결' 포함된 파일 수: {len(target_files)}개\n")

# # ✅ 2. 항목명 추출 함수 정의
# def extract_column_names(filepath):
#     column_names = []
#     try:
#         with open(filepath, encoding='utf-8') as f:
#             for i, line in enumerate(f):
#                 parts = line.strip().split('\t')
#                 if len(parts) > 11 and i > 0:
#                     name = parts[11].strip()
#                     if name and name != '항목명':
#                         column_names.append(name)
#     except UnicodeDecodeError:
#         with open(filepath, encoding='cp949') as f:
#             for i, line in enumerate(f):
#                 parts = line.strip().split('\t')
#                 if len(parts) > 11 and i > 0:
#                     name = parts[11].strip()
#                     if name and name != '항목명':
#                         column_names.append(name)
#     return column_names

# # ✅ 3. 전체 항목명 수집
# all_column_names = []
# print("📌 항목명 수집 중...")
# for idx, file in enumerate(target_files, 1):
#     file_path = os.path.join(input_path, file)
#     print(f"  [{idx}/{len(target_files)}] → {file} 처리 중")
#     extracted = extract_column_names(file_path)
#     all_column_names.extend(extracted)
# print(f"✅ 총 추출된 항목명 수: {len(all_column_names)}개\n")

# # ✅ 4. 유사 컬럼 그룹화
# print("🧠 유사 컬럼 그룹화 중...")
# grouped = defaultdict(list)
# visited = set()
# for col in all_column_names:
#     if col in visited:
#         continue
#     matches = get_close_matches(col, all_column_names, cutoff=0.75)
#     for m in matches:
#         visited.add(m)
#         grouped[col].append(m)
# print(f"✅ 그룹화 완료: {len(grouped)}개 그룹 생성\n")

# # ✅ 5. 대표 컬럼 도출
# print("🏷 대표 컬럼 추출 중...")
# freq = Counter(all_column_names)
# representatives = [max(members, key=lambda x: freq[x]) for members in grouped.values()]
# print(f"✅ 대표 컬럼 도출 완료: {len(set(representatives))}개\n")

# # ✅ 6. 결과 저장
# df = pd.DataFrame({'대표컬럼': sorted(set(representatives))})
# output_file = os.path.join(output_path, "대표컬럼목록.csv")
# df.to_csv(output_file, index=False)
# print(f"💾 CSV 저장 완료: {output_file}")

# # ✅ 7. Colab 화면 출력
# import ace_tools as tools
# tools.display_dataframe_to_user(name="대표 컬럼 리스트", dataframe=df)
# Out:
# 🔍 파일 목록 확인 중...
# 📁 '연결' 포함된 파일 수: 16개
#
# 📌 항목명 수집 중...
#   [1/16] → 2025_1분기보고서_01_재무상태표_연결_20250606.txt 처리 중
#   [2/16] → 2025_1분기보고서_01_재무상태표_은행_연결_20250606.txt 처리 중
#   [3/16] → 2025_1분기보고서_01_재무상태표_금융기타_연결_20250606.txt 처리 중
#   [4/16] → 2025_1분기보고서_01_재무상태표_보험_연결_20250606.txt 처리 중
#   [5/16] → 2025_1분기보고서_01_재무상태표_증권_연결_20250606.txt 처리 중
#   [6/16] → 2024_사업보고서_01_재무상태표_금융기타_연결_20250606.txt 처리 중
#   [7/16] → 2024_사업보고서_01_재무상태표_보험_연결_20250606.txt 처리 중
#   [8/16] → 2024_사업보고서_01_재무상태표_증권_연결_20250606.txt 처리 중
#   [9/16] → 2024_사업보고서_01_재무상태표_은행_연결_20250606.txt 처리 중
#   [10/16] → 2024_사업보고서_01_재무상태표_연결_20250606.txt 처리 중
#   [11/16] → 2023_사업보고서_01_재무상태표_보험_연결_20241101.txt 처리 중
#   [12/16] → 2023_사업보고서_01_재무상태표_금융기타_연결_20241101.txt 처리 중
#   [13/16] → 2023_사업보고서_01_재무상태표_증권_연결_20241101.txt 처리 중
#   [14/16] → 2023_사업보고서_01_재무상태표_은행_연결_20241101.txt 처리 중
#   [15/16] → 2023_사업보고서_01_재무상태표_연결_20241101.txt 처리 중
#   [16/16] → 2022_사업보고서_01_재무상태표_연결_20250625.txt 처리 중
# ✅ 총 추출된 항목명 수: 396068개
#
# 🧠 유사 컬럼 그룹화 중...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-10-1860270220.py", line 55, in <cell line: 0>
#     matches = get_close_matches(col, all_column_names, cutoff=0.75)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/difflib.py", line 705, in get_close_matches
#     s.quick_ratio() >= cutoff and \
#     ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/difflib.py", line None, in quick_ratio
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-10-1860270220.py", line 55, in <cell line: 0>
#     matches = get_close_matches(col, all_column_names, cutoff=0.75)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/difflib.py", line 705, in get_close_matches
#     s.quick_ratio() >= cutoff and \
#     ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/difflib.py", line None, in quick_ratio
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-10-1860270220.py", line 55, in <cell line: 0>
#     matches = get_close_matches(col, all_column_names, cutoff=0.75)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/difflib.py", line 705, in get_close_matches
#     s.quick_ratio() >= cutoff and \
#     ^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/difflib.py", line None, in quick_ratio
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %%
# !pip install rapidfuzz tqdm
# Out:
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (3.13.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)

# %%
import os
import unicodedata
from collections import defaultdict, Counter
from tqdm import tqdm
from rapidfuzz import process, fuzz

# ✅ 경로 설정
input_path = "/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기"
output_path = "/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과"

# ✅ 항목명 추출 함수 (12번째 필드: index 11이 항목명)
def extract_column_names(filepath):
    column_names = []
    try:
        with open(filepath, encoding='utf-8') as f:
            for i, line in enumerate(f):
                parts = line.strip().split('\t')
                if len(parts) > 11 and i > 0:
                    name = parts[11].strip()
                    if name and name != '항목명':
                        column_names.append(name)
    except UnicodeDecodeError:
        with open(filepath, encoding='cp949') as f:
            for i, line in enumerate(f):
                parts = line.strip().split('\t')
                if len(parts) > 11 and i > 0:
                    name = parts[11].strip()
                    if name and name != '항목명':
                        column_names.append(name)
    return column_names

# ✅ 연결 포함된 .txt 파일 추출
all_files = os.listdir(input_path)
target_files = [
    f for f in all_files if "연결" in unicodedata.normalize('NFC', f) and f.endswith(".txt")
]
print(f"📁 '연결' 포함된 파일 수: {len(target_files)}개")

# ✅ 항목명 수집
all_column_names = []
for idx, file in enumerate(target_files, 1):
    file_path = os.path.join(input_path, file)
    print(f"  [{idx}/{len(target_files)}] → {file} 처리 중")
    all_column_names.extend(extract_column_names(file_path))

print(f"✅ 총 추출된 항목명 수: {len(all_column_names)}개")

# ✅ 중복 제거
unique_columns = list(set(all_column_names))
print(f"🧹 중복 제거 후 유니크 항목명 수: {len(unique_columns)}개")

# ✅ 유사 컬럼 그룹화
grouped = defaultdict(list)
visited = set()

print("🧠 유사 컬럼 그룹화 진행 중...")
for col in tqdm(unique_columns):
    if col in visited:
        continue
    matches = process.extract(
        col, unique_columns,
        scorer=fuzz.token_sort_ratio,
        score_cutoff=75,
        limit=20
    )
    matched_names = [m[0] for m in matches]
    for m in matched_names:
        visited.add(m)
    grouped[col].extend(matched_names)

# ✅ 대표 컬럼 추출
freq = Counter(all_column_names)
representatives = [max(members, key=lambda x: freq[x]) for members in grouped.values()]
print(f"🏷 대표컬럼 추출 완료: {len(set(representatives))}개")

# ✅ 결과 저장
import pandas as pd
os.makedirs(output_path, exist_ok=True)
df = pd.DataFrame({'대표컬럼': sorted(set(representatives))})
df.to_csv(os.path.join(output_path, "대표컬럼목록.csv"), index=False)
print("💾 대표컬럼 CSV 저장 완료")
# Out:
# 📁 '연결' 포함된 파일 수: 16개
#   [1/16] → 2025_1분기보고서_01_재무상태표_연결_20250606.txt 처리 중
#   [2/16] → 2025_1분기보고서_01_재무상태표_은행_연결_20250606.txt 처리 중
#   [3/16] → 2025_1분기보고서_01_재무상태표_금융기타_연결_20250606.txt 처리 중
#   [4/16] → 2025_1분기보고서_01_재무상태표_보험_연결_20250606.txt 처리 중
#   [5/16] → 2025_1분기보고서_01_재무상태표_증권_연결_20250606.txt 처리 중
#   [6/16] → 2024_사업보고서_01_재무상태표_금융기타_연결_20250606.txt 처리 중
#   [7/16] → 2024_사업보고서_01_재무상태표_보험_연결_20250606.txt 처리 중
#   [8/16] → 2024_사업보고서_01_재무상태표_증권_연결_20250606.txt 처리 중
#   [9/16] → 2024_사업보고서_01_재무상태표_은행_연결_20250606.txt 처리 중
#   [10/16] → 2024_사업보고서_01_재무상태표_연결_20250606.txt 처리 중
#   [11/16] → 2023_사업보고서_01_재무상태표_보험_연결_20241101.txt 처리 중
#   [12/16] → 2023_사업보고서_01_재무상태표_금융기타_연결_20241101.txt 처리 중
#   [13/16] → 2023_사업보고서_01_재무상태표_증권_연결_20241101.txt 처리 중
#   [14/16] → 2023_사업보고서_01_재무상태표_은행_연결_20241101.txt 처리 중
#   [15/16] → 2023_사업보고서_01_재무상태표_연결_20241101.txt 처리 중
#   [16/16] → 2022_사업보고서_01_재무상태표_연결_20250625.txt 처리 중
# ✅ 총 추출된 항목명 수: 396068개
# 🧹 중복 제거 후 유니크 항목명 수: 4012개
# 🧠 유사 컬럼 그룹화 진행 중...
# 100%|██████████| 4012/4012 [00:02<00:00, 1647.53it/s]
# 🏷 대표컬럼 추출 완료: 995개
# 💾 대표컬럼 CSV 저장 완료

# %%
df
# Out:
#           대표컬럼
# 0      (1)기타채권
# 1      (3)리스부채
# 2      (3)매출채권
# 3    (5) 이익잉여금
# 4      (6)무형자산
# ..         ...
# 990       환불자산
# 991       회생채무
# 992        회원권
# 993  회원사서비스미수금
# 994      후순위사채
#
# [995 rows x 1 columns]

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과/대표컬럼목록.csv")
print(df.columns)
# Out:
# Index(['대표컬럼'], dtype='object')

# %%
import pandas as pd
from collections import defaultdict, Counter
from rapidfuzz import process, fuzz
from tqdm import tqdm
import os

# ✅ 경로 설정
output_path = "/content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과"
column_file_path = os.path.join(output_path, "대표컬럼목록.csv")  # 여기에 원본 컬럼 리스트가 있다고 가정
output_csv_path = os.path.join(output_path, "대표컬럼_최종정리.csv")

# ✅ 1. 컬럼 리스트 불러오기
def load_column_list(path, col_name= "대표컬럼"):
    df = pd.read_csv(path)
    return df[col_name].dropna().tolist()

# ✅ 2. 유사 컬럼끼리 그룹 묶기 (RapidFuzz 기반)
def group_similar_columns(column_list, similarity_cutoff=75):
    unique_columns = list(set(column_list))
    grouped = defaultdict(list)
    visited = set()

    for col in tqdm(unique_columns, desc="🧠 유사 컬럼 그룹화 진행 중"):
        if col in visited:
            continue
        matches = process.extract(
            col, unique_columns,
            scorer=fuzz.token_sort_ratio,
            score_cutoff=similarity_cutoff,
            limit=20
        )
        matched_names = [m[0] for m in matches]
        for m in matched_names:
            visited.add(m)
        grouped[col].extend(matched_names)

    return grouped

# ✅ 3. 각 그룹에서 대표 컬럼 선택 (빈도 기준)
def select_representative_columns(grouped_dict, full_column_list):
    frequency = Counter(full_column_list)
    representative_mapping = dict()

    for rep, members in grouped_dict.items():
        best = max(members, key=lambda x: frequency[x])
        for m in members:
            representative_mapping[m] = best  # 유사컬럼 → 대표컬럼

    return representative_mapping

# ✅ 4. 실행
column_list = load_column_list(column_file_path)
grouped_columns = group_similar_columns(column_list, similarity_cutoff=75)
representative_map = select_representative_columns(grouped_columns, column_list)

# ✅ 5. 결과 저장
# 대표컬럼 리스트만 정리
final_representatives = sorted(set(representative_map.values()))
rep_df = pd.DataFrame({"대표컬럼": final_representatives})
rep_df.to_csv(output_csv_path, index=False)

print(f"✅ 대표컬럼 {len(rep_df)}개가 추출되어 저장되었습니다.")
# Out:
# 🧠 유사 컬럼 그룹화 진행 중: 100%|██████████| 995/995 [00:00<00:00, 3030.64it/s]
# ✅ 대표컬럼 794개가 추출되어 저장되었습니다.

# %%
# ✅ 6. 전체 컬럼 → 대표컬럼으로 치환
replaced_columns = [representative_map.get(col, col) for col in column_list]  # 매핑 안 된 경우 본인 유지

# ✅ 7. 대표컬럼별 사용 빈도 집계 및 정렬
representative_counter = Counter(replaced_columns)
sorted_representatives = representative_counter.most_common()

# ✅ 8. 정렬된 대표컬럼 + 빈도수 저장
freq_df = pd.DataFrame(sorted_representatives, columns=["대표컬럼", "빈도수"])
freq_output_path = os.path.join(output_path, "대표컬럼_빈도순정렬.csv")
freq_df.to_csv(freq_output_path, index=False)

# ✅ 9. 출력 확인
print("📊 대표컬럼별 사용 빈도 (내림차순 정렬):")
for col, freq in sorted_representatives[:20]:  # 상위 20개만 보기 좋게 출력
    print(f"{col}: {freq}")

print(f"\n✅ 빈도 기준 정렬 결과가 {freq_output_path}에 저장되었습니다.")
# Out:
# 📊 대표컬럼별 사용 빈도 (내림차순 정렬):
# 유동파생상품부채: 6
# 유동금융자산: 5
# 비유동 기타포괄손익-공정가치 측정 금융자산: 5
# 공동기업투자주식: 4
# 공정가치측정금융자산: 4
# 관계기업 및 공동기업투자: 4
# 유동금융보증부채: 4
# 금융부채: 4
# 기타유동채무: 4
# 기타지급채무: 4
# 보증금: 4
# 장기임대보증금: 4
# 대여금 및 수취채권: 4
# 매출채권: 4
# 비유동 리스부채: 4
# 매입채무 및 기타채무: 4
# 감가상각누계액: 3
# Ⅱ. 비 유 동 부 채: 3
# 계약부채: 3
# 관계기업및공동기업투자: 3
#
# ✅ 빈도 기준 정렬 결과가 /content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과/대표컬럼_빈도순정렬.csv에 저장되었습니다.

# %%
# ✅ 10. 대표컬럼 → 유사컬럼 리스트 역변환
representative_to_similars = defaultdict(list)
for similar_col, rep_col in representative_map.items():
    representative_to_similars[rep_col].append(similar_col)

# ✅ 11. 딕셔너리를 CSV로 저장
rep_group_path = os.path.join(output_path, "대표컬럼_유사컬럼_매핑.csv")
rep_group_df = pd.DataFrame([
    {"대표컬럼": rep, "유사컬럼들": ", ".join(sorted(list(set(similars))))}
    for rep, similars in representative_to_similars.items()
])
rep_group_df.to_csv(rep_group_path, index=False)

print(f"✅ 대표컬럼별 유사컬럼 목록이 {rep_group_path}에 저장되었습니다.")
# Out:
# ✅ 대표컬럼별 유사컬럼 목록이 /content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과/대표컬럼_유사컬럼_매핑.csv에 저장되었습니다.

# %%
# ✅ 12. 대표컬럼별 전체 사용 빈도 계산 (유사컬럼 등장 횟수 합산 기준)
column_frequency = Counter(column_list)  # 원본 컬럼 리스트에서의 빈도

rep_count_list = []
for rep, similars in representative_to_similars.items():
    total_count = sum(column_frequency[col] for col in similars if col in column_frequency)
    rep_count_list.append((rep, total_count, similars))

# ✅ 내림차순 정렬
rep_count_list_sorted = sorted(rep_count_list, key=lambda x: x[1], reverse=True)

# ✅ 13. 정리된 형태로 DataFrame 저장
rep_count_df = pd.DataFrame([
    {
        "대표컬럼": rep,
        "총사용빈도": count,
        "유사컬럼수": len(similars),
        "유사컬럼목록": ", ".join(sorted(set(similars)))
    }
    for rep, count, similars in rep_count_list_sorted
])

rep_count_path = os.path.join(output_path, "대표컬럼_사용빈도_내림차순.csv")
rep_count_df.to_csv(rep_count_path, index=False)

print(f"✅ 대표컬럼 사용빈도 기준 정리 결과가 {rep_count_path}에 저장되었습니다.")
# Out:
# ✅ 대표컬럼 사용빈도 기준 정리 결과가 /content/drive/MyDrive/Colab Notebooks/실전프로젝트/기러기_결과/대표컬럼_사용빈도_내림차순.csv에 저장되었습니다.
